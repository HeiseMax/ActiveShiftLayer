# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas

import torch
import torch.optim as optim
from torch.nn import CrossEntropyLoss, Conv2d, Sequential, BatchNorm2d
from torch.utils.data import DataLoader

import torchvision
import torchvision.datasets as datasets
from torchvision import transforms

from torchinfo import summary

from ActiveShiftLayer import ASL
from util import test_loss, train_NN

from ray import tune
from ray.tune.search.bayesopt import BayesOptSearch
from ray.tune.search import ConcurrencyLimiter

# %%
if torch.cuda.is_available():
    device = 'cuda'
else:
    device = 'cpu'
print(device)
# Out:
# cuda

# %%
batch_size = 100

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_dataset = torchvision.datasets.CIFAR10(root='./data/CIFAR10', train=True,
                                        download=True, transform=transform)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

test_dataset = torchvision.datasets.CIFAR10(root='./data/CIFAR10', train=False,
                                       download=True, transform=transform)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

num_labels = 10
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
from Models import LeNet
criterion = CrossEntropyLoss()
input_shape = (batch_size, 3, 32, 32)

def train_mnist(config, data = None):
    print(config)
    test_device = "cuda"
    model = LeNet(input_shape, 10, initial_lr=config["lr"], momentum=config["momentum"], weight_decay=0).to(test_device)
    train_NN(model, criterion, data,
    test_dataloader, epochs=4, batches_to_test=100,patience=2,device=test_device, print_test=False, verbose=False)
    acc = test_loss(model, test_dataloader, criterion, test_device)[1]
    tune.report(mean_accuracy=acc)

# %%
config = {"lr": tune.uniform(0.001, 0.1), "momentum": tune.uniform(0.5, 1)}

bayesopt = BayesOptSearch(metric="mean_accuracy", mode="max",
                          verbose=1, random_state=36, random_search_steps=10)
bayesopt = ConcurrencyLimiter(bayesopt, max_concurrent=1)

tuner = tune.Tuner(tune.with_resources(tune.with_parameters(train_mnist, data=train_dataloader), 
                {"gpu": 1}),  tune_config=tune.TuneConfig(search_alg=bayesopt, num_samples=30), param_space=config)

analysis = tuner.fit()
# Out:
# 2022-08-31 01:34:42,769	INFO worker.py:1509 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 2022-08-31 01:34:44,589	WARNING function_trainable.py:619 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# 2022-08-31 01:34:44,989	WARNING bayesopt_search.py:423 -- BayesOpt does not support specific sampling methods. The Uniform sampler will be dropped.
# 2022-08-31 01:34:44,990	WARNING bayesopt_search.py:423 -- BayesOpt does not support specific sampling methods. The Uniform sampler will be dropped.
# == Status ==<br>Current time: 2022-08-31 01:59:27 (running for 00:24:42.19)<br>Memory usage on this node: 9.5/15.4 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/5.89 GiB heap, 0.0/2.94 GiB objects (0.0/1.0 accelerator_type:G)<br>Result logdir: /home/max/ray_results/train_mnist_2022-08-31_01-34-39<br>Number of trials: 30/30 (30 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name          </th><th>status    </th><th>loc                  </th><th style="text-align: right;">        lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">  acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>train_mnist_544d74ca</td><td>TERMINATED</td><td>192.168.178.40:92676 </td><td style="text-align: right;">0.0731222 </td><td style="text-align: right;">  0.800807</td><td style="text-align: right;">60.7 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         39.3578</td></tr>
# <tr><td>train_mnist_6d3c8458</td><td>TERMINATED</td><td>192.168.178.40:93556 </td><td style="text-align: right;">0.0952659 </td><td style="text-align: right;">  0.571587</td><td style="text-align: right;">58.71</td><td style="text-align: right;">     1</td><td style="text-align: right;">         47.0122</td></tr>
# <tr><td>train_mnist_8ae4f5f8</td><td>TERMINATED</td><td>192.168.178.40:94443 </td><td style="text-align: right;">0.0809286 </td><td style="text-align: right;">  0.681607</td><td style="text-align: right;">58.81</td><td style="text-align: right;">     1</td><td style="text-align: right;">         46.3837</td></tr>
# <tr><td>train_mnist_a82693d8</td><td>TERMINATED</td><td>192.168.178.40:95335 </td><td style="text-align: right;">0.0194691 </td><td style="text-align: right;">  0.629576</td><td style="text-align: right;">55.28</td><td style="text-align: right;">     1</td><td style="text-align: right;">         46.7675</td></tr>
# <tr><td>train_mnist_c5950c88</td><td>TERMINATED</td><td>192.168.178.40:96230 </td><td style="text-align: right;">0.0633465 </td><td style="text-align: right;">  0.51628 </td><td style="text-align: right;">58.93</td><td style="text-align: right;">     1</td><td style="text-align: right;">         47.5955</td></tr>
# <tr><td>train_mnist_e35746c8</td><td>TERMINATED</td><td>192.168.178.40:97147 </td><td style="text-align: right;">0.094776  </td><td style="text-align: right;">  0.952159</td><td style="text-align: right;">51   </td><td style="text-align: right;">     1</td><td style="text-align: right;">         47.7754</td></tr>
# <tr><td>train_mnist_01372b40</td><td>TERMINATED</td><td>192.168.178.40:98037 </td><td style="text-align: right;">0.0554629 </td><td style="text-align: right;">  0.598504</td><td style="text-align: right;">56.35</td><td style="text-align: right;">     1</td><td style="text-align: right;">         48.5605</td></tr>
# <tr><td>train_mnist_1f81a5b2</td><td>TERMINATED</td><td>192.168.178.40:98945 </td><td style="text-align: right;">0.0239713 </td><td style="text-align: right;">  0.501183</td><td style="text-align: right;">54.03</td><td style="text-align: right;">     1</td><td style="text-align: right;">         47.453 </td></tr>
# <tr><td>train_mnist_3d3c2bcc</td><td>TERMINATED</td><td>192.168.178.40:99787 </td><td style="text-align: right;">0.0233795 </td><td style="text-align: right;">  0.687672</td><td style="text-align: right;">57.57</td><td style="text-align: right;">     1</td><td style="text-align: right;">         47.2905</td></tr>
# <tr><td>train_mnist_5af06c96</td><td>TERMINATED</td><td>192.168.178.40:100606</td><td style="text-align: right;">0.0458216 </td><td style="text-align: right;">  0.62304 </td><td style="text-align: right;">58.18</td><td style="text-align: right;">     1</td><td style="text-align: right;">         46.51  </td></tr>
# <tr><td>train_mnist_78452f48</td><td>TERMINATED</td><td>192.168.178.40:101428</td><td style="text-align: right;">0.0275192 </td><td style="text-align: right;">  0.570504</td><td style="text-align: right;">55.59</td><td style="text-align: right;">     1</td><td style="text-align: right;">         47.2592</td></tr>
# <tr><td>train_mnist_95f3b3e8</td><td>TERMINATED</td><td>192.168.178.40:102248</td><td style="text-align: right;">0.00653045</td><td style="text-align: right;">  0.876757</td><td style="text-align: right;">56.13</td><td style="text-align: right;">     1</td><td style="text-align: right;">         46.5155</td></tr>
# <tr><td>train_mnist_b34bcb56</td><td>TERMINATED</td><td>192.168.178.40:103055</td><td style="text-align: right;">0.0140691 </td><td style="text-align: right;">  0.882075</td><td style="text-align: right;">57.61</td><td style="text-align: right;">     1</td><td style="text-align: right;">         47.8467</td></tr>
# <tr><td>train_mnist_d1529382</td><td>TERMINATED</td><td>192.168.178.40:104339</td><td style="text-align: right;">0.0269526 </td><td style="text-align: right;">  0.847775</td><td style="text-align: right;">57.67</td><td style="text-align: right;">     1</td><td style="text-align: right;">         47.2457</td></tr>
# <tr><td>train_mnist_ef57c262</td><td>TERMINATED</td><td>192.168.178.40:105164</td><td style="text-align: right;">0.0236123 </td><td style="text-align: right;">  0.888012</td><td style="text-align: right;">59.02</td><td style="text-align: right;">     1</td><td style="text-align: right;">         46.8824</td></tr>
# <tr><td>train_mnist_0cea19ba</td><td>TERMINATED</td><td>192.168.178.40:105979</td><td style="text-align: right;">0.0342268 </td><td style="text-align: right;">  0.530184</td><td style="text-align: right;">56.92</td><td style="text-align: right;">     1</td><td style="text-align: right;">         46.6842</td></tr>
# <tr><td>train_mnist_2a990188</td><td>TERMINATED</td><td>192.168.178.40:106812</td><td style="text-align: right;">0.0707497 </td><td style="text-align: right;">  0.824101</td><td style="text-align: right;">61.21</td><td style="text-align: right;">     1</td><td style="text-align: right;">         47.3221</td></tr>
# <tr><td>train_mnist_48c4a734</td><td>TERMINATED</td><td>192.168.178.40:107631</td><td style="text-align: right;">0.1       </td><td style="text-align: right;">  0.820472</td><td style="text-align: right;">59.8 </td><td style="text-align: right;">     1</td><td style="text-align: right;">         47.223 </td></tr>
# <tr><td>train_mnist_668b38b4</td><td>TERMINATED</td><td>192.168.178.40:108439</td><td style="text-align: right;">0.0749    </td><td style="text-align: right;">  0.86006 </td><td style="text-align: right;">59.13</td><td style="text-align: right;">     1</td><td style="text-align: right;">         47.8134</td></tr>
# <tr><td>train_mnist_84b042da</td><td>TERMINATED</td><td>192.168.178.40:109275</td><td style="text-align: right;">0.0379786 </td><td style="text-align: right;">  0.794896</td><td style="text-align: right;">60.61</td><td style="text-align: right;">     1</td><td style="text-align: right;">         46.7009</td></tr>
# <tr><td>train_mnist_a26a36aa</td><td>TERMINATED</td><td>192.168.178.40:110092</td><td style="text-align: right;">0.0530961 </td><td style="text-align: right;">  0.753955</td><td style="text-align: right;">61.36</td><td style="text-align: right;">     1</td><td style="text-align: right;">         47.343 </td></tr>
# <tr><td>train_mnist_c010d56a</td><td>TERMINATED</td><td>192.168.178.40:110904</td><td style="text-align: right;">0.0139011 </td><td style="text-align: right;">  0.754366</td><td style="text-align: right;">55.63</td><td style="text-align: right;">     1</td><td style="text-align: right;">         47.2766</td></tr>
# <tr><td>train_mnist_ddcd4066</td><td>TERMINATED</td><td>192.168.178.40:111727</td><td style="text-align: right;">0.0810524 </td><td style="text-align: right;">  0.681603</td><td style="text-align: right;">57.21</td><td style="text-align: right;">     1</td><td style="text-align: right;">         47.35  </td></tr>
# <tr><td>train_mnist_
# 2022-08-31 01:34:45,765	WARNING worker.py:1829 -- Warning: The actor ImplicitFunc is very large (29 MiB). Check that its definition is not implicitly capturing a large array or other object in scope. Tip: use ray.put() to put large objects in the Ray object store.
# (train_mnist pid=92676) {'lr': 0.07312221196797684, 'momentum': 0.8008071061851066}
# Result for train_mnist_544d74ca:
#   date: 2022-08-31_01-35-26
#   done: false
#   experiment_id: f437961348ba4a5a919b4d10992263a7
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 60.7
#   node_ip: 192.168.178.40
#   pid: 92676
#   time_since_restore: 39.35782337188721
#   time_this_iter_s: 39.35782337188721
#   time_total_s: 39.35782337188721
#   timestamp: 1661902526
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 544d74ca
#   warmup_time: 0.0027205944061279297
#
# Result for train_mnist_544d74ca:
#   date: 2022-08-31_01-35-26
#   done: true
#   experiment_id: f437961348ba4a5a919b4d10992263a7
#   experiment_tag: 1_lr=0.0731,momentum=0.8008
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 60.7
#   node_ip: 192.168.178.40
#   pid: 92676
#   time_since_restore: 39.35782337188721
#   time_this_iter_s: 39.35782337188721
#   time_total_s: 39.35782337188721
#   timestamp: 1661902526
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 544d74ca
#   warmup_time: 0.0027205944061279297
#
# (train_mnist pid=93556) {'lr': 0.09526588607319536, 'momentum': 0.5715867238605152}
# Result for train_mnist_6d3c8458:
#   date: 2022-08-31_01-36-16
#   done: false
#   experiment_id: 97ccec76a144431cbd225ec79c2da1a9
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 58.71
#   node_ip: 192.168.178.40
#   pid: 93556
#   time_since_restore: 47.01223111152649
#   time_this_iter_s: 47.01223111152649
#   time_total_s: 47.01223111152649
#   timestamp: 1661902576
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 6d3c8458
#   warmup_time: 0.0022134780883789062
#
# Result for train_mnist_6d3c8458:
#   date: 2022-08-31_01-36-16
#   done: true
#   experiment_id: 97ccec76a144431cbd225ec79c2da1a9
#   experiment_tag: 2_lr=0.0953,momentum=0.5716
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 58.71
#   node_ip: 192.168.178.40
#   pid: 93556
#   time_since_restore: 47.01223111152649
#   time_this_iter_s: 47.01223111152649
#   time_total_s: 47.01223111152649
#   timestamp: 1661902576
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 6d3c8458
#   warmup_time: 0.0022134780883789062
#
# (train_mnist pid=94443) {'lr': 0.08092855385714631, 'momentum': 0.6816072982605145}
# Result for train_mnist_8ae4f5f8:
#   date: 2022-08-31_01-37-05
#   done: false
#   experiment_id: 523f6c1718194d528282be1751123ed5
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 58.81
#   node_ip: 192.168.178.40
#   pid: 94443
#   time_since_restore: 46.38371419906616
#   time_this_iter_s: 46.38371419906616
#   time_total_s: 46.38371419906616
#   timestamp: 1661902625
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8ae4f5f8
#   warmup_time: 0.002062082290649414
#
# Result for train_mnist_8ae4f5f8:
#   date: 2022-08-31_01-37-05
#   done: true
#   experiment_id: 523f6c1718194d528282be1751123ed5
#   experiment_tag: 3_lr=0.0809,momentum=0.6816
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 58.81
#   node_ip: 192.168.178.40
#   pid: 94443
#   time_since_restore: 46.38371419906616
#   time_this_iter_s: 46.38371419906616
#   time_total_s: 46.38371419906616
#   timestamp: 1661902625
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8ae4f5f8
#   warmup_time: 0.002062082290649414
#
# (train_mnist pid=95335) {'lr': 0.019469124416642274, 'momentum': 0.6295756191439736}
# Result for train_mnist_a82693d8:
#   date: 2022-08-31_01-37-55
#   done: false
#   experiment_id: a6061dd12ef54db8b3d27112ec6d157a
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 55.28
#   node_ip: 192.168.178.40
#   pid: 95335
#   time_since_restore: 46.7675416469574
#   time_this_iter_s: 46.7675416469574
#   time_total_s: 46.7675416469574
#   timestamp: 1661902675
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: a82693d8
#   warmup_time: 0.002105236053466797
#
# Result for train_mnist_a82693d8:
#   date: 2022-08-31_01-37-55
#   done: true
#   experiment_id: a6061dd12ef54db8b3d27112ec6d157a
#   experiment_tag: 4_lr=0.0195,momentum=0.6296
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 55.28
#   node_ip: 192.168.178.40
#   pid: 95335
#   time_since_restore: 46.7675416469574
#   time_this_iter_s: 46.7675416469574
#   time_total_s: 46.7675416469574
#   timestamp: 1661902675
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: a82693d8
#   warmup_time: 0.002105236053466797
#
# (train_mnist pid=96230) {'lr': 0.06334647191858297, 'momentum': 0.5162804607694647}
# Result for train_mnist_c5950c88:
#   date: 2022-08-31_01-38-45
#   done: false
#   experiment_id: ebd18e8eb4204c8d9158fc00c4a1df93
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 58.93
#   node_ip: 192.168.178.40
#   pid: 96230
#   time_since_restore: 47.59548282623291
#   time_this_iter_s: 47.59548282623291
#   time_total_s: 47.59548282623291
#   timestamp: 1661902725
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: c5950c88
#   warmup_time: 0.002390623092651367
#
# Result for train_mnist_c5950c88:
#   date: 2022-08-31_01-38-45
#   done: true
#   experiment_id: ebd18e8eb4204c8d9158fc00c4a1df93
#   experiment_tag: 5_lr=0.0633,momentum=0.5163
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 58.93
#   node_ip: 192.168.178.40
#   pid: 96230
#   time_since_restore: 47.59548282623291
#   time_this_iter_s: 47.59548282623291
#   time_total_s: 47.59548282623291
#   timestamp: 1661902725
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: c5950c88
#   warmup_time: 0.002390623092651367
#
# (train_mnist pid=97147) {'lr': 0.09477597524454878, 'momentum': 0.9521591218091032}
# Result for train_mnist_e35746c8:
#   date: 2022-08-31_01-39-35
#   done: false
#   experiment_id: 93b2d3c9a105418ea2033ece289e0237
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 51.0
#   node_ip: 192.168.178.40
#   pid: 97147
#   time_since_restore: 47.775352478027344
#   time_this_iter_s: 47.775352478027344
#   time_total_s: 47.775352478027344
#   timestamp: 1661902775
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e35746c8
#   warmup_time: 0.0020742416381835938
#
# Result for train_mnist_e35746c8:
#   date: 2022-08-31_01-39-35
#   done: true
#   experiment_id: 93b2d3c9a105418ea2033ece289e0237
#   experiment_tag: 6_lr=0.0948,momentum=0.9522
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 51.0
#   node_ip: 192.168.178.40
#   pid: 97147
#   time_since_restore: 47.775352478027344
#   time_this_iter_s: 47.775352478027344
#   time_total_s: 47.775352478027344
#   timestamp: 1661902775
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e35746c8
#   warmup_time: 0.0020742416381835938
#
# (train_mnist pid=98037) {'lr': 0.055462885406561406, 'momentum': 0.5985041438203735}
# Result for train_mnist_01372b40:
#   date: 2022-08-31_01-40-26
#   done: false
#   experiment_id: ad40b2569f9f47e4bc17cdbf5410f437
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 56.35
#   node_ip: 192.168.178.40
#   pid: 98037
#   time_since_restore: 48.56047487258911
#   time_this_iter_s: 48.56047487258911
#   time_total_s: 48.56047487258911
#   timestamp: 1661902826
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 01372b40
#   warmup_time: 0.0023097991943359375
#
# Result for train_mnist_01372b40:
#   date: 2022-08-31_01-40-26
#   done: true
#   experiment_id: ad40b2569f9f47e4bc17cdbf5410f437
#   experiment_tag: 7_lr=0.0555,momentum=0.5985
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 56.35
#   node_ip: 192.168.178.40
#   pid: 98037
#   time_since_restore: 48.56047487258911
#   time_this_iter_s: 48.56047487258911
#   time_total_s: 48.56047487258911
#   timestamp: 1661902826
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 01372b40
#   warmup_time: 0.0023097991943359375
#
# (train_mnist pid=98945) {'lr': 0.023971250318175902, 'momentum': 0.5011829875221057}
# Result for train_mnist_1f81a5b2:
#   date: 2022-08-31_01-41-15
#   done: false
#   experiment_id: 94792e79caa14997abec6bba4470652d
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 54.03
#   node_ip: 192.168.178.40
#   pid: 98945
#   time_since_restore: 47.453028440475464
#   time_this_iter_s: 47.453028440475464
#   time_total_s: 47.453028440475464
#   timestamp: 1661902875
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 1f81a5b2
#   warmup_time: 0.002709627151489258
#
# Result for train_mnist_1f81a5b2:
#   date: 2022-08-31_01-41-15
#   done: true
#   experiment_id: 94792e79caa14997abec6bba4470652d
#   experiment_tag: 8_lr=0.0240,momentum=0.5012
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 54.03
#   node_ip: 192.168.178.40
#   pid: 98945
#   time_since_restore: 47.453028440475464
#   time_this_iter_s: 47.453028440475464
#   time_total_s: 47.453028440475464
#   timestamp: 1661902875
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 1f81a5b2
#   warmup_time: 0.002709627151489258
#
# (train_mnist pid=99787) {'lr': 0.02337949895247408, 'momentum': 0.6876716187775468}
# Result for train_mnist_3d3c2bcc:
#   date: 2022-08-31_01-42-05
#   done: false
#   experiment_id: 84af7e7993aa47c082059f48090a7029
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 57.57
#   node_ip: 192.168.178.40
#   pid: 99787
#   time_since_restore: 47.29046297073364
#   time_this_iter_s: 47.29046297073364
#   time_total_s: 47.29046297073364
#   timestamp: 1661902925
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 3d3c2bcc
#   warmup_time: 0.0021600723266601562
#
# Result for train_mnist_3d3c2bcc:
#   date: 2022-08-31_01-42-05
#   done: true
#   experiment_id: 84af7e7993aa47c082059f48090a7029
#   experiment_tag: 9_lr=0.0234,momentum=0.6877
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 57.57
#   node_ip: 192.168.178.40
#   pid: 99787
#   time_since_restore: 47.29046297073364
#   time_this_iter_s: 47.29046297073364
#   time_total_s: 47.29046297073364
#   timestamp: 1661902925
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 3d3c2bcc
#   warmup_time: 0.0021600723266601562
#
# (train_mnist pid=100606) {'lr': 0.04582162682879263, 'momentum': 0.6230395950371264}
# Result for train_mnist_5af06c96:
#   date: 2022-08-31_01-42-54
#   done: false
#   experiment_id: 77f0ecec617b43679139966ed3a3128f
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 58.18
#   node_ip: 192.168.178.40
#   pid: 100606
#   time_since_restore: 46.510027170181274
#   time_this_iter_s: 46.510027170181274
#   time_total_s: 46.510027170181274
#   timestamp: 1661902974
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 5af06c96
#   warmup_time: 0.002198934555053711
#
# Result for train_mnist_5af06c96:
#   date: 2022-08-31_01-42-54
#   done: true
#   experiment_id: 77f0ecec617b43679139966ed3a3128f
#   experiment_tag: 10_lr=0.0458,momentum=0.6230
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 58.18
#   node_ip: 192.168.178.40
#   pid: 100606
#   time_since_restore: 46.510027170181274
#   time_this_iter_s: 46.510027170181274
#   time_total_s: 46.510027170181274
#   timestamp: 1661902974
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 5af06c96
#   warmup_time: 0.002198934555053711
#
# (train_mnist pid=101428) {'lr': 0.02751917950960998, 'momentum': 0.5705037793692689}
# Result for train_mnist_78452f48:
#   date: 2022-08-31_01-43-44
#   done: false
#   experiment_id: 4a3ecaabe958450f9c752807c878aeb3
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 55.59
#   node_ip: 192.168.178.40
#   pid: 101428
#   time_since_restore: 47.25924372673035
#   time_this_iter_s: 47.25924372673035
#   time_total_s: 47.25924372673035
#   timestamp: 1661903024
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 78452f48
#   warmup_time: 0.0021567344665527344
#
# Result for train_mnist_78452f48:
#   date: 2022-08-31_01-43-44
#   done: true
#   experiment_id: 4a3ecaabe958450f9c752807c878aeb3
#   experiment_tag: 11_lr=0.0275,momentum=0.5705
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 55.59
#   node_ip: 192.168.178.40
#   pid: 101428
#   time_since_restore: 47.25924372673035
#   time_this_iter_s: 47.25924372673035
#   time_total_s: 47.25924372673035
#   timestamp: 1661903024
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 78452f48
#   warmup_time: 0.0021567344665527344
#
# (train_mnist pid=102248) {'lr': 0.006530447905696379, 'momentum': 0.8767568104444392}
# Result for train_mnist_95f3b3e8:
#   date: 2022-08-31_01-44-34
#   done: false
#   experiment_id: 58ccfe5e503345db9deb04e8d933c09e
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 56.13
#   node_ip: 192.168.178.40
#   pid: 102248
#   time_since_restore: 46.51553559303284
#   time_this_iter_s: 46.51553559303284
#   time_total_s: 46.51553559303284
#   timestamp: 1661903074
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 95f3b3e8
#   warmup_time: 0.0020592212677001953
#
# Result for train_mnist_95f3b3e8:
#   date: 2022-08-31_01-44-34
#   done: true
#   experiment_id: 58ccfe5e503345db9deb04e8d933c09e
#   experiment_tag: 12_lr=0.0065,momentum=0.8768
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 56.13
#   node_ip: 192.168.178.40
#   pid: 102248
#   time_since_restore: 46.51553559303284
#   time_this_iter_s: 46.51553559303284
#   time_total_s: 46.51553559303284
#   timestamp: 1661903074
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 95f3b3e8
#   warmup_time: 0.0020592212677001953
#
# (train_mnist pid=103055) {'lr': 0.014069139591091954, 'momentum': 0.8820746344827901}
# Result for train_mnist_b34bcb56:
#   date: 2022-08-31_01-45-24
#   done: false
#   experiment_id: 717b0179b7164091bf9a8981e0a1a27f
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 57.61
#   node_ip: 192.168.178.40
#   pid: 103055
#   time_since_restore: 47.84668493270874
#   time_this_iter_s: 47.84668493270874
#   time_total_s: 47.84668493270874
#   timestamp: 1661903124
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: b34bcb56
#   warmup_time: 0.0022902488708496094
#
# Result for train_mnist_b34bcb56:
#   date: 2022-08-31_01-45-24
#   done: true
#   experiment_id: 717b0179b7164091bf9a8981e0a1a27f
#   experiment_tag: 13_lr=0.0141,momentum=0.8821
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 57.61
#   node_ip: 192.168.178.40
#   pid: 103055
#   time_since_restore: 47.84668493270874
#   time_this_iter_s: 47.84668493270874
#   time_total_s: 47.84668493270874
#   timestamp: 1661903124
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: b34bcb56
#   warmup_time: 0.0022902488708496094
#
# (train_mnist pid=104339) {'lr': 0.026952550582905858, 'momentum': 0.8477749447684775}
# Result for train_mnist_d1529382:
#   date: 2022-08-31_01-46-14
#   done: false
#   experiment_id: 307931a9d1c34334b6dc48a4f283309a
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 57.67
#   node_ip: 192.168.178.40
#   pid: 104339
#   time_since_restore: 47.24572777748108
#   time_this_iter_s: 47.24572777748108
#   time_total_s: 47.24572777748108
#   timestamp: 1661903174
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d1529382
#   warmup_time: 0.002406597137451172
#
# Result for train_mnist_d1529382:
#   date: 2022-08-31_01-46-14
#   done: true
#   experiment_id: 307931a9d1c34334b6dc48a4f283309a
#   experiment_tag: 14_lr=0.0270,momentum=0.8478
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 57.67
#   node_ip: 192.168.178.40
#   pid: 104339
#   time_since_restore: 47.24572777748108
#   time_this_iter_s: 47.24572777748108
#   time_total_s: 47.24572777748108
#   timestamp: 1661903174
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d1529382
#   warmup_time: 0.002406597137451172
#
# (train_mnist pid=105164) {'lr': 0.02361225397502149, 'momentum': 0.8880119247415177}
# Result for train_mnist_ef57c262:
#   date: 2022-08-31_01-47-04
#   done: false
#   experiment_id: dce365b0dbfb4856a69a51d7a9820f7a
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 59.02
#   node_ip: 192.168.178.40
#   pid: 105164
#   time_since_restore: 46.88242220878601
#   time_this_iter_s: 46.88242220878601
#   time_total_s: 46.88242220878601
#   timestamp: 1661903224
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: ef57c262
#   warmup_time: 0.002254962921142578
#
# Result for train_mnist_ef57c262:
#   date: 2022-08-31_01-47-04
#   done: true
#   experiment_id: dce365b0dbfb4856a69a51d7a9820f7a
#   experiment_tag: 15_lr=0.0236,momentum=0.8880
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 59.02
#   node_ip: 192.168.178.40
#   pid: 105164
#   time_since_restore: 46.88242220878601
#   time_this_iter_s: 46.88242220878601
#   time_total_s: 46.88242220878601
#   timestamp: 1661903224
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: ef57c262
#   warmup_time: 0.002254962921142578
#
# (train_mnist pid=105979) {'lr': 0.034226842200255174, 'momentum': 0.5301844058675189}
# Result for train_mnist_0cea19ba:
#   date: 2022-08-31_01-47-54
#   done: false
#   experiment_id: 9e472c6018df4f89bc31b0fd23e89993
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 56.92
#   node_ip: 192.168.178.40
#   pid: 105979
#   time_since_restore: 46.68423056602478
#   time_this_iter_s: 46.68423056602478
#   time_total_s: 46.68423056602478
#   timestamp: 1661903274
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 0cea19ba
#   warmup_time: 0.0024034976959228516
#
# Result for train_mnist_0cea19ba:
#   date: 2022-08-31_01-47-54
#   done: true
#   experiment_id: 9e472c6018df4f89bc31b0fd23e89993
#   experiment_tag: 16_lr=0.0342,momentum=0.5302
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 56.92
#   node_ip: 192.168.178.40
#   pid: 105979
#   time_since_restore: 46.68423056602478
#   time_this_iter_s: 46.68423056602478
#   time_total_s: 46.68423056602478
#   timestamp: 1661903274
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 0cea19ba
#   warmup_time: 0.0024034976959228516
#
# (train_mnist pid=106812) {'lr': 0.07074965227377933, 'momentum': 0.8241010467283005}
# Result for train_mnist_2a990188:
#   date: 2022-08-31_01-48-44
#   done: false
#   experiment_id: 66c4ed423ba64519b1626a120365a9f3
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 61.21
#   node_ip: 192.168.178.40
#   pid: 106812
#   time_since_restore: 47.32206988334656
#   time_this_iter_s: 47.32206988334656
#   time_total_s: 47.32206988334656
#   timestamp: 1661903324
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 2a990188
#   warmup_time: 0.0023856163024902344
#
# Result for train_mnist_2a990188:
#   date: 2022-08-31_01-48-44
#   done: true
#   experiment_id: 66c4ed423ba64519b1626a120365a9f3
#   experiment_tag: 17_lr=0.0707,momentum=0.8241
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 61.21
#   node_ip: 192.168.178.40
#   pid: 106812
#   time_since_restore: 47.32206988334656
#   time_this_iter_s: 47.32206988334656
#   time_total_s: 47.32206988334656
#   timestamp: 1661903324
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 2a990188
#   warmup_time: 0.0023856163024902344
#
# (train_mnist pid=107631) {'lr': 0.1, 'momentum': 0.8204723185157798}
# Result for train_mnist_48c4a734:
#   date: 2022-08-31_01-49-34
#   done: false
#   experiment_id: 31ddf99beefa47d5a7525515580f4820
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 59.8
#   node_ip: 192.168.178.40
#   pid: 107631
#   time_since_restore: 47.22298240661621
#   time_this_iter_s: 47.22298240661621
#   time_total_s: 47.22298240661621
#   timestamp: 1661903374
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 48c4a734
#   warmup_time: 0.0021021366119384766
#
# Result for train_mnist_48c4a734:
#   date: 2022-08-31_01-49-34
#   done: true
#   experiment_id: 31ddf99beefa47d5a7525515580f4820
#   experiment_tag: 18_lr=0.1000,momentum=0.8205
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 59.8
#   node_ip: 192.168.178.40
#   pid: 107631
#   time_since_restore: 47.22298240661621
#   time_this_iter_s: 47.22298240661621
#   time_total_s: 47.22298240661621
#   timestamp: 1661903374
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 48c4a734
#   warmup_time: 0.0021021366119384766
#
# (train_mnist pid=108439) {'lr': 0.07489998373844163, 'momentum': 0.8600598080690183}
# Result for train_mnist_668b38b4:
#   date: 2022-08-31_01-50-25
#   done: false
#   experiment_id: 82204ca3caa446758abcfcbb32052a4f
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 59.13
#   node_ip: 192.168.178.40
#   pid: 108439
#   time_since_restore: 47.81337547302246
#   time_this_iter_s: 47.81337547302246
#   time_total_s: 47.81337547302246
#   timestamp: 1661903425
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 668b38b4
#   warmup_time: 0.0022974014282226562
#
# Result for train_mnist_668b38b4:
#   date: 2022-08-31_01-50-25
#   done: true
#   experiment_id: 82204ca3caa446758abcfcbb32052a4f
#   experiment_tag: 19_lr=0.0749,momentum=0.8601
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 59.13
#   node_ip: 192.168.178.40
#   pid: 108439
#   time_since_restore: 47.81337547302246
#   time_this_iter_s: 47.81337547302246
#   time_total_s: 47.81337547302246
#   timestamp: 1661903425
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 668b38b4
#   warmup_time: 0.0022974014282226562
#
# (train_mnist pid=109275) {'lr': 0.03797862535444276, 'momentum': 0.7948956764055903}
# Result for train_mnist_84b042da:
#   date: 2022-08-31_01-51-15
#   done: false
#   experiment_id: 755d98db5fe148cfac9182daea85a14f
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 60.61
#   node_ip: 192.168.178.40
#   pid: 109275
#   time_since_restore: 46.70086622238159
#   time_this_iter_s: 46.70086622238159
#   time_total_s: 46.70086622238159
#   timestamp: 1661903475
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 84b042da
#   warmup_time: 0.002438068389892578
#
# Result for train_mnist_84b042da:
#   date: 2022-08-31_01-51-15
#   done: true
#   experiment_id: 755d98db5fe148cfac9182daea85a14f
#   experiment_tag: 20_lr=0.0380,momentum=0.7949
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 60.61
#   node_ip: 192.168.178.40
#   pid: 109275
#   time_since_restore: 46.70086622238159
#   time_this_iter_s: 46.70086622238159
#   time_total_s: 46.70086622238159
#   timestamp: 1661903475
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 84b042da
#   warmup_time: 0.002438068389892578
#
# (train_mnist pid=110092) {'lr': 0.05309612987790999, 'momentum': 0.7539545167256022}
# Result for train_mnist_a26a36aa:
#   date: 2022-08-31_01-52-04
#   done: false
#   experiment_id: 2b42bb02779a4f2898500fff98e8a499
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 61.36
#   node_ip: 192.168.178.40
#   pid: 110092
#   time_since_restore: 47.34300780296326
#   time_this_iter_s: 47.34300780296326
#   time_total_s: 47.34300780296326
#   timestamp: 1661903524
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: a26a36aa
#   warmup_time: 0.0020453929901123047
#
# Result for train_mnist_a26a36aa:
#   date: 2022-08-31_01-52-04
#   done: true
#   experiment_id: 2b42bb02779a4f2898500fff98e8a499
#   experiment_tag: 21_lr=0.0531,momentum=0.7540
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 61.36
#   node_ip: 192.168.178.40
#   pid: 110092
#   time_since_restore: 47.34300780296326
#   time_this_iter_s: 47.34300780296326
#   time_total_s: 47.34300780296326
#   timestamp: 1661903524
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: a26a36aa
#   warmup_time: 0.0020453929901123047
#
# (train_mnist pid=110904) {'lr': 0.013901051468247907, 'momentum': 0.7543655577583153}
# Result for train_mnist_c010d56a:
#   date: 2022-08-31_01-52-54
#   done: false
#   experiment_id: 392dc776a2e0424f8fb65d0e4582c3d7
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 55.63
#   node_ip: 192.168.178.40
#   pid: 110904
#   time_since_restore: 47.27657747268677
#   time_this_iter_s: 47.27657747268677
#   time_total_s: 47.27657747268677
#   timestamp: 1661903574
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: c010d56a
#   warmup_time: 0.002206087112426758
#
# Result for train_mnist_c010d56a:
#   date: 2022-08-31_01-52-54
#   done: true
#   experiment_id: 392dc776a2e0424f8fb65d0e4582c3d7
#   experiment_tag: 22_lr=0.0139,momentum=0.7544
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 55.63
#   node_ip: 192.168.178.40
#   pid: 110904
#   time_since_restore: 47.27657747268677
#   time_this_iter_s: 47.27657747268677
#   time_total_s: 47.27657747268677
#   timestamp: 1661903574
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: c010d56a
#   warmup_time: 0.002206087112426758
#
# (train_mnist pid=111727) {'lr': 0.08105236880323892, 'momentum': 0.6816025697084931}
# Result for train_mnist_ddcd4066:
#   date: 2022-08-31_01-53-44
#   done: false
#   experiment_id: 0e1b0a13dbbc4f919f3982affbb818b6
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 57.21
#   node_ip: 192.168.178.40
#   pid: 111727
#   time_since_restore: 47.350034952163696
#   time_this_iter_s: 47.350034952163696
#   time_total_s: 47.350034952163696
#   timestamp: 1661903624
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: ddcd4066
#   warmup_time: 0.0021622180938720703
#
# Result for train_mnist_ddcd4066:
#   date: 2022-08-31_01-53-44
#   done: true
#   experiment_id: 0e1b0a13dbbc4f919f3982affbb818b6
#   experiment_tag: 23_lr=0.0811,momentum=0.6816
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 57.21
#   node_ip: 192.168.178.40
#   pid: 111727
#   time_since_restore: 47.350034952163696
#   time_this_iter_s: 47.350034952163696
#   time_total_s: 47.350034952163696
#   timestamp: 1661903624
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: ddcd4066
#   warmup_time: 0.0021622180938720703
#
# (train_mnist pid=112554) {'lr': 0.07415219839833402, 'momentum': 0.956684168643591}
# Result for train_mnist_fbaa08b2:
#   date: 2022-08-31_01-54-34
#   done: false
#   experiment_id: 009e5c04904f47bdad337a585a925fb0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 51.51
#   node_ip: 192.168.178.40
#   pid: 112554
#   time_since_restore: 46.88748383522034
#   time_this_iter_s: 46.88748383522034
#   time_total_s: 46.88748383522034
#   timestamp: 1661903674
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: fbaa08b2
#   warmup_time: 0.0022177696228027344
#
# Result for train_mnist_fbaa08b2:
#   date: 2022-08-31_01-54-34
#   done: true
#   experiment_id: 009e5c04904f47bdad337a585a925fb0
#   experiment_tag: 24_lr=0.0742,momentum=0.9567
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 51.51
#   node_ip: 192.168.178.40
#   pid: 112554
#   time_since_restore: 46.88748383522034
#   time_this_iter_s: 46.88748383522034
#   time_total_s: 46.88748383522034
#   timestamp: 1661903674
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: fbaa08b2
#   warmup_time: 0.0022177696228027344
#
# (train_mnist pid=113361) {'lr': 0.09064810642952528, 'momentum': 0.788265166755095}
# Result for train_mnist_19237d74:
#   date: 2022-08-31_01-55-23
#   done: false
#   experiment_id: fa25a365d806455899db8a98b8d64928
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 56.87
#   node_ip: 192.168.178.40
#   pid: 113361
#   time_since_restore: 45.711302042007446
#   time_this_iter_s: 45.711302042007446
#   time_total_s: 45.711302042007446
#   timestamp: 1661903723
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 19237d74
#   warmup_time: 0.0022335052490234375
#
# Result for train_mnist_19237d74:
#   date: 2022-08-31_01-55-23
#   done: true
#   experiment_id: fa25a365d806455899db8a98b8d64928
#   experiment_tag: 25_lr=0.0906,momentum=0.7883
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 56.87
#   node_ip: 192.168.178.40
#   pid: 113361
#   time_since_restore: 45.711302042007446
#   time_this_iter_s: 45.711302042007446
#   time_total_s: 45.711302042007446
#   timestamp: 1661903723
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 19237d74
#   warmup_time: 0.0022335052490234375
#
# (train_mnist pid=114201) {'lr': 0.07275514138039212, 'momentum': 0.8012518839030085}
# Result for train_mnist_3634dc46:
#   date: 2022-08-31_01-56-12
#   done: false
#   experiment_id: ed96ff779cf54ff3abf8842aacb40cfb
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 59.64
#   node_ip: 192.168.178.40
#   pid: 114201
#   time_since_restore: 46.80079889297485
#   time_this_iter_s: 46.80079889297485
#   time_total_s: 46.80079889297485
#   timestamp: 1661903772
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 3634dc46
#   warmup_time: 0.0027222633361816406
#
# Result for train_mnist_3634dc46:
#   date: 2022-08-31_01-56-12
#   done: true
#   experiment_id: ed96ff779cf54ff3abf8842aacb40cfb
#   experiment_tag: 26_lr=0.0728,momentum=0.8013
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 59.64
#   node_ip: 192.168.178.40
#   pid: 114201
#   time_since_restore: 46.80079889297485
#   time_this_iter_s: 46.80079889297485
#   time_total_s: 46.80079889297485
#   timestamp: 1661903772
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 3634dc46
#   warmup_time: 0.0027222633361816406
#
# (train_mnist pid=115025) {'lr': 0.00794823757124111, 'momentum': 0.8681094048597053}
# Result for train_mnist_537ee3be:
#   date: 2022-08-31_01-57-01
#   done: false
#   experiment_id: 023b5bcbbd1e4f14a28ec774b9eb714a
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 55.31
#   node_ip: 192.168.178.40
#   pid: 115025
#   time_since_restore: 45.96293902397156
#   time_this_iter_s: 45.96293902397156
#   time_total_s: 45.96293902397156
#   timestamp: 1661903821
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 537ee3be
#   warmup_time: 0.0022020339965820312
#
# Result for train_mnist_537ee3be:
#   date: 2022-08-31_01-57-01
#   done: true
#   experiment_id: 023b5bcbbd1e4f14a28ec774b9eb714a
#   experiment_tag: 27_lr=0.0079,momentum=0.8681
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 55.31
#   node_ip: 192.168.178.40
#   pid: 115025
#   time_since_restore: 45.96293902397156
#   time_this_iter_s: 45.96293902397156
#   time_total_s: 45.96293902397156
#   timestamp: 1661903821
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 537ee3be
#   warmup_time: 0.0022020339965820312
#
# (train_mnist pid=115830) {'lr': 0.0441737926118412, 'momentum': 0.5371295862626061}
# Result for train_mnist_70d7c0f2:
#   date: 2022-08-31_01-57-50
#   done: false
#   experiment_id: 6ccfb4dd0a9848f7b82cb6962a913e89
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 58.02
#   node_ip: 192.168.178.40
#   pid: 115830
#   time_since_restore: 46.36705708503723
#   time_this_iter_s: 46.36705708503723
#   time_total_s: 46.36705708503723
#   timestamp: 1661903870
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 70d7c0f2
#   warmup_time: 0.0027964115142822266
#
# Result for train_mnist_70d7c0f2:
#   date: 2022-08-31_01-57-50
#   done: true
#   experiment_id: 6ccfb4dd0a9848f7b82cb6962a913e89
#   experiment_tag: 28_lr=0.0442,momentum=0.5371
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 58.02
#   node_ip: 192.168.178.40
#   pid: 115830
#   time_since_restore: 46.36705708503723
#   time_this_iter_s: 46.36705708503723
#   time_total_s: 46.36705708503723
#   timestamp: 1661903870
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 70d7c0f2
#   warmup_time: 0.0027964115142822266
#
# (train_mnist pid=116648) {'lr': 0.07052625399416326, 'momentum': 0.8247569308746521}
# Result for train_mnist_8e2ed208:
#   date: 2022-08-31_01-58-38
#   done: false
#   experiment_id: 93ea8afe4844463a867832221be3e8fe
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 60.01
#   node_ip: 192.168.178.40
#   pid: 116648
#   time_since_restore: 45.25474572181702
#   time_this_iter_s: 45.25474572181702
#   time_total_s: 45.25474572181702
#   timestamp: 1661903918
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8e2ed208
#   warmup_time: 0.002776622772216797
#
# Result for train_mnist_8e2ed208:
#   date: 2022-08-31_01-58-38
#   done: true
#   experiment_id: 93ea8afe4844463a867832221be3e8fe
#   experiment_tag: 29_lr=0.0705,momentum=0.8248
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 60.01
#   node_ip: 192.168.178.40
#   pid: 116648
#   time_since_restore: 45.25474572181702
#   time_this_iter_s: 45.25474572181702
#   time_total_s: 45.25474572181702
#   timestamp: 1661903918
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 8e2ed208
#   warmup_time: 0.002776622772216797
#
# (train_mnist pid=117475) {'lr': 0.05311383161004084, 'momentum': 0.7547868808146412}
# Result for train_mnist_aacc9850:
#   date: 2022-08-31_01-59-27
#   done: false
#   experiment_id: 78742724cfdc434a95b2b6f2d28c48a0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 59.63
#   node_ip: 192.168.178.40
#   pid: 117475
#   time_since_restore: 45.862706661224365
#   time_this_iter_s: 45.862706661224365
#   time_total_s: 45.862706661224365
#   timestamp: 1661903967
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: aacc9850
#   warmup_time: 0.002252340316772461
#
# Result for train_mnist_aacc9850:
#   date: 2022-08-31_01-59-27
#   done: true
#   experiment_id: 78742724cfdc434a95b2b6f2d28c48a0
#   experiment_tag: 30_lr=0.0531,momentum=0.7548
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 59.63
#   node_ip: 192.168.178.40
#   pid: 117475
#   time_since_restore: 45.862706661224365
#   time_this_iter_s: 45.862706661224365
#   time_total_s: 45.862706661224365
#   timestamp: 1661903967
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: aacc9850
#   warmup_time: 0.002252340316772461
# 2022-08-31 01:59:27,471	INFO tune.py:758 -- Total run time: 1482.88 seconds (1482.19 seconds for the tuning loop).

# %%
print(analysis.get_best_result(metric="mean_accuracy", mode="max"))
print(analysis.get_best_result(metric="mean_accuracy", mode="max").config)
analysis.get_dataframe()
# Out:
# Result(metrics={'mean_accuracy': 61.36, 'done': True, 'trial_id': 'a26a36aa', 'experiment_tag': '21_lr=0.0531,momentum=0.7540'}, error=None, log_dir=PosixPath('/home/max/ray_results/train_mnist_2022-08-31_01-34-39/train_mnist_a26a36aa_21_lr=0.0531,momentum=0.7540_2022-08-31_01-51-15'))
# {'lr': 0.05309612987790999, 'momentum': 0.7539545167256022}
#     mean_accuracy  time_this_iter_s   done  timesteps_total  episodes_total  \
# 0           60.70         39.357823  False              NaN             NaN
# 1           58.71         47.012231  False              NaN             NaN
# 2           58.81         46.383714  False              NaN             NaN
# 3           55.28         46.767542  False              NaN             NaN
# 4           58.93         47.595483  False              NaN             NaN
# 5           51.00         47.775352  False              NaN             NaN
# 6           56.35         48.560475  False              NaN             NaN
# 7           54.03         47.453028  False              NaN             NaN
# 8           57.57         47.290463  False              NaN             NaN
# 9           58.18         46.510027  False              NaN             NaN
# 10          55.59         47.259244  False              NaN             NaN
# 11          56.13         46.515536  False              NaN             NaN
# 12          57.61         47.846685  False              NaN             NaN
# 13          57.67         47.245728  False              NaN             NaN
# 14          59.02         46.882422  False              NaN             NaN
# 15          56.92         46.684231  False              NaN             NaN
# 16          61.21         47.322070  False              NaN             NaN
# 17          59.80         47.222982  False              NaN             NaN
# 18          59.13         47.813375  False              NaN             NaN
# 19          60.61         46.700866  False              NaN             NaN
# 20          61.36         47.343008  False              NaN             NaN
# 21          55.63         47.276577  False              NaN             NaN
# 22          57.21         47.350035  False              NaN             NaN
# 23          51.51         46.887484  False              NaN             NaN
# 24          56.87         45.711302  False              NaN             NaN
# 25          59.64         46.800799  False              NaN             NaN
# 26          55.31         45.962939  False              NaN             NaN
# 27          58.02         46.367057  False              NaN             NaN
# 28          60.01         45.254746  False              NaN             NaN
# 29          59.63         45.862707  False              NaN             NaN
#
#     training_iteration  trial_id                     experiment_id  \
# 0                    1  544d74ca  f437961348ba4a5a919b4d10992263a7
# 1                    1  6d3c8458  97ccec76a144431cbd225ec79c2da1a9
# 2                    1  8ae4f5f8  523f6c1718194d528282be1751123ed5
# 3                    1  a82693d8  a6061dd12ef54db8b3d27112ec6d157a
# 4                    1  c5950c88  ebd18e8eb4204c8d9158fc00c4a1df93
# 5                    1  e35746c8  93b2d3c9a105418ea2033ece289e0237
# 6                    1  01372b40  ad40b2569f9f47e4bc17cdbf5410f437
# 7                    1  1f81a5b2  94792e79caa14997abec6bba4470652d
# 8                    1  3d3c2bcc  84af7e7993aa47c082059f48090a7029
# 9                    1  5af06c96  77f0ecec617b43679139966ed3a3128f
# 10                   1  78452f48  4a3ecaabe958450f9c752807c878aeb3
# 11                   1  95f3b3e8  58ccfe5e503345db9deb04e8d933c09e
# 12                   1  b34bcb56  717b0179b7164091bf9a8981e0a1a27f
# 13                   1  d1529382  307931a9d1c34334b6dc48a4f283309a
# 14                   1  ef57c262  dce365b0dbfb4856a69a51d7a9820f7a
# 15                   1  0cea19ba  9e472c6018df4f89bc31b0fd23e89993
# 16                   1  2a990188  66c4ed423ba64519b1626a120365a9f3
# 17                   1  48c4a734  31ddf99beefa47d5a7525515580f4820
# 18                   1  668b38b4  82204ca3caa446758abcfcbb32052a4f
# 19                   1  84b042da  755d98db5fe148cfac9182daea85a14f
# 20                   1  a26a36aa  2b42bb02779a4f2898500fff98e8a499
# 21                   1  c010d56a  392dc776a2e0424f8fb65d0e4582c3d7
# 22                   1  ddcd4066  0e1b0a13dbbc4f919f3982affbb818b6
# 23                   1  fbaa08b2  009e5c04904f47bdad337a585a925fb0
# 24                   1  19237d74  fa25a365d806455899db8a98b8d64928
# 25                   1  3634dc46  ed96ff779cf54ff3abf8842aacb40cfb
# 26                   1  537ee3be  023b5bcbbd1e4f14a28ec774b9eb714a
# 27                   1  70d7c0f2  6ccfb4dd0a9848f7b82cb6962a913e89
# 28                   1  8e2ed208  93ea8afe4844463a867832221be3e8fe
# 29                   1  aacc9850  78742724cfdc434a95b2b6f2d28c48a0
#
#                    date   timestamp  ...     pid           hostname  \
# 0   2022-08-31_01-35-26  1661902526  ...   92676  max-Latitude-5401
# 1   2022-08-31_01-36-16  1661902576  ...   93556  max-Latitude-5401
# 2   2022-08-31_01-37-05  1661902625  ...   94443  max-Latitude-5401
# 3   2022-08-31_01-37-55  1661902675  ...   95335  max-Latitude-5401
# 4   2022-08-31_01-38-45  1661902725  ...   96230  max-Latitude-5401
# 5   2022-08-31_01-39-35  1661902775  ...   97147  max-Latitude-5401
# 6   2022-08-31_01-40-26  1661902826  ...   98037  max-Latitude-5401
# 7   2022-08-31_01-41-15  1661902875  ...   98945  max-Latitude-5401
# 8   2022-08-31_01-42-05  1661902925  ...   99787  max-Latitude-5401
# 9   2022-08-31_01-42-54  1661902974  ...  100606  max-Latitude-5401
# 10  2022-08-31_01-43-44  1661903024  ...  101428  max-Latitude-5401
# 11  2022-08-31_01-44-34  1661903074  ...  102248  max-Latitude-5401
# 12  2022-08-31_01-45-24  1661903124  ...  103055  max-Latitude-5401
# 13  2022-08-31_01-46-14  1661903174  ...  104339  max-Latitude-5401
# 14  2022-08-31_01-47-04  1661903224  ...  105164  max-Latitude-5401
# 15  2022-08-31_01-47-54  1661903274  ...  105979  max-Latitude-5401
# 16  2022-08-31_01-48-44  1661903324  ...  106812  max-Latitude-5401
# 17  2022-08-31_01-49-34  1661903374  ...  107631  max-Latitude-5401
# 18  2022-08-31_01-50-25  1661903425  ...  108439  max-Latitude-5401
# 19  2022-08-31_01-51-15  1661903475  ...  109275  max-Latitude-5401
# 20  2022-08-31_01-52-04  1661903524  ...  110092  max-Latitude-5401
# 21  2022-08-31_01-52-54  1661903574  ...  110904  max-Latitude-5401
# 22  2022-08-31_01-53-44  1661903624  ...  111727  max-Latitude-5401
# 23  2022-08-31_01-54-34  1661903674  ...  112554  max-Latitude-5401
# 24  2022-08-31_01-55-23  1661903723  ...  113361  max-Latitude-5401
# 25  2022-08-31_01-56-12  1661903772  ...  114201  max-Latitude-5401
# 26  2022-08-31_01-57-01  1661903821  ...  115025  max-Latitude-5401
# 27  2022-08-31_01-57-50  1661903870  ...  115830  max-Latitude-5401
# 28  2022-08-31_01-58-38  1661903918  ...  116648  max-Latitude-5401
# 29  2022-08-31_01-59-27  1661903967  ...  117475  max-Latitude-5401
#
#            node_ip time_since_restore  timesteps_since_restore  \
# 0   192.168.178.40          39.357823                        0
# 1   192.168.178.40          47.012231                        0
# 2   192.168.178.40          46.383714                        0
# 3   192.168.178.40          46.767542                        0
# 4   192.168.178.40          47.595483                        0
# 5   192.168.178.40          47.775352                        0
# 6   192.168.178.40          48.560475                        0
# 7   192.168.178.40          47.453028                        0
# 8   192.168.178.40          47.290463                        0
# 9   192.168.178.40          46.510027                        0
# 10  192.168.178.40          47.259244                        0
# 11  192.168.178.40          46.515536                        0
# 12  192.168.178.40          47.846685                        0
# 13  192.168.178.40          47.245728                        0
# 14  192.168.178.40          46.882422                        0
# 15  192.168.178.40          46.684231                        0
# 16  192.168.178.40          47.322070                        0
# 17  192.168.178.40          47.222982                        0
# 18  192.168.178.40          47.813375                        0
# 19  192.168.178.40          46.700866                        0
# 20  192.168.178.40          47.343008                        0
# 21  192.168.178.40          47.276577                        0
# 22  192.168.178.40          47.350035                        0
# 23  192.168.178.40          46.887484                        0
# 24  192.168.178.40          45.711302                        0
# 25  192.168.178.40          46.800799                        0
# 26  192.168.178.40          45.962939                        0
# 27  192.168.178.40          46.367057                        0
# 28  192.168.178.40          45.254746                        0
# 29  192.168.178.40          45.862707                        0
#
#     iterations_since_restore  warmup_time  config/lr  config/momentum  \
# 0                          1     0.002721   0.073122         0.800807
# 1                          1     0.002213   0.095266         0.571587
# 2                          1     0.002062   0.080929         0.681607
# 3                          1     0.002105   0.019469         0.629576
# 4                          1     0.002391   0.063346         0.516280
# 5                          1     0.002074   0.094776         0.952159
# 6                          1     0.002310   0.055463         0.598504
# 7                          1     0.002710   0.023971         0.501183
# 8                          1     0.002160   0.023379         0.687672
# 9                          1     0.002199   0.045822         0.623040
# 10                         1     0.002157   0.027519         0.570504
# 11                         1     0.002059   0.006530         0.876757
# 12                         1     0.002290   0.014069         0.882075
# 13                         1     0.002407   0.026953         0.847775
# 14                         1     0.002255   0.023612         0.888012
# 15                         1     0.002403   0.034227         0.530184
# 16                         1     0.002386   0.070750         0.824101
# 17                         1     0.002102   0.100000         0.820472
# 18                         1     0.002297   0.074900         0.860060
# 19                         1     0.002438   0.037979         0.794896
# 20                         1     0.002045   0.053096         0.753955
# 21                         1     0.002206   0.013901         0.754366
# 22                         1     0.002162   0.081052         0.681603
# 23                         1     0.002218   0.074152         0.956684
# 24                         1     0.002234   0.090648         0.788265
# 25                         1     0.002722   0.072755         0.801252
# 26                         1     0.002202   0.007948         0.868109
# 27                         1     0.002796   0.044174         0.537130
# 28                         1     0.002777   0.070526         0.824757
# 29                         1     0.002252   0.053114         0.754787
#
#                                                logdir
# 0   /home/max/ray_results/train_mnist_2022-08-31_0...
# 1   /home/max/ray_results/train_mnist_2022-08-31_0...
# 2   /home/max/ray_results/train_mnist_2022-08-31_0...
# 3   /home/max/ray_results/train_mnist_2022-08-31_0...
# 4   /home/max/ray_results/train_mnist_2022-08-31_0...
# 5   /home/max/ray_results/train_mnist_2022-08-31_0...
# 6   /home/max/ray_results/train_mnist_2022-08-31_0...
# 7   /home/max/ray_results/train_mnist_2022-08-31_0...
# 8   /home/max/ray_results/train_mnist_2022-08-31_0...
# 9   /home/max/ray_results/train_mnist_2022-08-31_0...
# 10  /home/max/ray_results/train_mnist_2022-08-31_0...
# 11  /home/max/ray_results/train_mnist_2022-08-31_0...
# 12  /home/max/ray_results/train_mnist_2022-08-31_0...
# 13  /home/max/ray_results/train_mnist_2022-08-31_0...
# 14  /home/max/ray_results/train_mnist_2022-08-31_0...
# 15  /home/max/ray_results/train_mnist_2022-08-31_0...
# 16  /home/max/ray_results/train_mnist_2022-08-31_0...
# 17  /home/max/ray_results/train_mnist_2022-08-31_0...
# 18  /home/max/ray_results/train_mnist_2022-08-31_0...
# 19  /home/max/ray_results/train_mnist_2022-08-31_0...
# 20  /home/max/ray_results/train_mnist_2022-08-31_0...
# 21  /home/max/ray_results/train_mnist_2022-08-31_0...
# 22  /home/max/ray_results/train_mnist_2022-08-31_0...
# 23  /home/max/ray_results/train_mnist_2022-08-31_0...
# 24  /home/max/ray_results/train_mnist_2022-08-31_0...
# 25  /home/max/ray_results/train_mnist_2022-08-31_0...
# 26  /home/max/ray_results/train_mnist_2022-08-31_0...
# 27  /home/max/ray_results/train_mnist_2022-08-31_0...
# 28  /home/max/ray_results/train_mnist_2022-08-31_0...
# 29  /home/max/ray_results/train_mnist_2022-08-31_0...
#
# [30 rows x 21 columns]

# %%
from Models import LeNet
#input_shape = (batch_size, 1, 28, 28)
criterion = CrossEntropyLoss()

def train_mnist(config):
    test_device = "cpu"
    model = LeNet(input_shape, 10, initial_lr=config["lr"], momentum=config["momentum"], weight_decay=config["weight_decay"]).to(test_device)
    for i in range(2):
        train_NN(model, criterion, train_dataloader,
        test_dataloader, epochs=2, batches_to_test=100,patience=2,device=test_device, print_test=False, verbose=False)
        acc = test_loss(model, test_dataloader, criterion, test_device)[1]
        tune.report(mean_accuracy=acc)

analysis = tune.run(
    train_mnist, config={"lr": tune.grid_search([0.001, 0.01, 0.1]), "momentum": tune.grid_search([0.9, 0.99]), "weight_decay": tune.grid_search([0, 0.01, 0.1])})

print("Best config: ", analysis.get_best_config(metric="mean_accuracy", mode="max",))

# Get a dataframe for analyzing trial results.
df = analysis.dataframe()
# Out:
# == Status ==<br>Current time: 2022-08-30 13:00:00 (running for 00:00:35.23)<br>Memory usage on this node: 14.0/15.4 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.<br>Using FIFO scheduling algorithm.<br>Resources requested: 8.0/12 CPUs, 0/1 GPUs, 0.0/2.47 GiB heap, 0.0/1.24 GiB objects (0.0/1.0 accelerator_type:G)<br>Result logdir: /home/max/ray_results/train_mnist_2022-08-30_12-59-24<br>Number of trials: 18/18 (1 ERROR, 10 PENDING, 7 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name             </th><th>status  </th><th>loc  </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">  weight_decay</th></tr>
# </thead>
# <tbody>
# <tr><td>train_mnist_ced3b_00001</td><td>RUNNING </td><td>     </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0   </td></tr>
# <tr><td>train_mnist_ced3b_00002</td><td>RUNNING </td><td>     </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0   </td></tr>
# <tr><td>train_mnist_ced3b_00003</td><td>RUNNING </td><td>     </td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0   </td></tr>
# <tr><td>train_mnist_ced3b_00004</td><td>RUNNING </td><td>     </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0   </td></tr>
# <tr><td>train_mnist_ced3b_00005</td><td>RUNNING </td><td>     </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0   </td></tr>
# <tr><td>train_mnist_ced3b_00006</td><td>RUNNING </td><td>     </td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.01</td></tr>
# <tr><td>train_mnist_ced3b_00007</td><td>RUNNING </td><td>     </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.01</td></tr>
# <tr><td>train_mnist_ced3b_00008</td><td>PENDING </td><td>     </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.01</td></tr>
# <tr><td>train_mnist_ced3b_00009</td><td>PENDING </td><td>     </td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.01</td></tr>
# <tr><td>train_mnist_ced3b_00010</td><td>PENDING </td><td>     </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.01</td></tr>
# <tr><td>train_mnist_ced3b_00011</td><td>PENDING </td><td>     </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.01</td></tr>
# <tr><td>train_mnist_ced3b_00012</td><td>PENDING </td><td>     </td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.1 </td></tr>
# <tr><td>train_mnist_ced3b_00013</td><td>PENDING </td><td>     </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.1 </td></tr>
# <tr><td>train_mnist_ced3b_00014</td><td>PENDING </td><td>     </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.1 </td></tr>
# <tr><td>train_mnist_ced3b_00015</td><td>PENDING </td><td>     </td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.1 </td></tr>
# <tr><td>train_mnist_ced3b_00016</td><td>PENDING </td><td>     </td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.1 </td></tr>
# <tr><td>train_mnist_ced3b_00017</td><td>PENDING </td><td>     </td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.1 </td></tr>
# <tr><td>train_mnist_ced3b_00000</td><td>ERROR   </td><td>     </td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0   </td></tr>
# </tbody>
# </table><br>Number of errored trials: 1<br><table>
# <thead>
# <tr><th>Trial name             </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                                                            </th></tr>
# </thead>
# <tbody>
# <tr><td>train_mnist_ced3b_00000</td><td style="text-align: right;">           1</td><td>/home/max/ray_results/train_mnist_2022-08-30_12-59-24/train_mnist_ced3b_00000_0_lr=0.0010,momentum=0.9000,weight_decay=0_2022-08-30_12-59-46/error.txt</td></tr>
# </tbody>
# </table><br>
# 2022-08-30 12:59:47,080	ERROR ray_trial_executor.py:562 -- Trial train_mnist_ced3b_00000: Unexpected error starting runner.
# Traceback (most recent call last):
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/tune/execution/ray_trial_executor.py", line 555, in start_trial
#     return self._start_trial(trial)
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/tune/execution/ray_trial_executor.py", line 458, in _start_trial
#     runner = self._setup_remote_runner(trial)
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/tune/execution/ray_trial_executor.py", line 399, in _setup_remote_runner
#     return full_actor_class.remote(**kwargs)
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/actor.py", line 637, in remote
#     return actor_cls._remote(args=args, kwargs=kwargs, **updated_options)
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/util/tracing/tracing_helper.py", line 387, in _invocation_actor_class_remote_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/actor.py", line 844, in _remote
#     worker.function_actor_manager.export_actor_class(
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 479, in export_actor_class
#     check_oversized_function(
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 729, in check_oversized_function
#     raise ValueError(error)
# ValueError: The actor ImplicitFunc is too large (175 MiB > FUNCTION_SIZE_ERROR_THRESHOLD=95 MiB). Check that its definition is not implicitly capturing a large array or other object in scope. Tip: use ray.put() to put large objects in the Ray object store.
# 2022-08-30 12:59:49,114	WARNING util.py:220 -- The `start_trial` operation took 3.064 s, which may be a performance bottleneck.
# 2022-08-30 12:59:51,480	WARNING util.py:220 -- The `start_trial` operation took 0.998 s, which may be a performance bottleneck.
# 2022-08-30 12:59:52,290	WARNING worker.py:1829 -- Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
#     actor_class = self._load_actor_class_from_gcs(
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
#     class_name = ensure_str(class_name)
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
#     assert isinstance(s, bytes)
# AssertionError
# An unexpected internal error occurred while the worker was executing a task.
# (pid=84287) 2022-08-30 12:59:52,286	ERROR worker.py:756 -- Worker exits with an exit code None.
# (pid=84287)  Traceback (most recent call last):
# (pid=84287)   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
# (pid=84287)   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
# (pid=84287)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
# (pid=84287)     actor_class = self._load_actor_class_from_gcs(
# (pid=84287)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
# (pid=84287)     class_name = ensure_str(class_name)
# (pid=84287)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
# (pid=84287)     assert isinstance(s, bytes)
# (pid=84287) AssertionError
# (pid=84287) An unexpected internal error occurred while the worker was executing a task.
# (pid=84287) Traceback (most recent call last):
# (pid=84287)   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
# (pid=84287)   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
# (pid=84287)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
# (pid=84287)     actor_class = self._load_actor_class_from_gcs(
# (pid=84287)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
# (pid=84287)     class_name = ensure_str(class_name)
# (pid=84287)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
# (pid=84287)     assert isinstance(s, bytes)
# (pid=84287) AssertionError
# (pid=84287)
# (pid=84287) During handling of the above exception, another exception occurred:
# (pid=84287)
# (pid=84287) Traceback (most recent call last):
# (pid=84287)   File "python/ray/_raylet.pyx", line 837, in ray._raylet.task_execution_handler
# (pid=84287) SystemExit
# 2022-08-30 12:59:52,374	WARNING worker.py:1829 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: ffffffffffffffffccafac0b39aa284c289c04ca01000000 Worker ID: ba623f5f0e21c2d4076da35f9867b37070be8707bf42a2351a9ae256 Node ID: 45b74ae556532644d6bfb9a681d32b80aa99d18de1cbbf3c36d85e46 Worker IP address: 129.206.61.139 Worker port: 40281 Worker PID: 84287 Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None.
#  Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
#     actor_class = self._load_actor_class_from_gcs(
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
#     class_name = ensure_str(class_name)
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
#     assert isinstance(s, bytes)
# AssertionError
# An unexpected internal error occurred while the worker was executing a task.
# 2022-08-30 12:59:53,827	WARNING util.py:220 -- The `start_trial` operation took 0.982 s, which may be a performance bottleneck.
# (pid=84324) 2022-08-30 12:59:54,685	ERROR worker.py:756 -- Worker exits with an exit code None.
# (pid=84324)  Traceback (most recent call last):
# (pid=84324)   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
# (pid=84324)   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
# (pid=84324)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
# (pid=84324)     actor_class = self._load_actor_class_from_gcs(
# (pid=84324)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
# (pid=84324)     class_name = ensure_str(class_name)
# (pid=84324)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
# (pid=84324)     assert isinstance(s, bytes)
# (pid=84324) AssertionError
# (pid=84324) An unexpected internal error occurred while the worker was executing a task.
# (pid=84324) Traceback (most recent call last):
# (pid=84324)   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
# (pid=84324)   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
# (pid=84324)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
# (pid=84324)     actor_class = self._load_actor_class_from_gcs(
# (pid=84324)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
# (pid=84324)     class_name = ensure_str(class_name)2022-08-30 12:59:54,752	WARNING worker.py:1829 -- Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
#     actor_class = self._load_actor_class_from_gcs(
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
#     class_name = ensure_str(class_name)
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
#     assert isinstance(s, bytes)
# AssertionError
# An unexpected internal error occurred while the worker was executing a task.
#
# (pid=84324)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
# (pid=84324)     assert isinstance(s, bytes)
# (pid=84324) AssertionError
# (pid=84324)
# (pid=84324) During handling of the above exception, another exception occurred:
# (pid=84324)
# (pid=84324) Traceback (most recent call last):
# (pid=84324)   File "python/ray/_raylet.pyx", line 837, in ray._raylet.task_execution_handler
# (pid=84324) SystemExit
# 2022-08-30 12:59:54,767	WARNING worker.py:1829 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: fffffffffffffffff7270519ce95db7d117db6a201000000 Worker ID: 7b901ae879967276c67f252a67bbc1ccae5395ee9607a41dddabf906 Node ID: 45b74ae556532644d6bfb9a681d32b80aa99d18de1cbbf3c36d85e46 Worker IP address: 129.206.61.139 Worker port: 35379 Worker PID: 84324 Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None.
#  Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
#     actor_class = self._load_actor_class_from_gcs(
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
#     class_name = ensure_str(class_name)
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
#     assert isinstance(s, bytes)
# AssertionError
# An unexpected internal error occurred while the worker was executing a task.
# 2022-08-30 12:59:54,770	WARNING util.py:220 -- The `start_trial` operation took 0.942 s, which may be a performance bottleneck.
# 2022-08-30 12:59:55,530	WARNING worker.py:1829 -- Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
#     actor_class = self._load_actor_class_from_gcs(
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
#     class_name = ensure_str(class_name)
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
#     assert isinstance(s, bytes)
# AssertionError
# An unexpected internal error occurred while the worker was executing a task.
# 2022-08-30 12:59:55,532	WARNING worker.py:1829 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: ffffffffffffffffd703fb01ea89818fd33e471201000000 Worker ID: 136610da61e64043b3ebed8db25e7c5b993b0a39aa669a7cc27ccc94 Node ID: 45b74ae556532644d6bfb9a681d32b80aa99d18de1cbbf3c36d85e46 Worker IP address: 129.206.61.139 Worker port: 36861 Worker PID: 84357 Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None.
#  Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
#     actor_class = self._load_actor_class_from_gcs(
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
#     class_name = ensure_str(class_name)
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
#     assert isinstance(s, bytes)
# AssertionError
# An unexpected internal error occurred while the worker was executing a task.
# (pid=84357) 2022-08-30 12:59:55,530	ERROR worker.py:756 -- Worker exits with an exit code None.
# (pid=84357)  Traceback (most recent call last):
# (pid=84357)   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
# (pid=84357)   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
# (pid=84357)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
# (pid=84357)     actor_class = self._load_actor_class_from_gcs(
# (pid=84357)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
# (pid=84357)     class_name = ensure_str(class_name)
# (pid=84357)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
# (pid=84357)     assert isinstance(s, bytes)
# (pid=84357) AssertionError
# (pid=84357) An unexpected internal error occurred while the worker was executing a task.
# (pid=84357) Traceback (most recent call last):
# (pid=84357)   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
# (pid=84357)   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
# (pid=84357)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
# (pid=84357)     actor_class = self._load_actor_class_from_gcs(
# (pid=84357)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
# (pid=84357)     class_name = ensure_str(class_name)
# (pid=84357)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
# (pid=84357)     assert isinstance(s, bytes)
# (pid=84357) AssertionError
# (pid=84357)
# (pid=84357) During handling of the above exception, another exception occurred:
# (pid=84357)
# (pid=84357) Traceback (most recent call last):
# (pid=84357)   File "python/ray/_raylet.pyx", line 837, in ray._raylet.task_execution_handler
# (pid=84357) SystemExit
# 2022-08-30 12:59:56,512	WARNING util.py:220 -- The `start_trial` operation took 0.976 s, which may be a performance bottleneck.
# 2022-08-30 12:59:57,485	WARNING worker.py:1829 -- Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
#     actor_class = self._load_actor_class_from_gcs(
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
#     class_name = ensure_str(class_name)
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
#     assert isinstance(s, bytes)
# AssertionError
# An unexpected internal error occurred while the worker was executing a task.
# (pid=84387) 2022-08-30 12:59:57,436	ERROR worker.py:756 -- Worker exits with an exit code None.
# (pid=84387)  Traceback (most recent call last):
# (pid=84387)   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
# (pid=84387)   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
# (pid=84387)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
# (pid=84387)     actor_class = self._load_actor_class_from_gcs(
# (pid=84387)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
# (pid=84387)     class_name = ensure_str(class_name)
# (pid=84387)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
# (pid=84387)     assert isinstance(s, bytes)
# (pid=84387) AssertionError
# (pid=84387) An unexpected internal error occurred while the worker was executing a task.
# (pid=84387) Traceback (most recent call last):
# (pid=84387)   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
# (pid=84387)   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
# (pid=84387)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
# (pid=84387)     actor_class = self._load_actor_class_from_gcs(
# (pid=84387)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
# (pid=84387)     class_name = ensure_str(class_name)
# (pid=84387)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
# (pid=84387)     assert isinstance(s, bytes)
# (pid=84387) AssertionError
# (pid=84387)
# (pid=84387) During handling of the above exception, another exception occurred:
# (pid=84387)
# (pid=84387) Traceback (most recent call last):
# (pid=84387)   File "python/ray/_raylet.pyx", line 837, in ray._raylet.task_execution_handler
# (pid=84387) SystemExit
# 2022-08-30 12:59:57,574	WARNING worker.py:1829 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: ffffffffffffffffa939a503f9a354fe1f365a8201000000 Worker ID: 4e70c0303446318a42e11c777f2edf0a75db1b7da4a7d6a842dd0024 Node ID: 45b74ae556532644d6bfb9a681d32b80aa99d18de1cbbf3c36d85e46 Worker IP address: 129.206.61.139 Worker port: 44853 Worker PID: 84387 Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None.
#  Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
#     actor_class = self._load_actor_class_from_gcs(
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
#     class_name = ensure_str(class_name)
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
#     assert isinstance(s, bytes)
# AssertionError
# An unexpected internal error occurred while the worker was executing a task.
# 2022-08-30 12:59:57,578	WARNING util.py:220 -- The `start_trial` operation took 1.064 s, which may be a performance bottleneck.
# 2022-08-30 12:59:58,553	WARNING worker.py:1829 -- Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
#     actor_class = self._load_actor_class_from_gcs(
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
#     class_name = ensure_str(class_name)
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
#     assert isinstance(s, bytes)
# AssertionError
# An unexpected internal error occurred while the worker was executing a task.
# (pid=84416) 2022-08-30 12:59:58,427	ERROR worker.py:756 -- Worker exits with an exit code None.
# (pid=84416)  Traceback (most recent call last):
# (pid=84416)   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
# (pid=84416)   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
# (pid=84416)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
# (pid=84416)     actor_class = self._load_actor_class_from_gcs(
# (pid=84416)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
# (pid=84416)     class_name = ensure_str(class_name)
# (pid=84416)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
# (pid=84416)     assert isinstance(s, bytes)
# (pid=84416) AssertionError
# (pid=84416) An unexpected internal error occurred while the worker was executing a task.
# (pid=84416) Traceback (most recent call last):
# (pid=84416)   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
# (pid=84416)   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
# (pid=84416)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
# (pid=84416)     actor_class = self._load_actor_class_from_gcs(
# (pid=84416)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
# (pid=84416)     class_name = ensure_str(class_name)
# (pid=84416)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
# (pid=84416)     assert isinstance(s, bytes)
# (pid=84416) AssertionError
# (pid=84416)
# (pid=84416) During handling of the above exception, another exception occurred:
# (pid=84416)
# (pid=84416) Traceback (most recent call last):
# (pid=84416)   File "python/ray/_raylet.pyx", line 837, in ray._raylet.task_execution_handler
# (pid=84416) SystemExit
# 2022-08-30 12:59:58,572	WARNING worker.py:1829 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: ffffffffffffffff42363627470a0174d6c4cb7201000000 Worker ID: d9c582bbd403de6537e8747b3cbccebc50f4cafe04ec8a1f6ecb090a Node ID: 45b74ae556532644d6bfb9a681d32b80aa99d18de1cbbf3c36d85e46 Worker IP address: 129.206.61.139 Worker port: 33009 Worker PID: 84416 Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None.
#  Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
#     actor_class = self._load_actor_class_from_gcs(
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
#     class_name = ensure_str(class_name)
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
#     assert isinstance(s, bytes)
# AssertionError
# An unexpected internal error occurred while the worker was executing a task.
# 2022-08-30 12:59:58,575	WARNING util.py:220 -- The `start_trial` operation took 0.996 s, which may be a performance bottleneck.
# 2022-08-30 12:59:59,441	WARNING worker.py:1829 -- Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
#     actor_class = self._load_actor_class_from_gcs(
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
#     class_name = ensure_str(class_name)
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
#     assert isinstance(s, bytes)
# AssertionError
# An unexpected internal error occurred while the worker was executing a task.
# (pid=84443) 2022-08-30 12:59:59,379	ERROR worker.py:756 -- Worker exits with an exit code None.
# (pid=84443)  Traceback (most recent call last):
# (pid=84443)   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
# (pid=84443)   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
# (pid=84443)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
# (pid=84443)     actor_class = self._load_actor_class_from_gcs(
# (pid=84443)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
# (pid=84443)     class_name = ensure_str(class_name)
# (pid=84443)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
# (pid=84443)     assert isinstance(s, bytes)
# (pid=84443) AssertionError
# (pid=84443) An unexpected internal error occurred while the worker was executing a task.
# (pid=84443) Traceback (most recent call last):
# (pid=84443)   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
# (pid=84443)   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
# (pid=84443)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
# (pid=84443)     actor_class = self._load_actor_class_from_gcs(
# (pid=84443)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
# (pid=84443)     class_name = ensure_str(class_name)
# (pid=84443)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
# (pid=84443)     assert isinstance(s, bytes)
# (pid=84443) AssertionError
# (pid=84443)
# (pid=84443) During handling of the above exception, another exception occurred:
# (pid=84443)
# (pid=84443) Traceback (most recent call last):
# (pid=84443)   File "python/ray/_raylet.pyx", line 837, in ray._raylet.task_execution_handler
# (pid=84443) SystemExit
# 2022-08-30 12:59:59,441	WARNING tune.py:686 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# 2022-08-30 12:59:59,444	WARNING worker.py:1829 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: ffffffffffffffff6eb14606959a1462e6d2432701000000 Worker ID: ce21b70d3014d97450895ffe4955c5f22f59c9202b817d3c5a63a1fd Node ID: 45b74ae556532644d6bfb9a681d32b80aa99d18de1cbbf3c36d85e46 Worker IP address: 129.206.61.139 Worker port: 37973 Worker PID: 84443 Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None.
#  Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
#     actor_class = self._load_actor_class_from_gcs(
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
#     class_name = ensure_str(class_name)
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
#     assert isinstance(s, bytes)
# AssertionError
# An unexpected internal error occurred while the worker was executing a task.
# 2022-08-30 12:59:59,565	WARNING util.py:220 -- The `start_trial` operation took 0.990 s, which may be a performance bottleneck.
# 2022-08-30 13:00:00,270	WARNING worker.py:1829 -- Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
#     actor_class = self._load_actor_class_from_gcs(
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
#     class_name = ensure_str(class_name)
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
#     assert isinstance(s, bytes)
# AssertionError
# An unexpected internal error occurred while the worker was executing a task.
# 2022-08-30 13:00:00,271	WARNING worker.py:1829 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: ffffffffffffffffb3dfbd816f9d2c2f7f7ebf6101000000 Worker ID: 11a0438cd791897923e0210aa2e9da8332248ca38ffe922854435224 Node ID: 45b74ae556532644d6bfb9a681d32b80aa99d18de1cbbf3c36d85e46 Worker IP address: 129.206.61.139 Worker port: 35713 Worker PID: 84481 Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None.
#  Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
#     actor_class = self._load_actor_class_from_gcs(
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
#     class_name = ensure_str(class_name)
#   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
#     assert isinstance(s, bytes)
# AssertionError
# An unexpected internal error occurred while the worker was executing a task.
# (pid=84481) 2022-08-30 13:00:00,269	ERROR worker.py:756 -- Worker exits with an exit code None.
# (pid=84481)  Traceback (most recent call last):
# (pid=84481)   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
# (pid=84481)   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
# (pid=84481)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
# (pid=84481)     actor_class = self._load_actor_class_from_gcs(
# (pid=84481)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
# (pid=84481)     class_name = ensure_str(class_name)
# (pid=84481)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
# (pid=84481)     assert isinstance(s, bytes)
# (pid=84481) AssertionError
# (pid=84481) An unexpected internal error occurred while the worker was executing a task.
# (pid=84481) Traceback (most recent call last):
# (pid=84481)   File "python/ray/_raylet.pyx", line 804, in ray._raylet.task_execution_handler
# (pid=84481)   File "python/ray/_raylet.pyx", line 535, in ray._raylet.execute_task
# (pid=84481)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 522, in load_actor_class
# (pid=84481)     actor_class = self._load_actor_class_from_gcs(
# (pid=84481)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/function_manager.py", line 617, in _load_actor_class_from_gcs
# (pid=84481)     class_name = ensure_str(class_name)
# (pid=84481)   File "/home/max/anaconda3/lib/python3.9/site-packages/ray/_private/utils.py", line 285, in ensure_str
# (pid=84481)     assert isinstance(s, bytes)
# (pid=84481) AssertionError
# (pid=84481)
# (pid=84481) During handling of the above exception, another exception occurred:
# (pid=84481)
# (pid=84481) Traceback (most recent call last):
# (pid=84481)   File "python/ray/_raylet.pyx", line 837, in ray._raylet.task_execution_handler
# (pid=84481) SystemExit
# 2022-08-30 13:00:00,492	ERROR tune.py:754 -- Trials did not complete: [train_mnist_ced3b_00000, train_mnist_ced3b_00001, train_mnist_ced3b_00002, train_mnist_ced3b_00003, train_mnist_ced3b_00004, train_mnist_ced3b_00005, train_mnist_ced3b_00006, train_mnist_ced3b_00007, train_mnist_ced3b_00008, train_mnist_ced3b_00009, train_mnist_ced3b_00010, train_mnist_ced3b_00011, train_mnist_ced3b_00012, train_mnist_ced3b_00013, train_mnist_ced3b_00014, train_mnist_ced3b_00015, train_mnist_ced3b_00016, train_mnist_ced3b_00017]
# 2022-08-30 13:00:00,493	INFO tune.py:758 -- Total run time: 39.08 seconds (34.53 seconds for the tuning loop).
# 2022-08-30 13:00:00,493	WARNING tune.py:764 -- Experiment has been interrupted, but the most recent state was saved. You can continue running this experiment by passing `resume=True` to `tune.run()`
# 2022-08-30 13:00:00,498	WARNING experiment_analysis.py:627 -- Could not find best trial. Did you pass the correct `metric` parameter?
# 2022-08-30 13:00:00,499	WARNING experiment_analysis.py:542 -- Couldn't read config from 11 paths
# Best config:  None
