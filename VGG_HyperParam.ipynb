# %%
import numpy as np
import matplotlib.pyplot as plt
import json

import torch
from torch.nn import CrossEntropyLoss, NLLLoss
import torch.optim as optim

import torchvision
import torchvision.transforms as transforms

from torchinfo import summary

from os.path import exists

from util import test_loss, train_NN

from ray import tune
from ray.tune.search.bayesopt import BayesOptSearch

# %%
if torch.cuda.is_available():
    device = 'cuda'
else:
    device = 'cpu'
print(device)
# Out:
# cuda

# %%
batch_size = 100

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_dataset = torchvision.datasets.CIFAR10(root='./data/CIFAR10', train=True,
                                        download=True, transform=transform)
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

test_dataset = torchvision.datasets.CIFAR10(root='./data/CIFAR10', train=False,
                                       download=True, transform=transform)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

input_shape = (batch_size, 3, 32, 32)
num_labels = 10
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
from Models import LeNet
input_shape = (batch_size, 1, 28, 28)
criterion = CrossEntropyLoss()

def train_mnist(config):
    test_device = "cpu"
    model = LeNet(input_shape, 10, initial_lr=config["lr"], momentum=config["momentum"], weight_decay=config["weight_decay"]).to(test_device)
    for i in range(2):
        train_NN(model, criterion, train_dataloader,
        test_dataloader, epochs=2, batches_to_test=100,patience=2,device=test_device, print_test=False, verbose=False)
        acc = test_loss(model, test_dataloader, criterion, test_device)[1]
        tune.report(mean_accuracy=acc)

analysis = tune.run(
    train_mnist, config={"lr": tune.grid_search([0.001, 0.01, 0.1]), "momentum": tune.grid_search([0.9, 0.99]), "weight_decay": tune.grid_search([0, 0.01, 0.1])})

print("Best config: ", analysis.get_best_config(metric="mean_accuracy", mode="max",))

# Get a dataframe for analyzing trial results.
df = analysis.dataframe()
# Out:
# == Status ==<br>Current time: 2022-08-29 15:07:06 (running for 00:11:45.68)<br>Memory usage on this node: 8.4/15.4 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/5.55 GiB heap, 0.0/2.78 GiB objects (0.0/1.0 accelerator_type:G)<br>Result logdir: /home/max/ray_results/train_mnist_2022-08-29_14-55-20<br>Number of trials: 18/18 (18 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name             </th><th>status    </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">  weight_decay</th><th style="text-align: right;">  acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>train_mnist_d6d05_00000</td><td>TERMINATED</td><td>147.142.68.85:96840</td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0   </td><td style="text-align: right;">95.77</td><td style="text-align: right;">     2</td><td style="text-align: right;">         430.805</td></tr>
# <tr><td>train_mnist_d6d05_00001</td><td>TERMINATED</td><td>147.142.68.85:96891</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0   </td><td style="text-align: right;">94.67</td><td style="text-align: right;">     2</td><td style="text-align: right;">         444.224</td></tr>
# <tr><td>train_mnist_d6d05_00002</td><td>TERMINATED</td><td>147.142.68.85:96898</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0   </td><td style="text-align: right;">99.07</td><td style="text-align: right;">     2</td><td style="text-align: right;">         444.087</td></tr>
# <tr><td>train_mnist_d6d05_00003</td><td>TERMINATED</td><td>147.142.68.85:96920</td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0   </td><td style="text-align: right;">98.35</td><td style="text-align: right;">     2</td><td style="text-align: right;">         450.634</td></tr>
# <tr><td>train_mnist_d6d05_00004</td><td>TERMINATED</td><td>147.142.68.85:96922</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0   </td><td style="text-align: right;">98.67</td><td style="text-align: right;">     2</td><td style="text-align: right;">         438.771</td></tr>
# <tr><td>train_mnist_d6d05_00005</td><td>TERMINATED</td><td>147.142.68.85:96962</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0   </td><td style="text-align: right;">30.74</td><td style="text-align: right;">     2</td><td style="text-align: right;">         444.898</td></tr>
# <tr><td>train_mnist_d6d05_00006</td><td>TERMINATED</td><td>147.142.68.85:97124</td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.01</td><td style="text-align: right;">96.17</td><td style="text-align: right;">     2</td><td style="text-align: right;">         461.305</td></tr>
# <tr><td>train_mnist_d6d05_00007</td><td>TERMINATED</td><td>147.142.68.85:97127</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.01</td><td style="text-align: right;">93.32</td><td style="text-align: right;">     2</td><td style="text-align: right;">         460.013</td></tr>
# <tr><td>train_mnist_d6d05_00008</td><td>TERMINATED</td><td>147.142.68.85:97310</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.01</td><td style="text-align: right;">97.27</td><td style="text-align: right;">     2</td><td style="text-align: right;">         455.669</td></tr>
# <tr><td>train_mnist_d6d05_00009</td><td>TERMINATED</td><td>147.142.68.85:97393</td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.01</td><td style="text-align: right;">95.66</td><td style="text-align: right;">     2</td><td style="text-align: right;">         457.808</td></tr>
# <tr><td>train_mnist_d6d05_00010</td><td>TERMINATED</td><td>147.142.68.85:97540</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.01</td><td style="text-align: right;">93.16</td><td style="text-align: right;">     2</td><td style="text-align: right;">         455.011</td></tr>
# <tr><td>train_mnist_d6d05_00011</td><td>TERMINATED</td><td>147.142.68.85:97622</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.01</td><td style="text-align: right;">90.6 </td><td style="text-align: right;">     2</td><td style="text-align: right;">         450.983</td></tr>
# <tr><td>train_mnist_d6d05_00012</td><td>TERMINATED</td><td>147.142.68.85:96840</td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.1 </td><td style="text-align: right;">79.84</td><td style="text-align: right;">     2</td><td style="text-align: right;">         251.329</td></tr>
# <tr><td>train_mnist_d6d05_00013</td><td>TERMINATED</td><td>147.142.68.85:96922</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.1 </td><td style="text-align: right;">88.69</td><td style="text-align: right;">     2</td><td style="text-align: right;">         241.357</td></tr>
# <tr><td>train_mnist_d6d05_00014</td><td>TERMINATED</td><td>147.142.68.85:96891</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.1 </td><td style="text-align: right;">67.1 </td><td style="text-align: right;">     2</td><td style="text-align: right;">         246.923</td></tr>
# <tr><td>train_mnist_d6d05_00015</td><td>TERMINATED</td><td>147.142.68.85:96898</td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.1 </td><td style="text-align: right;">76.32</td><td style="text-align: right;">     2</td><td style="text-align: right;">         243.662</td></tr>
# <tr><td>train_mnist_d6d05_00016</td><td>TERMINATED</td><td>147.142.68.85:96962</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.1 </td><td style="text-align: right;">62.91</td><td style="text-align: right;">     2</td><td style="text-align: right;">         241.595</td></tr>
# <tr><td>train_mnist_d6d05_00017</td><td>TERMINATED</td><td>147.142.68.85:96920</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.1 </td><td style="text-align: right;">61.59</td><td style="text-align: right;">     2</td><td style="text-align: right;">         237.789</td></tr>
# </tbody>
# </table><br><br>
# 2022-08-29 14:55:29,402	WARNING worker.py:1829 -- Warning: The actor ImplicitFunc is very large (52 MiB). Check that its definition is not implicitly capturing a large array or other object in scope. Tip: use ray.put() to put large objects in the Ray object store.
# 2022-08-29 14:55:29,523	WARNING util.py:220 -- The `start_trial` operation took 0.875 s, which may be a performance bottleneck.
# 2022-08-29 14:55:39,059	WARNING util.py:220 -- The `start_trial` operation took 0.712 s, which may be a performance bottleneck.
# 2022-08-29 14:55:39,790	WARNING util.py:220 -- The `start_trial` operation took 0.728 s, which may be a performance bottleneck.
# 2022-08-29 14:55:45,867	WARNING util.py:220 -- The `start_trial` operation took 0.784 s, which may be a performance bottleneck.
# 2022-08-29 14:55:52,663	WARNING util.py:220 -- The `start_trial` operation took 0.834 s, which may be a performance bottleneck.
# 2022-08-29 14:55:59,831	WARNING util.py:220 -- The `start_trial` operation took 0.896 s, which may be a performance bottleneck.
# 2022-08-29 14:56:07,712	WARNING util.py:220 -- The `start_trial` operation took 0.918 s, which may be a performance bottleneck.
# Result for train_mnist_d6d05_00000:
#   date: 2022-08-29_14-58-48
#   done: false
#   experiment_id: 6eb2d6ddb1ca433a98476d01ce30bb94
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 91.01
#   node_ip: 147.142.68.85
#   pid: 96840
#   time_since_restore: 196.7659192085266
#   time_this_iter_s: 196.7659192085266
#   time_total_s: 196.7659192085266
#   timestamp: 1661777928
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00000
#   warmup_time: 0.0029163360595703125
#
# Result for train_mnist_d6d05_00001:
#   date: 2022-08-29_14-59-00
#   done: false
#   experiment_id: 09dead0ff7394abfba708c66d4c6fb7e
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 84.55
#   node_ip: 147.142.68.85
#   pid: 96891
#   time_since_restore: 205.38097524642944
#   time_this_iter_s: 205.38097524642944
#   time_total_s: 205.38097524642944
#   timestamp: 1661777940
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00001
#   warmup_time: 0.002808094024658203
#
# Result for train_mnist_d6d05_00004:
#   date: 2022-08-29_14-59-06
#   done: false
#   experiment_id: 3e54a894655340fa9993945b657772e0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 97.8
#   node_ip: 147.142.68.85
#   pid: 96922
#   time_since_restore: 209.13505721092224
#   time_this_iter_s: 209.13505721092224
#   time_total_s: 209.13505721092224
#   timestamp: 1661777946
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00004
#   warmup_time: 0.004798173904418945
#
# Result for train_mnist_d6d05_00002:
#   date: 2022-08-29_14-59-10
#   done: false
#   experiment_id: 3564bc84c2d7442398ab5c644993d1a4
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 77.21
#   node_ip: 147.142.68.85
#   pid: 96898
#   time_since_restore: 214.52799344062805
#   time_this_iter_s: 214.52799344062805
#   time_total_s: 214.52799344062805
#   timestamp: 1661777950
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00002
#   warmup_time: 0.004522562026977539
#
# Result for train_mnist_d6d05_00005:
#   date: 2022-08-29_14-59-12
#   done: false
#   experiment_id: b3701e47210e430fa1ed6425754c2461
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 20.87
#   node_ip: 147.142.68.85
#   pid: 96962
#   time_since_restore: 213.7410593032837
#   time_this_iter_s: 213.7410593032837
#   time_total_s: 213.7410593032837
#   timestamp: 1661777952
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00005
#   warmup_time: 0.004241228103637695
#
# Result for train_mnist_d6d05_00003:
#   date: 2022-08-29_14-59-13
#   done: false
#   experiment_id: 0e90858623cb450eaa85859ec5da25fc
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 93.92
#   node_ip: 147.142.68.85
#   pid: 96920
#   time_since_restore: 216.29233765602112
#   time_this_iter_s: 216.29233765602112
#   time_total_s: 216.29233765602112
#   timestamp: 1661777953
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00003
#   warmup_time: 0.0043027400970458984
#
# Result for train_mnist_d6d05_00006:
#   date: 2022-08-29_14-59-29
#   done: false
#   experiment_id: 2fe3b689ad5941b9aaca9d3af3b26b0c
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 92.27
#   node_ip: 147.142.68.85
#   pid: 97124
#   time_since_restore: 225.0220763683319
#   time_this_iter_s: 225.0220763683319
#   time_total_s: 225.0220763683319
#   timestamp: 1661777969
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00006
#   warmup_time: 0.004260063171386719
#
# Result for train_mnist_d6d05_00007:
#   date: 2022-08-29_14-59-30
#   done: false
#   experiment_id: ce329c6a43fa4ec2849a25f88c1e70a4
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 84.12
#   node_ip: 147.142.68.85
#   pid: 97127
#   time_since_restore: 225.21538496017456
#   time_this_iter_s: 225.21538496017456
#   time_total_s: 225.21538496017456
#   timestamp: 1661777970
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00007
#   warmup_time: 0.00983572006225586
#
# Result for train_mnist_d6d05_00008:
#   date: 2022-08-29_14-59-35
#   done: false
#   experiment_id: f04744bd2c524396b7729fee139bf300
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 85.69
#   node_ip: 147.142.68.85
#   pid: 97310
#   time_since_restore: 223.18477821350098
#   time_this_iter_s: 223.18477821350098
#   time_total_s: 223.18477821350098
#   timestamp: 1661777975
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00008
#   warmup_time: 0.009851455688476562
#
# Result for train_mnist_d6d05_00009:
#   date: 2022-08-29_14-59-46
#   done: false
#   experiment_id: 3a01de2a0b6c4a7787c17638a7900b85
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 96.86
#   node_ip: 147.142.68.85
#   pid: 97393
#   time_since_restore: 227.87822222709656
#   time_this_iter_s: 227.87822222709656
#   time_total_s: 227.87822222709656
#   timestamp: 1661777986
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00009
#   warmup_time: 0.012578010559082031
#
# Result for train_mnist_d6d05_00010:
#   date: 2022-08-29_14-59-57
#   done: false
#   experiment_id: 21b6c0002646473db9af64d3d9725dae
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 95.64
#   node_ip: 147.142.68.85
#   pid: 97540
#   time_since_restore: 230.47767400741577
#   time_this_iter_s: 230.47767400741577
#   time_total_s: 230.47767400741577
#   timestamp: 1661777997
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00010
#   warmup_time: 0.017763853073120117
#
# Result for train_mnist_d6d05_00011:
#   date: 2022-08-29_15-00-05
#   done: false
#   experiment_id: 070c5ce040f74800b1e8f38246149c75
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 60.41
#   node_ip: 147.142.68.85
#   pid: 97622
#   time_since_restore: 230.84846806526184
#   time_this_iter_s: 230.84846806526184
#   time_total_s: 230.84846806526184
#   timestamp: 1661778005
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00011
#   warmup_time: 0.012460708618164062
#
# Result for train_mnist_d6d05_00000:
#   date: 2022-08-29_15-02-42
#   done: false
#   experiment_id: 6eb2d6ddb1ca433a98476d01ce30bb94
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 95.77
#   node_ip: 147.142.68.85
#   pid: 96840
#   time_since_restore: 430.80548572540283
#   time_this_iter_s: 234.03956651687622
#   time_total_s: 430.80548572540283
#   timestamp: 1661778162
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00000
#   warmup_time: 0.0029163360595703125
#
# Result for train_mnist_d6d05_00000:
#   date: 2022-08-29_15-02-42
#   done: true
#   experiment_id: 6eb2d6ddb1ca433a98476d01ce30bb94
#   experiment_tag: 0_lr=0.0010,momentum=0.9000,weight_decay=0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 95.77
#   node_ip: 147.142.68.85
#   pid: 96840
#   time_since_restore: 430.80548572540283
#   time_this_iter_s: 234.03956651687622
#   time_total_s: 430.80548572540283
#   timestamp: 1661778162
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00000
#   warmup_time: 0.0029163360595703125
#
# Result for train_mnist_d6d05_00004:
#   date: 2022-08-29_15-02-56
#   done: false
#   experiment_id: 3e54a894655340fa9993945b657772e0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 98.67
#   node_ip: 147.142.68.85
#   pid: 96922
#   time_since_restore: 438.77088379859924
#   time_this_iter_s: 229.635826587677
#   time_total_s: 438.77088379859924
#   timestamp: 1661778176
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00004
#   warmup_time: 0.004798173904418945
#
# Result for train_mnist_d6d05_00004:
#   date: 2022-08-29_15-02-56
#   done: true
#   experiment_id: 3e54a894655340fa9993945b657772e0
#   experiment_tag: 4_lr=0.0100,momentum=0.9900,weight_decay=0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 98.67
#   node_ip: 147.142.68.85
#   pid: 96922
#   time_since_restore: 438.77088379859924
#   time_this_iter_s: 229.635826587677
#   time_total_s: 438.77088379859924
#   timestamp: 1661778176
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00004
#   warmup_time: 0.004798173904418945
#
# Result for train_mnist_d6d05_00001:
#   date: 2022-08-29_15-02-59
#   done: false
#   experiment_id: 09dead0ff7394abfba708c66d4c6fb7e
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 94.67
#   node_ip: 147.142.68.85
#   pid: 96891
#   time_since_restore: 444.22418308258057
#   time_this_iter_s: 238.84320783615112
#   time_total_s: 444.22418308258057
#   timestamp: 1661778179
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00001
#   warmup_time: 0.002808094024658203
#
# Result for train_mnist_d6d05_00001:
#   date: 2022-08-29_15-02-59
#   done: true
#   experiment_id: 09dead0ff7394abfba708c66d4c6fb7e
#   experiment_tag: 1_lr=0.0100,momentum=0.9000,weight_decay=0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 94.67
#   node_ip: 147.142.68.85
#   pid: 96891
#   time_since_restore: 444.22418308258057
#   time_this_iter_s: 238.84320783615112
#   time_total_s: 444.22418308258057
#   timestamp: 1661778179
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00001
#   warmup_time: 0.002808094024658203
#
# Result for train_mnist_d6d05_00002:
#   date: 2022-08-29_15-03-00
#   done: false
#   experiment_id: 3564bc84c2d7442398ab5c644993d1a4
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 99.07
#   node_ip: 147.142.68.85
#   pid: 96898
#   time_since_restore: 444.08652544021606
#   time_this_iter_s: 229.558531999588
#   time_total_s: 444.08652544021606
#   timestamp: 1661778180
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00002
#   warmup_time: 0.004522562026977539
#
# Result for train_mnist_d6d05_00002:
#   date: 2022-08-29_15-03-00
#   done: true
#   experiment_id: 3564bc84c2d7442398ab5c644993d1a4
#   experiment_tag: 2_lr=0.1000,momentum=0.9000,weight_decay=0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 99.07
#   node_ip: 147.142.68.85
#   pid: 96898
#   time_since_restore: 444.08652544021606
#   time_this_iter_s: 229.558531999588
#   time_total_s: 444.08652544021606
#   timestamp: 1661778180
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00002
#   warmup_time: 0.004522562026977539
#
# Result for train_mnist_d6d05_00005:
#   date: 2022-08-29_15-03-03
#   done: false
#   experiment_id: b3701e47210e430fa1ed6425754c2461
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 30.74
#   node_ip: 147.142.68.85
#   pid: 96962
#   time_since_restore: 444.8980641365051
#   time_this_iter_s: 231.15700483322144
#   time_total_s: 444.8980641365051
#   timestamp: 1661778183
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00005
#   warmup_time: 0.004241228103637695
#
# Result for train_mnist_d6d05_00005:
#   date: 2022-08-29_15-03-03
#   done: true
#   experiment_id: b3701e47210e430fa1ed6425754c2461
#   experiment_tag: 5_lr=0.1000,momentum=0.9900,weight_decay=0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 30.74
#   node_ip: 147.142.68.85
#   pid: 96962
#   time_since_restore: 444.8980641365051
#   time_this_iter_s: 231.15700483322144
#   time_total_s: 444.8980641365051
#   timestamp: 1661778183
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00005
#   warmup_time: 0.004241228103637695
#
# Result for train_mnist_d6d05_00003:
#   date: 2022-08-29_15-03-07
#   done: false
#   experiment_id: 0e90858623cb450eaa85859ec5da25fc
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 98.35
#   node_ip: 147.142.68.85
#   pid: 96920
#   time_since_restore: 450.6336464881897
#   time_this_iter_s: 234.34130883216858
#   time_total_s: 450.6336464881897
#   timestamp: 1661778187
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00003
#   warmup_time: 0.0043027400970458984
#
# Result for train_mnist_d6d05_00003:
#   date: 2022-08-29_15-03-07
#   done: true
#   experiment_id: 0e90858623cb450eaa85859ec5da25fc
#   experiment_tag: 3_lr=0.0010,momentum=0.9900,weight_decay=0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 98.35
#   node_ip: 147.142.68.85
#   pid: 96920
#   time_since_restore: 450.6336464881897
#   time_this_iter_s: 234.34130883216858
#   time_total_s: 450.6336464881897
#   timestamp: 1661778187
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00003
#   warmup_time: 0.0043027400970458984
#
# Result for train_mnist_d6d05_00007:
#   date: 2022-08-29_15-03-25
#   done: false
#   experiment_id: ce329c6a43fa4ec2849a25f88c1e70a4
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 93.32
#   node_ip: 147.142.68.85
#   pid: 97127
#   time_since_restore: 460.0130891799927
#   time_this_iter_s: 234.79770421981812
#   time_total_s: 460.0130891799927
#   timestamp: 1661778205
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00007
#   warmup_time: 0.00983572006225586
#
# Result for train_mnist_d6d05_00007:
#   date: 2022-08-29_15-03-25
#   done: true
#   experiment_id: ce329c6a43fa4ec2849a25f88c1e70a4
#   experiment_tag: 7_lr=0.0100,momentum=0.9000,weight_decay=0.0100
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 93.32
#   node_ip: 147.142.68.85
#   pid: 97127
#   time_since_restore: 460.0130891799927
#   time_this_iter_s: 234.79770421981812
#   time_total_s: 460.0130891799927
#   timestamp: 1661778205
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00007
#   warmup_time: 0.00983572006225586
#
# Result for train_mnist_d6d05_00006:
#   date: 2022-08-29_15-03-25
#   done: false
#   experiment_id: 2fe3b689ad5941b9aaca9d3af3b26b0c
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 96.17
#   node_ip: 147.142.68.85
#   pid: 97124
#   time_since_restore: 461.3054401874542
#   time_this_iter_s: 236.28336381912231
#   time_total_s: 461.3054401874542
#   timestamp: 1661778205
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00006
#   warmup_time: 0.004260063171386719
#
# Result for train_mnist_d6d05_00006:
#   date: 2022-08-29_15-03-25
#   done: true
#   experiment_id: 2fe3b689ad5941b9aaca9d3af3b26b0c
#   experiment_tag: 6_lr=0.0010,momentum=0.9000,weight_decay=0.0100
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 96.17
#   node_ip: 147.142.68.85
#   pid: 97124
#   time_since_restore: 461.3054401874542
#   time_this_iter_s: 236.28336381912231
#   time_total_s: 461.3054401874542
#   timestamp: 1661778205
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00006
#   warmup_time: 0.004260063171386719
#
# Result for train_mnist_d6d05_00008:
#   date: 2022-08-29_15-03-27
#   done: false
#   experiment_id: f04744bd2c524396b7729fee139bf300
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 97.27
#   node_ip: 147.142.68.85
#   pid: 97310
#   time_since_restore: 455.6686351299286
#   time_this_iter_s: 232.4838569164276
#   time_total_s: 455.6686351299286
#   timestamp: 1661778207
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00008
#   warmup_time: 0.009851455688476562
#
# Result for train_mnist_d6d05_00008:
#   date: 2022-08-29_15-03-27
#   done: true
#   experiment_id: f04744bd2c524396b7729fee139bf300
#   experiment_tag: 8_lr=0.1000,momentum=0.9000,weight_decay=0.0100
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 97.27
#   node_ip: 147.142.68.85
#   pid: 97310
#   time_since_restore: 455.6686351299286
#   time_this_iter_s: 232.4838569164276
#   time_total_s: 455.6686351299286
#   timestamp: 1661778207
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00008
#   warmup_time: 0.009851455688476562
#
# Result for train_mnist_d6d05_00009:
#   date: 2022-08-29_15-03-36
#   done: false
#   experiment_id: 3a01de2a0b6c4a7787c17638a7900b85
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 95.66
#   node_ip: 147.142.68.85
#   pid: 97393
#   time_since_restore: 457.8082420825958
#   time_this_iter_s: 229.93001985549927
#   time_total_s: 457.8082420825958
#   timestamp: 1661778216
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00009
#   warmup_time: 0.012578010559082031
#
# Result for train_mnist_d6d05_00009:
#   date: 2022-08-29_15-03-36
#   done: true
#   experiment_id: 3a01de2a0b6c4a7787c17638a7900b85
#   experiment_tag: 9_lr=0.0010,momentum=0.9900,weight_decay=0.0100
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 95.66
#   node_ip: 147.142.68.85
#   pid: 97393
#   time_since_restore: 457.8082420825958
#   time_this_iter_s: 229.93001985549927
#   time_total_s: 457.8082420825958
#   timestamp: 1661778216
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00009
#   warmup_time: 0.012578010559082031
#
# Result for train_mnist_d6d05_00010:
#   date: 2022-08-29_15-03-41
#   done: false
#   experiment_id: 21b6c0002646473db9af64d3d9725dae
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 93.16
#   node_ip: 147.142.68.85
#   pid: 97540
#   time_since_restore: 455.0114860534668
#   time_this_iter_s: 224.53381204605103
#   time_total_s: 455.0114860534668
#   timestamp: 1661778221
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00010
#   warmup_time: 0.017763853073120117
#
# Result for train_mnist_d6d05_00010:
#   date: 2022-08-29_15-03-41
#   done: true
#   experiment_id: 21b6c0002646473db9af64d3d9725dae
#   experiment_tag: 10_lr=0.0100,momentum=0.9900,weight_decay=0.0100
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 93.16
#   node_ip: 147.142.68.85
#   pid: 97540
#   time_since_restore: 455.0114860534668
#   time_this_iter_s: 224.53381204605103
#   time_total_s: 455.0114860534668
#   timestamp: 1661778221
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00010
#   warmup_time: 0.017763853073120117
#
# Result for train_mnist_d6d05_00011:
#   date: 2022-08-29_15-03-45
#   done: false
#   experiment_id: 070c5ce040f74800b1e8f38246149c75
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 90.6
#   node_ip: 147.142.68.85
#   pid: 97622
#   time_since_restore: 450.98347878456116
#   time_this_iter_s: 220.13501071929932
#   time_total_s: 450.98347878456116
#   timestamp: 1661778225
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00011
#   warmup_time: 0.012460708618164062
#
# Result for train_mnist_d6d05_00011:
#   date: 2022-08-29_15-03-45
#   done: true
#   experiment_id: 070c5ce040f74800b1e8f38246149c75
#   experiment_tag: 11_lr=0.1000,momentum=0.9900,weight_decay=0.0100
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 90.6
#   node_ip: 147.142.68.85
#   pid: 97622
#   time_since_restore: 450.98347878456116
#   time_this_iter_s: 220.13501071929932
#   time_total_s: 450.98347878456116
#   timestamp: 1661778225
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00011
#   warmup_time: 0.012460708618164062
#
# Result for train_mnist_d6d05_00012:
#   date: 2022-08-29_15-05-02
#   done: false
#   experiment_id: 6eb2d6ddb1ca433a98476d01ce30bb94
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 76.74
#   node_ip: 147.142.68.85
#   pid: 96840
#   time_since_restore: 139.96768236160278
#   time_this_iter_s: 139.96768236160278
#   time_total_s: 139.96768236160278
#   timestamp: 1661778302
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00012
#   warmup_time: 0.0029163360595703125
#
# Result for train_mnist_d6d05_00013:
#   date: 2022-08-29_15-05-05
#   done: false
#   experiment_id: 3e54a894655340fa9993945b657772e0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 85.13
#   node_ip: 147.142.68.85
#   pid: 96922
#   time_since_restore: 129.25716757774353
#   time_this_iter_s: 129.25716757774353
#   time_total_s: 129.25716757774353
#   timestamp: 1661778305
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00013
#   warmup_time: 0.004798173904418945
#
# Result for train_mnist_d6d05_00015:
#   date: 2022-08-29_15-05-12
#   done: false
#   experiment_id: 3564bc84c2d7442398ab5c644993d1a4
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 78.27
#   node_ip: 147.142.68.85
#   pid: 96898
#   time_since_restore: 131.9203155040741
#   time_this_iter_s: 131.9203155040741
#   time_total_s: 131.9203155040741
#   timestamp: 1661778312
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00015
#   warmup_time: 0.004522562026977539
#
# Result for train_mnist_d6d05_00016:
#   date: 2022-08-29_15-05-12
#   done: false
#   experiment_id: b3701e47210e430fa1ed6425754c2461
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 37.62
#   node_ip: 147.142.68.85
#   pid: 96962
#   time_since_restore: 129.07028698921204
#   time_this_iter_s: 129.07028698921204
#   time_total_s: 129.07028698921204
#   timestamp: 1661778312
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00016
#   warmup_time: 0.004241228103637695
#
# Result for train_mnist_d6d05_00017:
#   date: 2022-08-29_15-05-14
#   done: false
#   experiment_id: 0e90858623cb450eaa85859ec5da25fc
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 61.12
#   node_ip: 147.142.68.85
#   pid: 96920
#   time_since_restore: 126.68470573425293
#   time_this_iter_s: 126.68470573425293
#   time_total_s: 126.68470573425293
#   timestamp: 1661778314
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00017
#   warmup_time: 0.0043027400970458984
#
# Result for train_mnist_d6d05_00014:
#   date: 2022-08-29_15-05-14
#   done: false
#   experiment_id: 09dead0ff7394abfba708c66d4c6fb7e
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 55.16
#   node_ip: 147.142.68.85
#   pid: 96891
#   time_since_restore: 135.299622297287
#   time_this_iter_s: 135.299622297287
#   time_total_s: 135.299622297287
#   timestamp: 1661778314
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00014
#   warmup_time: 0.002808094024658203
#
# Result for train_mnist_d6d05_00012:
#   date: 2022-08-29_15-06-53
#   done: false
#   experiment_id: 6eb2d6ddb1ca433a98476d01ce30bb94
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 79.84
#   node_ip: 147.142.68.85
#   pid: 96840
#   time_since_restore: 251.3289337158203
#   time_this_iter_s: 111.36125135421753
#   time_total_s: 251.3289337158203
#   timestamp: 1661778413
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00012
#   warmup_time: 0.0029163360595703125
#
# Result for train_mnist_d6d05_00012:
#   date: 2022-08-29_15-06-53
#   done: true
#   experiment_id: 6eb2d6ddb1ca433a98476d01ce30bb94
#   experiment_tag: 12_lr=0.0010,momentum=0.9000,weight_decay=0.1000
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 79.84
#   node_ip: 147.142.68.85
#   pid: 96840
#   time_since_restore: 251.3289337158203
#   time_this_iter_s: 111.36125135421753
#   time_total_s: 251.3289337158203
#   timestamp: 1661778413
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00012
#   warmup_time: 0.0029163360595703125
#
# Result for train_mnist_d6d05_00013:
#   date: 2022-08-29_15-06-57
#   done: false
#   experiment_id: 3e54a894655340fa9993945b657772e0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 88.69
#   node_ip: 147.142.68.85
#   pid: 96922
#   time_since_restore: 241.35749292373657
#   time_this_iter_s: 112.10032534599304
#   time_total_s: 241.35749292373657
#   timestamp: 1661778417
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00013
#   warmup_time: 0.004798173904418945
#
# Result for train_mnist_d6d05_00013:
#   date: 2022-08-29_15-06-57
#   done: true
#   experiment_id: 3e54a894655340fa9993945b657772e0
#   experiment_tag: 13_lr=0.0100,momentum=0.9000,weight_decay=0.1000
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 88.69
#   node_ip: 147.142.68.85
#   pid: 96922
#   time_since_restore: 241.35749292373657
#   time_this_iter_s: 112.10032534599304
#   time_total_s: 241.35749292373657
#   timestamp: 1661778417
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00013
#   warmup_time: 0.004798173904418945
#
# Result for train_mnist_d6d05_00015:
#   date: 2022-08-29_15-07-04
#   done: false
#   experiment_id: 3564bc84c2d7442398ab5c644993d1a4
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 76.32
#   node_ip: 147.142.68.85
#   pid: 96898
#   time_since_restore: 243.6615219116211
#   time_this_iter_s: 111.741206407547
#   time_total_s: 243.6615219116211
#   timestamp: 1661778424
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00015
#   warmup_time: 0.004522562026977539
#
# Result for train_mnist_d6d05_00015:
#   date: 2022-08-29_15-07-04
#   done: true
#   experiment_id: 3564bc84c2d7442398ab5c644993d1a4
#   experiment_tag: 15_lr=0.0010,momentum=0.9900,weight_decay=0.1000
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 76.32
#   node_ip: 147.142.68.85
#   pid: 96898
#   time_since_restore: 243.6615219116211
#   time_this_iter_s: 111.741206407547
#   time_total_s: 243.6615219116211
#   timestamp: 1661778424
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00015
#   warmup_time: 0.004522562026977539
#
# Result for train_mnist_d6d05_00016:
#   date: 2022-08-29_15-07-04
#   done: false
#   experiment_id: b3701e47210e430fa1ed6425754c2461
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 62.91
#   node_ip: 147.142.68.85
#   pid: 96962
#   time_since_restore: 241.59546399116516
#   time_this_iter_s: 112.52517700195312
#   time_total_s: 241.59546399116516
#   timestamp: 1661778424
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00016
#   warmup_time: 0.004241228103637695
#
# Result for train_mnist_d6d05_00016:
#   date: 2022-08-29_15-07-04
#   done: true
#   experiment_id: b3701e47210e430fa1ed6425754c2461
#   experiment_tag: 16_lr=0.0100,momentum=0.9900,weight_decay=0.1000
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 62.91
#   node_ip: 147.142.68.85
#   pid: 96962
#   time_since_restore: 241.59546399116516
#   time_this_iter_s: 112.52517700195312
#   time_total_s: 241.59546399116516
#   timestamp: 1661778424
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00016
#   warmup_time: 0.004241228103637695
#
# Result for train_mnist_d6d05_00017:
#   date: 2022-08-29_15-07-05
#   done: false
#   experiment_id: 0e90858623cb450eaa85859ec5da25fc
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 61.59
#   node_ip: 147.142.68.85
#   pid: 96920
#   time_since_restore: 237.78889322280884
#   time_this_iter_s: 111.10418748855591
#   time_total_s: 237.78889322280884
#   timestamp: 1661778425
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00017
#   warmup_time: 0.0043027400970458984
#
# Result for train_mnist_d6d05_00017:
#   date: 2022-08-29_15-07-05
#   done: true
#   experiment_id: 0e90858623cb450eaa85859ec5da25fc
#   experiment_tag: 17_lr=0.1000,momentum=0.9900,weight_decay=0.1000
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 61.59
#   node_ip: 147.142.68.85
#   pid: 96920
#   time_since_restore: 237.78889322280884
#   time_this_iter_s: 111.10418748855591
#   time_total_s: 237.78889322280884
#   timestamp: 1661778425
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00017
#   warmup_time: 0.0043027400970458984
#
# Result for train_mnist_d6d05_00014:
#   date: 2022-08-29_15-07-06
#   done: false
#   experiment_id: 09dead0ff7394abfba708c66d4c6fb7e
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 67.1
#   node_ip: 147.142.68.85
#   pid: 96891
#   time_since_restore: 246.92278742790222
#   time_this_iter_s: 111.62316513061523
#   time_total_s: 246.92278742790222
#   timestamp: 1661778426
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00014
#   warmup_time: 0.002808094024658203
#
# Result for train_mnist_d6d05_00014:
#   date: 2022-08-29_15-07-06
#   done: true
#   experiment_id: 09dead0ff7394abfba708c66d4c6fb7e
#   experiment_tag: 14_lr=0.1000,momentum=0.9000,weight_decay=0.1000
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 67.1
#   node_ip: 147.142.68.85
#   pid: 96891
#   time_since_restore: 246.92278742790222
#   time_this_iter_s: 111.62316513061523
#   time_total_s: 246.92278742790222
#   timestamp: 1661778426
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00014
#   warmup_time: 0.002808094024658203
# 2022-08-29 15:07:06,676	INFO tune.py:758 -- Total run time: 706.66 seconds (705.67 seconds for the tuning loop).
# Best config:  {'lr': 0.1, 'momentum': 0.9, 'weight_decay': 0}
