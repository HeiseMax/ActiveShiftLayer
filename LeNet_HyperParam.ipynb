# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import pandas

import torch
import torch.optim as optim
from torch.nn import CrossEntropyLoss, Conv2d, Sequential, BatchNorm2d
from torch.utils.data import DataLoader

import torchvision
import torchvision.datasets as datasets
from torchvision import transforms

from torchinfo import summary

from ActiveShiftLayer import ASL
from util import test_loss, train_NN

from ray import tune
from ray.tune.search.bayesopt import BayesOptSearch

# %%
if torch.cuda.is_available():
    device = 'cuda'
else:
    device = 'cpu'
print(device)
# Out:
# cuda

# %%
batch_size = 100

#transform images into normalized tensors
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5,), std=(0.5,))
])

train_dataset = datasets.MNIST(
    "./data/MNIST",
    download=True,
    train=True,
    transform=transform,
)

test_dataset = datasets.MNIST(
    "./data/MNIST",
    download=True,
    train=False,
    transform=transform,
)

train_dataloader = DataLoader(
    dataset=train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=1,
    pin_memory=True,
)

test_dataloader = DataLoader(
    dataset=test_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=1,
    pin_memory=True,
)

# %%
from Models import LeASLNet
input_shape = (batch_size, 1, 28, 28)
criterion = CrossEntropyLoss()

def train_mnist(config):
    test_device = "cpu"
    model = LeASLNet(input_shape, 10, initial_lr=config["lr"], momentum=config["momentum"], weight_decay=config["weight_decay"], device=test_device, expansion_rate=1).to(test_device)
    for i in range(2):
        train_NN(model, criterion, train_dataloader,
        test_dataloader, epochs=2, batches_to_test=100,patience=2,device=test_device, print_test=False, verbose=False)
        acc = test_loss(model, test_dataloader, criterion, test_device)[1]
        tune.report(mean_accuracy=acc)

analysis = tune.run(
    train_mnist,num_samples=15, config={"lr": tune.loguniform(0.001, 0.1), "momentum": tune.uniform(0.8, 1), "weight_decay": tune.uniform(0, 0.1)})

print("Best config: ", analysis.get_best_config(metric="mean_accuracy", mode="max",))

# Get a dataframe for analyzing trial results.
df = analysis.dataframe()
# Out:
# == Status ==<br>Current time: 2022-08-29 13:59:00 (running for 00:12:10.86)<br>Memory usage on this node: 8.2/15.4 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/4.72 GiB heap, 0.0/2.36 GiB objects (0.0/1.0 accelerator_type:G)<br>Result logdir: /home/max/ray_results/train_mnist_2022-08-29_13-46-49<br>Number of trials: 15/15 (15 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name             </th><th>status    </th><th>loc                </th><th style="text-align: right;">        lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">  weight_decay</th><th style="text-align: right;">  acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>train_mnist_44217_00000</td><td>TERMINATED</td><td>147.142.68.85:68312</td><td style="text-align: right;">0.00446645</td><td style="text-align: right;">  0.993003</td><td style="text-align: right;">    0.0399922 </td><td style="text-align: right;">88.5 </td><td style="text-align: right;">     2</td><td style="text-align: right;">         557.05 </td></tr>
# <tr><td>train_mnist_44217_00001</td><td>TERMINATED</td><td>147.142.68.85:68362</td><td style="text-align: right;">0.00252822</td><td style="text-align: right;">  0.927413</td><td style="text-align: right;">    0.00924895</td><td style="text-align: right;">95.89</td><td style="text-align: right;">     2</td><td style="text-align: right;">         554.376</td></tr>
# <tr><td>train_mnist_44217_00002</td><td>TERMINATED</td><td>147.142.68.85:68364</td><td style="text-align: right;">0.00452166</td><td style="text-align: right;">  0.881696</td><td style="text-align: right;">    0.081959  </td><td style="text-align: right;">78.7 </td><td style="text-align: right;">     2</td><td style="text-align: right;">         556.69 </td></tr>
# <tr><td>train_mnist_44217_00003</td><td>TERMINATED</td><td>147.142.68.85:68368</td><td style="text-align: right;">0.0617364 </td><td style="text-align: right;">  0.89286 </td><td style="text-align: right;">    0.0637015 </td><td style="text-align: right;">84.1 </td><td style="text-align: right;">     2</td><td style="text-align: right;">         559.309</td></tr>
# <tr><td>train_mnist_44217_00004</td><td>TERMINATED</td><td>147.142.68.85:68394</td><td style="text-align: right;">0.0189816 </td><td style="text-align: right;">  0.860582</td><td style="text-align: right;">    0.0742808 </td><td style="text-align: right;">80.58</td><td style="text-align: right;">     2</td><td style="text-align: right;">         567.034</td></tr>
# <tr><td>train_mnist_44217_00005</td><td>TERMINATED</td><td>147.142.68.85:68420</td><td style="text-align: right;">0.00204454</td><td style="text-align: right;">  0.903675</td><td style="text-align: right;">    0.086614  </td><td style="text-align: right;">78.12</td><td style="text-align: right;">     2</td><td style="text-align: right;">         567.705</td></tr>
# <tr><td>train_mnist_44217_00006</td><td>TERMINATED</td><td>147.142.68.85:68446</td><td style="text-align: right;">0.0404193 </td><td style="text-align: right;">  0.881044</td><td style="text-align: right;">    0.03029   </td><td style="text-align: right;">88.91</td><td style="text-align: right;">     2</td><td style="text-align: right;">         569.063</td></tr>
# <tr><td>train_mnist_44217_00007</td><td>TERMINATED</td><td>147.142.68.85:68473</td><td style="text-align: right;">0.00115685</td><td style="text-align: right;">  0.969497</td><td style="text-align: right;">    0.0585754 </td><td style="text-align: right;">86.53</td><td style="text-align: right;">     2</td><td style="text-align: right;">         567.974</td></tr>
# <tr><td>train_mnist_44217_00008</td><td>TERMINATED</td><td>147.142.68.85:68683</td><td style="text-align: right;">0.00100183</td><td style="text-align: right;">  0.834387</td><td style="text-align: right;">    0.021391  </td><td style="text-align: right;">87.59</td><td style="text-align: right;">     2</td><td style="text-align: right;">         565.338</td></tr>
# <tr><td>train_mnist_44217_00009</td><td>TERMINATED</td><td>147.142.68.85:68816</td><td style="text-align: right;">0.017448  </td><td style="text-align: right;">  0.936761</td><td style="text-align: right;">    0.026766  </td><td style="text-align: right;">90.64</td><td style="text-align: right;">     2</td><td style="text-align: right;">         559.398</td></tr>
# <tr><td>train_mnist_44217_00010</td><td>TERMINATED</td><td>147.142.68.85:68914</td><td style="text-align: right;">0.0588809 </td><td style="text-align: right;">  0.869926</td><td style="text-align: right;">    0.0383133 </td><td style="text-align: right;">94.66</td><td style="text-align: right;">     2</td><td style="text-align: right;">         555.489</td></tr>
# <tr><td>train_mnist_44217_00011</td><td>TERMINATED</td><td>147.142.68.85:69044</td><td style="text-align: right;">0.0136286 </td><td style="text-align: right;">  0.842664</td><td style="text-align: right;">    0.0270664 </td><td style="text-align: right;">94.63</td><td style="text-align: right;">     2</td><td style="text-align: right;">         551.985</td></tr>
# <tr><td>train_mnist_44217_00012</td><td>TERMINATED</td><td>147.142.68.85:68312</td><td style="text-align: right;">0.00206474</td><td style="text-align: right;">  0.933809</td><td style="text-align: right;">    0.0553026 </td><td style="text-align: right;">86.41</td><td style="text-align: right;">     2</td><td style="text-align: right;">         164.277</td></tr>
# <tr><td>train_mnist_44217_00013</td><td>TERMINATED</td><td>147.142.68.85:68362</td><td style="text-align: right;">0.0192147 </td><td style="text-align: right;">  0.997185</td><td style="text-align: right;">    0.0957026 </td><td style="text-align: right;">74.65</td><td style="text-align: right;">     2</td><td style="text-align: right;">         160.791</td></tr>
# <tr><td>train_mnist_44217_00014</td><td>TERMINATED</td><td>147.142.68.85:68364</td><td style="text-align: right;">0.0204508 </td><td style="text-align: right;">  0.82664 </td><td style="text-align: right;">    0.0908216 </td><td style="text-align: right;">79.04</td><td style="text-align: right;">     2</td><td style="text-align: right;">         159.048</td></tr>
# </tbody>
# </table><br><br>
# 2022-08-29 13:46:56,359	WARNING worker.py:1829 -- Warning: The actor ImplicitFunc is very large (52 MiB). Check that its definition is not implicitly capturing a large array or other object in scope. Tip: use ray.put() to put large objects in the Ray object store.
# 2022-08-29 13:46:56,905	WARNING util.py:220 -- The `start_trial` operation took 0.926 s, which may be a performance bottleneck.
# 2022-08-29 13:47:01,036	WARNING util.py:220 -- The `start_trial` operation took 0.610 s, which may be a performance bottleneck.
# 2022-08-29 13:47:01,627	WARNING util.py:220 -- The `start_trial` operation took 0.588 s, which may be a performance bottleneck.
# 2022-08-29 13:47:02,195	WARNING util.py:220 -- The `start_trial` operation took 0.566 s, which may be a performance bottleneck.
# 2022-08-29 13:47:08,308	WARNING util.py:220 -- The `start_trial` operation took 0.961 s, which may be a performance bottleneck.
# 2022-08-29 13:47:16,526	WARNING util.py:220 -- The `start_trial` operation took 0.870 s, which may be a performance bottleneck.
# 2022-08-29 13:47:25,183	WARNING util.py:220 -- The `start_trial` operation took 0.954 s, which may be a performance bottleneck.
# 2022-08-29 13:47:34,963	WARNING util.py:220 -- The `start_trial` operation took 0.924 s, which may be a performance bottleneck.
# Result for train_mnist_44217_00000:
#   date: 2022-08-29_13-51-22
#   done: false
#   experiment_id: c386d6390e1944f5a0fcf79467e8ebc5
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 86.59
#   node_ip: 147.142.68.85
#   pid: 68312
#   time_since_restore: 263.56469988822937
#   time_this_iter_s: 263.56469988822937
#   time_total_s: 263.56469988822937
#   timestamp: 1661773882
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '44217_00000'
#   warmup_time: 0.002355813980102539
#
# Result for train_mnist_44217_00001:
#   date: 2022-08-29_13-51-29
#   done: false
#   experiment_id: ea3a79f2a8c04b69be51b1ad36850f88
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 92.61
#   node_ip: 147.142.68.85
#   pid: 68362
#   time_since_restore: 266.13845586776733
#   time_this_iter_s: 266.13845586776733
#   time_total_s: 266.13845586776733
#   timestamp: 1661773889
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '44217_00001'
#   warmup_time: 0.0037386417388916016
#
# Result for train_mnist_44217_00002:
#   date: 2022-08-29_13-51-31
#   done: false
#   experiment_id: 2c9c3c2bc3ca408889728486f6a55c72
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 79.07
#   node_ip: 147.142.68.85
#   pid: 68364
#   time_since_restore: 267.9941084384918
#   time_this_iter_s: 267.9941084384918
#   time_total_s: 267.9941084384918
#   timestamp: 1661773891
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '44217_00002'
#   warmup_time: 0.004679203033447266
#
# Result for train_mnist_44217_00003:
#   date: 2022-08-29_13-51-32
#   done: false
#   experiment_id: fbc91d1a720746b8a6784e3f88294418
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 82.29
#   node_ip: 147.142.68.85
#   pid: 68368
#   time_since_restore: 268.0899889469147
#   time_this_iter_s: 268.0899889469147
#   time_total_s: 268.0899889469147
#   timestamp: 1661773892
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '44217_00003'
#   warmup_time: 0.006840944290161133
#
# Result for train_mnist_44217_00006:
#   date: 2022-08-29_13-51-39
#   done: false
#   experiment_id: ec4c7f59f57644e292794b73bd774589
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 87.67
#   node_ip: 147.142.68.85
#   pid: 68446
#   time_since_restore: 272.9190616607666
#   time_this_iter_s: 272.9190616607666
#   time_total_s: 272.9190616607666
#   timestamp: 1661773899
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '44217_00006'
#   warmup_time: 0.006765604019165039
#
# Result for train_mnist_44217_00004:
#   date: 2022-08-29_13-51-41
#   done: false
#   experiment_id: c6de07c17aed482b8666aba3a49b7875
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 80.12
#   node_ip: 147.142.68.85
#   pid: 68394
#   time_since_restore: 276.3688533306122
#   time_this_iter_s: 276.3688533306122
#   time_total_s: 276.3688533306122
#   timestamp: 1661773901
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '44217_00004'
#   warmup_time: 0.0069615840911865234
#
# Result for train_mnist_44217_00005:
#   date: 2022-08-29_13-51-42
#   done: false
#   experiment_id: c94eb84f399444118b048627b4fe0b06
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 69.95
#   node_ip: 147.142.68.85
#   pid: 68420
#   time_since_restore: 276.9457833766937
#   time_this_iter_s: 276.9457833766937
#   time_total_s: 276.9457833766937
#   timestamp: 1661773902
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '44217_00005'
#   warmup_time: 0.0074727535247802734
#
# Result for train_mnist_44217_00007:
#   date: 2022-08-29_13-51-44
#   done: false
#   experiment_id: 11e34747c5244a82a2d4f9d182d7d9ad
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 85.75
#   node_ip: 147.142.68.85
#   pid: 68473
#   time_since_restore: 277.2188181877136
#   time_this_iter_s: 277.2188181877136
#   time_total_s: 277.2188181877136
#   timestamp: 1661773904
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '44217_00007'
#   warmup_time: 0.006163358688354492
#
# Result for train_mnist_44217_00008:
#   date: 2022-08-29_13-51-57
#   done: false
#   experiment_id: 50e6a810ffb949ec8e254964314d3c67
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 78.67
#   node_ip: 147.142.68.85
#   pid: 68683
#   time_since_restore: 281.96948647499084
#   time_this_iter_s: 281.96948647499084
#   time_total_s: 281.96948647499084
#   timestamp: 1661773917
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '44217_00008'
#   warmup_time: 0.022365093231201172
#
# Result for train_mnist_44217_00009:
#   date: 2022-08-29_13-52-05
#   done: false
#   experiment_id: 0dc5d49be72549d4a966dfb7fbcf20f4
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 89.33
#   node_ip: 147.142.68.85
#   pid: 68816
#   time_since_restore: 281.1467785835266
#   time_this_iter_s: 281.1467785835266
#   time_total_s: 281.1467785835266
#   timestamp: 1661773925
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '44217_00009'
#   warmup_time: 0.016208410263061523
#
# Result for train_mnist_44217_00010:
#   date: 2022-08-29_13-52-16
#   done: false
#   experiment_id: 70e93d0e9c51404b859a1b96c4e12e7b
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 91.28
#   node_ip: 147.142.68.85
#   pid: 68914
#   time_since_restore: 282.7977674007416
#   time_this_iter_s: 282.7977674007416
#   time_total_s: 282.7977674007416
#   timestamp: 1661773936
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '44217_00010'
#   warmup_time: 0.013387441635131836
#
# Result for train_mnist_44217_00011:
#   date: 2022-08-29_13-52-36
#   done: false
#   experiment_id: 9f492c1f733a4348a06376cd762dc258
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 73.41
#   node_ip: 147.142.68.85
#   pid: 69044
#   time_since_restore: 291.7486078739166
#   time_this_iter_s: 291.7486078739166
#   time_total_s: 291.7486078739166
#   timestamp: 1661773956
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '44217_00011'
#   warmup_time: 0.013059616088867188
#
# Result for train_mnist_44217_00000:
#   date: 2022-08-29_13-56-15
#   done: false
#   experiment_id: c386d6390e1944f5a0fcf79467e8ebc5
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 88.5
#   node_ip: 147.142.68.85
#   pid: 68312
#   time_since_restore: 557.0500764846802
#   time_this_iter_s: 293.4853765964508
#   time_total_s: 557.0500764846802
#   timestamp: 1661774175
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00000'
#   warmup_time: 0.002355813980102539
#
# Result for train_mnist_44217_00000:
#   date: 2022-08-29_13-56-15
#   done: true
#   experiment_id: c386d6390e1944f5a0fcf79467e8ebc5
#   experiment_tag: 0_lr=0.0045,momentum=0.9930,weight_decay=0.0400
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 88.5
#   node_ip: 147.142.68.85
#   pid: 68312
#   time_since_restore: 557.0500764846802
#   time_this_iter_s: 293.4853765964508
#   time_total_s: 557.0500764846802
#   timestamp: 1661774175
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00000'
#   warmup_time: 0.002355813980102539
#
# Result for train_mnist_44217_00001:
#   date: 2022-08-29_13-56-17
#   done: false
#   experiment_id: ea3a79f2a8c04b69be51b1ad36850f88
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 95.89
#   node_ip: 147.142.68.85
#   pid: 68362
#   time_since_restore: 554.3761050701141
#   time_this_iter_s: 288.2376492023468
#   time_total_s: 554.3761050701141
#   timestamp: 1661774177
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00001'
#   warmup_time: 0.0037386417388916016
#
# Result for train_mnist_44217_00001:
#   date: 2022-08-29_13-56-17
#   done: true
#   experiment_id: ea3a79f2a8c04b69be51b1ad36850f88
#   experiment_tag: 1_lr=0.0025,momentum=0.9274,weight_decay=0.0092
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 95.89
#   node_ip: 147.142.68.85
#   pid: 68362
#   time_since_restore: 554.3761050701141
#   time_this_iter_s: 288.2376492023468
#   time_total_s: 554.3761050701141
#   timestamp: 1661774177
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00001'
#   warmup_time: 0.0037386417388916016
#
# Result for train_mnist_44217_00002:
#   date: 2022-08-29_13-56-20
#   done: false
#   experiment_id: 2c9c3c2bc3ca408889728486f6a55c72
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 78.7
#   node_ip: 147.142.68.85
#   pid: 68364
#   time_since_restore: 556.6895778179169
#   time_this_iter_s: 288.69546937942505
#   time_total_s: 556.6895778179169
#   timestamp: 1661774180
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00002'
#   warmup_time: 0.004679203033447266
#
# Result for train_mnist_44217_00002:
#   date: 2022-08-29_13-56-20
#   done: true
#   experiment_id: 2c9c3c2bc3ca408889728486f6a55c72
#   experiment_tag: 2_lr=0.0045,momentum=0.8817,weight_decay=0.0820
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 78.7
#   node_ip: 147.142.68.85
#   pid: 68364
#   time_since_restore: 556.6895778179169
#   time_this_iter_s: 288.69546937942505
#   time_total_s: 556.6895778179169
#   timestamp: 1661774180
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00002'
#   warmup_time: 0.004679203033447266
#
# Result for train_mnist_44217_00003:
#   date: 2022-08-29_13-56-23
#   done: false
#   experiment_id: fbc91d1a720746b8a6784e3f88294418
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 84.1
#   node_ip: 147.142.68.85
#   pid: 68368
#   time_since_restore: 559.3088364601135
#   time_this_iter_s: 291.21884751319885
#   time_total_s: 559.3088364601135
#   timestamp: 1661774183
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00003'
#   warmup_time: 0.006840944290161133
#
# Result for train_mnist_44217_00003:
#   date: 2022-08-29_13-56-23
#   done: true
#   experiment_id: fbc91d1a720746b8a6784e3f88294418
#   experiment_tag: 3_lr=0.0617,momentum=0.8929,weight_decay=0.0637
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 84.1
#   node_ip: 147.142.68.85
#   pid: 68368
#   time_since_restore: 559.3088364601135
#   time_this_iter_s: 291.21884751319885
#   time_total_s: 559.3088364601135
#   timestamp: 1661774183
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00003'
#   warmup_time: 0.006840944290161133
#
# Result for train_mnist_44217_00004:
#   date: 2022-08-29_13-56-31
#   done: false
#   experiment_id: c6de07c17aed482b8666aba3a49b7875
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 80.58
#   node_ip: 147.142.68.85
#   pid: 68394
#   time_since_restore: 567.0344574451447
#   time_this_iter_s: 290.66560411453247
#   time_total_s: 567.0344574451447
#   timestamp: 1661774191
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00004'
#   warmup_time: 0.0069615840911865234
#
# Result for train_mnist_44217_00004:
#   date: 2022-08-29_13-56-31
#   done: true
#   experiment_id: c6de07c17aed482b8666aba3a49b7875
#   experiment_tag: 4_lr=0.0190,momentum=0.8606,weight_decay=0.0743
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 80.58
#   node_ip: 147.142.68.85
#   pid: 68394
#   time_since_restore: 567.0344574451447
#   time_this_iter_s: 290.66560411453247
#   time_total_s: 567.0344574451447
#   timestamp: 1661774191
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00004'
#   warmup_time: 0.0069615840911865234
#
# Result for train_mnist_44217_00005:
#   date: 2022-08-29_13-56-33
#   done: false
#   experiment_id: c94eb84f399444118b048627b4fe0b06
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 78.12
#   node_ip: 147.142.68.85
#   pid: 68420
#   time_since_restore: 567.7050523757935
#   time_this_iter_s: 290.75926899909973
#   time_total_s: 567.7050523757935
#   timestamp: 1661774193
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00005'
#   warmup_time: 0.0074727535247802734
#
# Result for train_mnist_44217_00005:
#   date: 2022-08-29_13-56-33
#   done: true
#   experiment_id: c94eb84f399444118b048627b4fe0b06
#   experiment_tag: 5_lr=0.0020,momentum=0.9037,weight_decay=0.0866
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 78.12
#   node_ip: 147.142.68.85
#   pid: 68420
#   time_since_restore: 567.7050523757935
#   time_this_iter_s: 290.75926899909973
#   time_total_s: 567.7050523757935
#   timestamp: 1661774193
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00005'
#   warmup_time: 0.0074727535247802734
#
# Result for train_mnist_44217_00007:
#   date: 2022-08-29_13-56-35
#   done: false
#   experiment_id: 11e34747c5244a82a2d4f9d182d7d9ad
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 86.53
#   node_ip: 147.142.68.85
#   pid: 68473
#   time_since_restore: 567.9743223190308
#   time_this_iter_s: 290.75550413131714
#   time_total_s: 567.9743223190308
#   timestamp: 1661774195
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00007'
#   warmup_time: 0.006163358688354492
#
# Result for train_mnist_44217_00007:
#   date: 2022-08-29_13-56-35
#   done: true
#   experiment_id: 11e34747c5244a82a2d4f9d182d7d9ad
#   experiment_tag: 7_lr=0.0012,momentum=0.9695,weight_decay=0.0586
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 86.53
#   node_ip: 147.142.68.85
#   pid: 68473
#   time_since_restore: 567.9743223190308
#   time_this_iter_s: 290.75550413131714
#   time_total_s: 567.9743223190308
#   timestamp: 1661774195
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00007'
#   warmup_time: 0.006163358688354492
#
# Result for train_mnist_44217_00006:
#   date: 2022-08-29_13-56-35
#   done: false
#   experiment_id: ec4c7f59f57644e292794b73bd774589
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 88.91
#   node_ip: 147.142.68.85
#   pid: 68446
#   time_since_restore: 569.062591791153
#   time_this_iter_s: 296.14353013038635
#   time_total_s: 569.062591791153
#   timestamp: 1661774195
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00006'
#   warmup_time: 0.006765604019165039
#
# Result for train_mnist_44217_00006:
#   date: 2022-08-29_13-56-35
#   done: true
#   experiment_id: ec4c7f59f57644e292794b73bd774589
#   experiment_tag: 6_lr=0.0404,momentum=0.8810,weight_decay=0.0303
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 88.91
#   node_ip: 147.142.68.85
#   pid: 68446
#   time_since_restore: 569.062591791153
#   time_this_iter_s: 296.14353013038635
#   time_total_s: 569.062591791153
#   timestamp: 1661774195
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00006'
#   warmup_time: 0.006765604019165039
#
# Result for train_mnist_44217_00008:
#   date: 2022-08-29_13-56-40
#   done: false
#   experiment_id: 50e6a810ffb949ec8e254964314d3c67
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 87.59
#   node_ip: 147.142.68.85
#   pid: 68683
#   time_since_restore: 565.3384470939636
#   time_this_iter_s: 283.3689606189728
#   time_total_s: 565.3384470939636
#   timestamp: 1661774200
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00008'
#   warmup_time: 0.022365093231201172
#
# Result for train_mnist_44217_00008:
#   date: 2022-08-29_13-56-40
#   done: true
#   experiment_id: 50e6a810ffb949ec8e254964314d3c67
#   experiment_tag: 8_lr=0.0010,momentum=0.8344,weight_decay=0.0214
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 87.59
#   node_ip: 147.142.68.85
#   pid: 68683
#   time_since_restore: 565.3384470939636
#   time_this_iter_s: 283.3689606189728
#   time_total_s: 565.3384470939636
#   timestamp: 1661774200
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00008'
#   warmup_time: 0.022365093231201172
#
# Result for train_mnist_44217_00009:
#   date: 2022-08-29_13-56-43
#   done: false
#   experiment_id: 0dc5d49be72549d4a966dfb7fbcf20f4
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 90.64
#   node_ip: 147.142.68.85
#   pid: 68816
#   time_since_restore: 559.3975577354431
#   time_this_iter_s: 278.2507791519165
#   time_total_s: 559.3975577354431
#   timestamp: 1661774203
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00009'
#   warmup_time: 0.016208410263061523
#
# Result for train_mnist_44217_00009:
#   date: 2022-08-29_13-56-43
#   done: true
#   experiment_id: 0dc5d49be72549d4a966dfb7fbcf20f4
#   experiment_tag: 9_lr=0.0174,momentum=0.9368,weight_decay=0.0268
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 90.64
#   node_ip: 147.142.68.85
#   pid: 68816
#   time_since_restore: 559.3975577354431
#   time_this_iter_s: 278.2507791519165
#   time_total_s: 559.3975577354431
#   timestamp: 1661774203
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00009'
#   warmup_time: 0.016208410263061523
#
# Result for train_mnist_44217_00010:
#   date: 2022-08-29_13-56-49
#   done: false
#   experiment_id: 70e93d0e9c51404b859a1b96c4e12e7b
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 94.66
#   node_ip: 147.142.68.85
#   pid: 68914
#   time_since_restore: 555.4885730743408
#   time_this_iter_s: 272.69080567359924
#   time_total_s: 555.4885730743408
#   timestamp: 1661774209
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00010'
#   warmup_time: 0.013387441635131836
#
# Result for train_mnist_44217_00010:
#   date: 2022-08-29_13-56-49
#   done: true
#   experiment_id: 70e93d0e9c51404b859a1b96c4e12e7b
#   experiment_tag: 10_lr=0.0589,momentum=0.8699,weight_decay=0.0383
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 94.66
#   node_ip: 147.142.68.85
#   pid: 68914
#   time_since_restore: 555.4885730743408
#   time_this_iter_s: 272.69080567359924
#   time_total_s: 555.4885730743408
#   timestamp: 1661774209
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00010'
#   warmup_time: 0.013387441635131836
#
# Result for train_mnist_44217_00011:
#   date: 2022-08-29_13-56-57
#   done: false
#   experiment_id: 9f492c1f733a4348a06376cd762dc258
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 94.63
#   node_ip: 147.142.68.85
#   pid: 69044
#   time_since_restore: 551.9852657318115
#   time_this_iter_s: 260.2366578578949
#   time_total_s: 551.9852657318115
#   timestamp: 1661774217
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00011'
#   warmup_time: 0.013059616088867188
#
# Result for train_mnist_44217_00011:
#   date: 2022-08-29_13-56-57
#   done: true
#   experiment_id: 9f492c1f733a4348a06376cd762dc258
#   experiment_tag: 11_lr=0.0136,momentum=0.8427,weight_decay=0.0271
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 94.63
#   node_ip: 147.142.68.85
#   pid: 69044
#   time_since_restore: 551.9852657318115
#   time_this_iter_s: 260.2366578578949
#   time_total_s: 551.9852657318115
#   timestamp: 1661774217
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00011'
#   warmup_time: 0.013059616088867188
#
# Result for train_mnist_44217_00013:
#   date: 2022-08-29_13-57-48
#   done: false
#   experiment_id: ea3a79f2a8c04b69be51b1ad36850f88
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 67.01
#   node_ip: 147.142.68.85
#   pid: 68362
#   time_since_restore: 91.47745871543884
#   time_this_iter_s: 91.47745871543884
#   time_total_s: 91.47745871543884
#   timestamp: 1661774268
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '44217_00013'
#   warmup_time: 0.0037386417388916016
#
# Result for train_mnist_44217_00014:
#   date: 2022-08-29_13-57-49
#   done: false
#   experiment_id: 2c9c3c2bc3ca408889728486f6a55c72
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 77.5
#   node_ip: 147.142.68.85
#   pid: 68364
#   time_since_restore: 88.93303632736206
#   time_this_iter_s: 88.93303632736206
#   time_total_s: 88.93303632736206
#   timestamp: 1661774269
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '44217_00014'
#   warmup_time: 0.004679203033447266
#
# Result for train_mnist_44217_00012:
#   date: 2022-08-29_13-57-50
#   done: false
#   experiment_id: c386d6390e1944f5a0fcf79467e8ebc5
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 85.57
#   node_ip: 147.142.68.85
#   pid: 68312
#   time_since_restore: 94.12912178039551
#   time_this_iter_s: 94.12912178039551
#   time_total_s: 94.12912178039551
#   timestamp: 1661774270
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '44217_00012'
#   warmup_time: 0.002355813980102539
#
# Result for train_mnist_44217_00013:
#   date: 2022-08-29_13-58-58
#   done: false
#   experiment_id: ea3a79f2a8c04b69be51b1ad36850f88
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 74.65
#   node_ip: 147.142.68.85
#   pid: 68362
#   time_since_restore: 160.79053926467896
#   time_this_iter_s: 69.31308054924011
#   time_total_s: 160.79053926467896
#   timestamp: 1661774338
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00013'
#   warmup_time: 0.0037386417388916016
#
# Result for train_mnist_44217_00013:
#   date: 2022-08-29_13-58-58
#   done: true
#   experiment_id: ea3a79f2a8c04b69be51b1ad36850f88
#   experiment_tag: 13_lr=0.0192,momentum=0.9972,weight_decay=0.0957
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 74.65
#   node_ip: 147.142.68.85
#   pid: 68362
#   time_since_restore: 160.79053926467896
#   time_this_iter_s: 69.31308054924011
#   time_total_s: 160.79053926467896
#   timestamp: 1661774338
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00013'
#   warmup_time: 0.0037386417388916016
#
# Result for train_mnist_44217_00014:
#   date: 2022-08-29_13-58-59
#   done: false
#   experiment_id: 2c9c3c2bc3ca408889728486f6a55c72
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 79.04
#   node_ip: 147.142.68.85
#   pid: 68364
#   time_since_restore: 159.0475368499756
#   time_this_iter_s: 70.11450052261353
#   time_total_s: 159.0475368499756
#   timestamp: 1661774339
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00014'
#   warmup_time: 0.004679203033447266
#
# Result for train_mnist_44217_00014:
#   date: 2022-08-29_13-58-59
#   done: true
#   experiment_id: 2c9c3c2bc3ca408889728486f6a55c72
#   experiment_tag: 14_lr=0.0205,momentum=0.8266,weight_decay=0.0908
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 79.04
#   node_ip: 147.142.68.85
#   pid: 68364
#   time_since_restore: 159.0475368499756
#   time_this_iter_s: 70.11450052261353
#   time_total_s: 159.0475368499756
#   timestamp: 1661774339
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00014'
#   warmup_time: 0.004679203033447266
#
# Result for train_mnist_44217_00012:
#   date: 2022-08-29_13-59-00
#   done: false
#   experiment_id: c386d6390e1944f5a0fcf79467e8ebc5
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 86.41
#   node_ip: 147.142.68.85
#   pid: 68312
#   time_since_restore: 164.27729105949402
#   time_this_iter_s: 70.14816927909851
#   time_total_s: 164.27729105949402
#   timestamp: 1661774340
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00012'
#   warmup_time: 0.002355813980102539
#
# Result for train_mnist_44217_00012:
#   date: 2022-08-29_13-59-00
#   done: true
#   experiment_id: c386d6390e1944f5a0fcf79467e8ebc5
#   experiment_tag: 12_lr=0.0021,momentum=0.9338,weight_decay=0.0553
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 86.41
#   node_ip: 147.142.68.85
#   pid: 68312
#   time_since_restore: 164.27729105949402
#   time_this_iter_s: 70.14816927909851
#   time_total_s: 164.27729105949402
#   timestamp: 1661774340
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: '44217_00012'
#   warmup_time: 0.002355813980102539
# 2022-08-29 13:59:00,316	INFO tune.py:758 -- Total run time: 731.87 seconds (730.86 seconds for the tuning loop).
# Best config:  {'lr': 0.0025282211848313913, 'momentum': 0.9274131119760397, 'weight_decay': 0.009248952703622115}

# %%
from Models import LeASLNet
input_shape = (batch_size, 1, 28, 28)
criterion = CrossEntropyLoss()

def train_mnist(config):
    test_device = "cpu"
    model = LeASLNet(input_shape, 10, initial_lr=config["lr"], momentum=config["momentum"], weight_decay=config["weight_decay"], device=test_device, expansion_rate=1).to(test_device)
    for i in range(2):
        train_NN(model, criterion, train_dataloader,
        test_dataloader, epochs=2, batches_to_test=100,patience=2,device=test_device, print_test=False, verbose=False)
        acc = test_loss(model, test_dataloader, criterion, test_device)[1]
        tune.report(mean_accuracy=acc)

analysis = tune.run(
    train_mnist, config={"lr": tune.grid_search([0.001, 0.01, 0.1]), "momentum": tune.grid_search([0.9, 0.99]), "weight_decay": tune.grid_search([0, 0.01, 0.1])})

print("Best config: ", analysis.get_best_config(metric="mean_accuracy", mode="max",))

# Get a dataframe for analyzing trial results.
df = analysis.dataframe()
# Out:
# 2022-08-29 14:19:38,106	INFO worker.py:1509 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 2022-08-29 14:19:39,130	WARNING function_trainable.py:619 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# == Status ==<br>Current time: 2022-08-29 14:34:37 (running for 00:14:57.59)<br>Memory usage on this node: 8.3/15.4 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/5.55 GiB heap, 0.0/2.78 GiB objects (0.0/1.0 accelerator_type:G)<br>Result logdir: /home/max/ray_results/train_mnist_2022-08-29_14-19-39<br>Number of trials: 18/18 (18 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name             </th><th>status    </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">  weight_decay</th><th style="text-align: right;">  acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>train_mnist_dacf6_00000</td><td>TERMINATED</td><td>147.142.68.85:83875</td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0   </td><td style="text-align: right;">91.45</td><td style="text-align: right;">     2</td><td style="text-align: right;">         536.509</td></tr>
# <tr><td>train_mnist_dacf6_00001</td><td>TERMINATED</td><td>147.142.68.85:83927</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0   </td><td style="text-align: right;">97.93</td><td style="text-align: right;">     2</td><td style="text-align: right;">         562.865</td></tr>
# <tr><td>train_mnist_dacf6_00002</td><td>TERMINATED</td><td>147.142.68.85:83930</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0   </td><td style="text-align: right;">98.69</td><td style="text-align: right;">     2</td><td style="text-align: right;">         557.857</td></tr>
# <tr><td>train_mnist_dacf6_00003</td><td>TERMINATED</td><td>147.142.68.85:83956</td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0   </td><td style="text-align: right;">97.32</td><td style="text-align: right;">     2</td><td style="text-align: right;">         558.735</td></tr>
# <tr><td>train_mnist_dacf6_00004</td><td>TERMINATED</td><td>147.142.68.85:83959</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0   </td><td style="text-align: right;">98.02</td><td style="text-align: right;">     2</td><td style="text-align: right;">         550.848</td></tr>
# <tr><td>train_mnist_dacf6_00005</td><td>TERMINATED</td><td>147.142.68.85:83982</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0   </td><td style="text-align: right;">10.09</td><td style="text-align: right;">     2</td><td style="text-align: right;">         558.601</td></tr>
# <tr><td>train_mnist_dacf6_00006</td><td>TERMINATED</td><td>147.142.68.85:84160</td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.01</td><td style="text-align: right;">91.36</td><td style="text-align: right;">     2</td><td style="text-align: right;">         575.619</td></tr>
# <tr><td>train_mnist_dacf6_00007</td><td>TERMINATED</td><td>147.142.68.85:84163</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.01</td><td style="text-align: right;">83.8 </td><td style="text-align: right;">     2</td><td style="text-align: right;">         572.41 </td></tr>
# <tr><td>train_mnist_dacf6_00008</td><td>TERMINATED</td><td>147.142.68.85:84349</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.01</td><td style="text-align: right;">96.83</td><td style="text-align: right;">     2</td><td style="text-align: right;">         570.339</td></tr>
# <tr><td>train_mnist_dacf6_00009</td><td>TERMINATED</td><td>147.142.68.85:84404</td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.01</td><td style="text-align: right;">95.29</td><td style="text-align: right;">     2</td><td style="text-align: right;">         577.206</td></tr>
# <tr><td>train_mnist_dacf6_00010</td><td>TERMINATED</td><td>147.142.68.85:84581</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.01</td><td style="text-align: right;">95.37</td><td style="text-align: right;">     2</td><td style="text-align: right;">         572.367</td></tr>
# <tr><td>train_mnist_dacf6_00011</td><td>TERMINATED</td><td>147.142.68.85:84649</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.01</td><td style="text-align: right;">93.59</td><td style="text-align: right;">     2</td><td style="text-align: right;">         566.655</td></tr>
# <tr><td>train_mnist_dacf6_00012</td><td>TERMINATED</td><td>147.142.68.85:83875</td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.1 </td><td style="text-align: right;">64.78</td><td style="text-align: right;">     2</td><td style="text-align: right;">         340.506</td></tr>
# <tr><td>train_mnist_dacf6_00013</td><td>TERMINATED</td><td>147.142.68.85:83959</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.1 </td><td style="text-align: right;">66.66</td><td style="text-align: right;">     2</td><td style="text-align: right;">         321.006</td></tr>
# <tr><td>train_mnist_dacf6_00014</td><td>TERMINATED</td><td>147.142.68.85:83930</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.1 </td><td style="text-align: right;">65.55</td><td style="text-align: right;">     2</td><td style="text-align: right;">         323.564</td></tr>
# <tr><td>train_mnist_dacf6_00015</td><td>TERMINATED</td><td>147.142.68.85:83956</td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.1 </td><td style="text-align: right;">11.35</td><td style="text-align: right;">     2</td><td style="text-align: right;">         319.901</td></tr>
# <tr><td>train_mnist_dacf6_00016</td><td>TERMINATED</td><td>147.142.68.85:83982</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.1 </td><td style="text-align: right;">11.35</td><td style="text-align: right;">     2</td><td style="text-align: right;">         322.021</td></tr>
# <tr><td>train_mnist_dacf6_00017</td><td>TERMINATED</td><td>147.142.68.85:83927</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.1 </td><td style="text-align: right;">76.4 </td><td style="text-align: right;">     2</td><td style="text-align: right;">         318.466</td></tr>
# </tbody>
# </table><br><br>
# 2022-08-29 14:19:48,093	WARNING worker.py:1829 -- Warning: The actor ImplicitFunc is very large (52 MiB). Check that its definition is not implicitly capturing a large array or other object in scope. Tip: use ray.put() to put large objects in the Ray object store.
# 2022-08-29 14:20:32,060	WARNING util.py:220 -- The `start_trial` operation took 1.035 s, which may be a performance bottleneck.
# Result for train_mnist_dacf6_00000:
#   date: 2022-08-29_14-23-55
#   done: false
#   experiment_id: 7079a85c0fc04a629399b20373dc3293
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 86.9
#   node_ip: 147.142.68.85
#   pid: 83875
#   time_since_restore: 245.56458640098572
#   time_this_iter_s: 245.56458640098572
#   time_total_s: 245.56458640098572
#   timestamp: 1661775835
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: dacf6_00000
#   warmup_time: 0.0023016929626464844
#
# Result for train_mnist_dacf6_00002:
#   date: 2022-08-29_14-24-17
#   done: false
#   experiment_id: 155fc01774114092ba5f488a31e405a0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 97.72
#   node_ip: 147.142.68.85
#   pid: 83930
#   time_since_restore: 262.0902826786041
#   time_this_iter_s: 262.0902826786041
#   time_total_s: 262.0902826786041
#   timestamp: 1661775857
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: dacf6_00002
#   warmup_time: 0.008280754089355469
#
# Result for train_mnist_dacf6_00001:
#   date: 2022-08-29_14-24-17
#   done: false
#   experiment_id: 0ce17d9cfa2044cb8fddf5f8300435f1
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 95.99
#   node_ip: 147.142.68.85
#   pid: 83927
#   time_since_restore: 263.46977257728577
#   time_this_iter_s: 263.46977257728577
#   time_total_s: 263.46977257728577
#   timestamp: 1661775857
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: dacf6_00001
#   warmup_time: 0.0030519962310791016
#
# Result for train_mnist_dacf6_00003:
#   date: 2022-08-29_14-24-18
#   done: false
#   experiment_id: e1d00ed9416b411b8a01b7b889f7bc2a
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 95.94
#   node_ip: 147.142.68.85
#   pid: 83956
#   time_since_restore: 262.82465648651123
#   time_this_iter_s: 262.82465648651123
#   time_total_s: 262.82465648651123
#   timestamp: 1661775858
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: dacf6_00003
#   warmup_time: 0.005101203918457031
#
# Result for train_mnist_dacf6_00004:
#   date: 2022-08-29_14-24-19
#   done: false
#   experiment_id: d5732706c94843cfa282ca7a37c17c13
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 96.88
#   node_ip: 147.142.68.85
#   pid: 83959
#   time_since_restore: 262.9804775714874
#   time_this_iter_s: 262.9804775714874
#   time_total_s: 262.9804775714874
#   timestamp: 1661775859
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: dacf6_00004
#   warmup_time: 0.008489131927490234
#
# Result for train_mnist_dacf6_00005:
#   date: 2022-08-29_14-24-23
#   done: false
#   experiment_id: 5ecc9a47b61c494b83558fd9fd8009b3
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 10.28
#   node_ip: 147.142.68.85
#   pid: 83982
#   time_since_restore: 266.6923623085022
#   time_this_iter_s: 266.6923623085022
#   time_total_s: 266.6923623085022
#   timestamp: 1661775863
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: dacf6_00005
#   warmup_time: 0.005768537521362305
#
# Result for train_mnist_dacf6_00007:
#   date: 2022-08-29_14-24-38
#   done: false
#   experiment_id: 3069810d59b448a9893698e14eee2e2f
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 77.64
#   node_ip: 147.142.68.85
#   pid: 84163
#   time_since_restore: 273.34850311279297
#   time_this_iter_s: 273.34850311279297
#   time_total_s: 273.34850311279297
#   timestamp: 1661775878
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: dacf6_00007
#   warmup_time: 0.011847257614135742
#
# Result for train_mnist_dacf6_00006:
#   date: 2022-08-29_14-24-40
#   done: false
#   experiment_id: 5e14cc9210de47f4b1962a9389e7a2d6
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 86.96
#   node_ip: 147.142.68.85
#   pid: 84160
#   time_since_restore: 275.5851366519928
#   time_this_iter_s: 275.5851366519928
#   time_total_s: 275.5851366519928
#   timestamp: 1661775880
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: dacf6_00006
#   warmup_time: 0.011911153793334961
#
# Result for train_mnist_dacf6_00008:
#   date: 2022-08-29_14-24-48
#   done: false
#   experiment_id: 82c127ccc35942e98dde55154636c2bf
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 94.09
#   node_ip: 147.142.68.85
#   pid: 84349
#   time_since_restore: 274.95664858818054
#   time_this_iter_s: 274.95664858818054
#   time_total_s: 274.95664858818054
#   timestamp: 1661775888
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: dacf6_00008
#   warmup_time: 0.01260232925415039
#
# Result for train_mnist_dacf6_00009:
#   date: 2022-08-29_14-25-03
#   done: false
#   experiment_id: 2dc6734b57344748be1cf15c679ef219
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 93.52
#   node_ip: 147.142.68.85
#   pid: 84404
#   time_since_restore: 281.1966154575348
#   time_this_iter_s: 281.1966154575348
#   time_total_s: 281.1966154575348
#   timestamp: 1661775903
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: dacf6_00009
#   warmup_time: 0.0180666446685791
#
# Result for train_mnist_dacf6_00010:
#   date: 2022-08-29_14-25-14
#   done: false
#   experiment_id: acf7aae528ac4a738b374acc7d9b2312
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 92.99
#   node_ip: 147.142.68.85
#   pid: 84581
#   time_since_restore: 283.85766768455505
#   time_this_iter_s: 283.85766768455505
#   time_total_s: 283.85766768455505
#   timestamp: 1661775914
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: dacf6_00010
#   warmup_time: 0.011073112487792969
#
# Result for train_mnist_dacf6_00011:
#   date: 2022-08-29_14-25-24
#   done: false
#   experiment_id: 6667ebbd45f34db79c73e20bf98299f4
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 52.46
#   node_ip: 147.142.68.85
#   pid: 84649
#   time_since_restore: 282.64245319366455
#   time_this_iter_s: 282.64245319366455
#   time_total_s: 282.64245319366455
#   timestamp: 1661775924
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: dacf6_00011
#   warmup_time: 0.017235279083251953
#
# Result for train_mnist_dacf6_00000:
#   date: 2022-08-29_14-28-46
#   done: false
#   experiment_id: 7079a85c0fc04a629399b20373dc3293
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 91.45
#   node_ip: 147.142.68.85
#   pid: 83875
#   time_since_restore: 536.5088758468628
#   time_this_iter_s: 290.9442894458771
#   time_total_s: 536.5088758468628
#   timestamp: 1661776126
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00000
#   warmup_time: 0.0023016929626464844
#
# Result for train_mnist_dacf6_00000:
#   date: 2022-08-29_14-28-46
#   done: true
#   experiment_id: 7079a85c0fc04a629399b20373dc3293
#   experiment_tag: 0_lr=0.0010,momentum=0.9000,weight_decay=0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 91.45
#   node_ip: 147.142.68.85
#   pid: 83875
#   time_since_restore: 536.5088758468628
#   time_this_iter_s: 290.9442894458771
#   time_total_s: 536.5088758468628
#   timestamp: 1661776126
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00000
#   warmup_time: 0.0023016929626464844
#
# Result for train_mnist_dacf6_00004:
#   date: 2022-08-29_14-29-07
#   done: false
#   experiment_id: d5732706c94843cfa282ca7a37c17c13
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 98.02
#   node_ip: 147.142.68.85
#   pid: 83959
#   time_since_restore: 550.8481612205505
#   time_this_iter_s: 287.8676836490631
#   time_total_s: 550.8481612205505
#   timestamp: 1661776147
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00004
#   warmup_time: 0.008489131927490234
#
# Result for train_mnist_dacf6_00004:
#   date: 2022-08-29_14-29-07
#   done: true
#   experiment_id: d5732706c94843cfa282ca7a37c17c13
#   experiment_tag: 4_lr=0.0100,momentum=0.9900,weight_decay=0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 98.02
#   node_ip: 147.142.68.85
#   pid: 83959
#   time_since_restore: 550.8481612205505
#   time_this_iter_s: 287.8676836490631
#   time_total_s: 550.8481612205505
#   timestamp: 1661776147
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00004
#   warmup_time: 0.008489131927490234
#
# Result for train_mnist_dacf6_00002:
#   date: 2022-08-29_14-29-13
#   done: false
#   experiment_id: 155fc01774114092ba5f488a31e405a0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 98.69
#   node_ip: 147.142.68.85
#   pid: 83930
#   time_since_restore: 557.8567848205566
#   time_this_iter_s: 295.7665021419525
#   time_total_s: 557.8567848205566
#   timestamp: 1661776153
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00002
#   warmup_time: 0.008280754089355469
#
# Result for train_mnist_dacf6_00002:
#   date: 2022-08-29_14-29-13
#   done: true
#   experiment_id: 155fc01774114092ba5f488a31e405a0
#   experiment_tag: 2_lr=0.1000,momentum=0.9000,weight_decay=0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 98.69
#   node_ip: 147.142.68.85
#   pid: 83930
#   time_since_restore: 557.8567848205566
#   time_this_iter_s: 295.7665021419525
#   time_total_s: 557.8567848205566
#   timestamp: 1661776153
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00002
#   warmup_time: 0.008280754089355469
#
# Result for train_mnist_dacf6_00003:
#   date: 2022-08-29_14-29-14
#   done: false
#   experiment_id: e1d00ed9416b411b8a01b7b889f7bc2a
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 97.32
#   node_ip: 147.142.68.85
#   pid: 83956
#   time_since_restore: 558.7349467277527
#   time_this_iter_s: 295.91029024124146
#   time_total_s: 558.7349467277527
#   timestamp: 1661776154
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00003
#   warmup_time: 0.005101203918457031
#
# Result for train_mnist_dacf6_00003:
#   date: 2022-08-29_14-29-14
#   done: true
#   experiment_id: e1d00ed9416b411b8a01b7b889f7bc2a
#   experiment_tag: 3_lr=0.0010,momentum=0.9900,weight_decay=0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 97.32
#   node_ip: 147.142.68.85
#   pid: 83956
#   time_since_restore: 558.7349467277527
#   time_this_iter_s: 295.91029024124146
#   time_total_s: 558.7349467277527
#   timestamp: 1661776154
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00003
#   warmup_time: 0.005101203918457031
#
# Result for train_mnist_dacf6_00005:
#   date: 2022-08-29_14-29-15
#   done: false
#   experiment_id: 5ecc9a47b61c494b83558fd9fd8009b3
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 10.09
#   node_ip: 147.142.68.85
#   pid: 83982
#   time_since_restore: 558.6014828681946
#   time_this_iter_s: 291.9091205596924
#   time_total_s: 558.6014828681946
#   timestamp: 1661776155
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00005
#   warmup_time: 0.005768537521362305
#
# Result for train_mnist_dacf6_00005:
#   date: 2022-08-29_14-29-15
#   done: true
#   experiment_id: 5ecc9a47b61c494b83558fd9fd8009b3
#   experiment_tag: 5_lr=0.1000,momentum=0.9900,weight_decay=0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 10.09
#   node_ip: 147.142.68.85
#   pid: 83982
#   time_since_restore: 558.6014828681946
#   time_this_iter_s: 291.9091205596924
#   time_total_s: 558.6014828681946
#   timestamp: 1661776155
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00005
#   warmup_time: 0.005768537521362305
#
# Result for train_mnist_dacf6_00001:
#   date: 2022-08-29_14-29-17
#   done: false
#   experiment_id: 0ce17d9cfa2044cb8fddf5f8300435f1
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 97.93
#   node_ip: 147.142.68.85
#   pid: 83927
#   time_since_restore: 562.8650441169739
#   time_this_iter_s: 299.3952715396881
#   time_total_s: 562.8650441169739
#   timestamp: 1661776157
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00001
#   warmup_time: 0.0030519962310791016
#
# Result for train_mnist_dacf6_00001:
#   date: 2022-08-29_14-29-17
#   done: true
#   experiment_id: 0ce17d9cfa2044cb8fddf5f8300435f1
#   experiment_tag: 1_lr=0.0100,momentum=0.9000,weight_decay=0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 97.93
#   node_ip: 147.142.68.85
#   pid: 83927
#   time_since_restore: 562.8650441169739
#   time_this_iter_s: 299.3952715396881
#   time_total_s: 562.8650441169739
#   timestamp: 1661776157
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00001
#   warmup_time: 0.0030519962310791016
#
# Result for train_mnist_dacf6_00007:
#   date: 2022-08-29_14-29-37
#   done: false
#   experiment_id: 3069810d59b448a9893698e14eee2e2f
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 83.8
#   node_ip: 147.142.68.85
#   pid: 84163
#   time_since_restore: 572.4103116989136
#   time_this_iter_s: 299.0618085861206
#   time_total_s: 572.4103116989136
#   timestamp: 1661776177
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00007
#   warmup_time: 0.011847257614135742
#
# Result for train_mnist_dacf6_00007:
#   date: 2022-08-29_14-29-37
#   done: true
#   experiment_id: 3069810d59b448a9893698e14eee2e2f
#   experiment_tag: 7_lr=0.0100,momentum=0.9000,weight_decay=0.0100
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 83.8
#   node_ip: 147.142.68.85
#   pid: 84163
#   time_since_restore: 572.4103116989136
#   time_this_iter_s: 299.0618085861206
#   time_total_s: 572.4103116989136
#   timestamp: 1661776177
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00007
#   warmup_time: 0.011847257614135742
#
# Result for train_mnist_dacf6_00006:
#   date: 2022-08-29_14-29-40
#   done: false
#   experiment_id: 5e14cc9210de47f4b1962a9389e7a2d6
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 91.36
#   node_ip: 147.142.68.85
#   pid: 84160
#   time_since_restore: 575.6187965869904
#   time_this_iter_s: 300.03365993499756
#   time_total_s: 575.6187965869904
#   timestamp: 1661776180
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00006
#   warmup_time: 0.011911153793334961
#
# Result for train_mnist_dacf6_00006:
#   date: 2022-08-29_14-29-40
#   done: true
#   experiment_id: 5e14cc9210de47f4b1962a9389e7a2d6
#   experiment_tag: 6_lr=0.0010,momentum=0.9000,weight_decay=0.0100
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 91.36
#   node_ip: 147.142.68.85
#   pid: 84160
#   time_since_restore: 575.6187965869904
#   time_this_iter_s: 300.03365993499756
#   time_total_s: 575.6187965869904
#   timestamp: 1661776180
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00006
#   warmup_time: 0.011911153793334961
#
# Result for train_mnist_dacf6_00008:
#   date: 2022-08-29_14-29-43
#   done: false
#   experiment_id: 82c127ccc35942e98dde55154636c2bf
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 96.83
#   node_ip: 147.142.68.85
#   pid: 84349
#   time_since_restore: 570.3392434120178
#   time_this_iter_s: 295.3825948238373
#   time_total_s: 570.3392434120178
#   timestamp: 1661776183
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00008
#   warmup_time: 0.01260232925415039
#
# Result for train_mnist_dacf6_00008:
#   date: 2022-08-29_14-29-43
#   done: true
#   experiment_id: 82c127ccc35942e98dde55154636c2bf
#   experiment_tag: 8_lr=0.1000,momentum=0.9000,weight_decay=0.0100
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 96.83
#   node_ip: 147.142.68.85
#   pid: 84349
#   time_since_restore: 570.3392434120178
#   time_this_iter_s: 295.3825948238373
#   time_total_s: 570.3392434120178
#   timestamp: 1661776183
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00008
#   warmup_time: 0.01260232925415039
#
# Result for train_mnist_dacf6_00009:
#   date: 2022-08-29_14-29-59
#   done: false
#   experiment_id: 2dc6734b57344748be1cf15c679ef219
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 95.29
#   node_ip: 147.142.68.85
#   pid: 84404
#   time_since_restore: 577.2058925628662
#   time_this_iter_s: 296.0092771053314
#   time_total_s: 577.2058925628662
#   timestamp: 1661776199
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00009
#   warmup_time: 0.0180666446685791
#
# Result for train_mnist_dacf6_00009:
#   date: 2022-08-29_14-29-59
#   done: true
#   experiment_id: 2dc6734b57344748be1cf15c679ef219
#   experiment_tag: 9_lr=0.0010,momentum=0.9900,weight_decay=0.0100
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 95.29
#   node_ip: 147.142.68.85
#   pid: 84404
#   time_since_restore: 577.2058925628662
#   time_this_iter_s: 296.0092771053314
#   time_total_s: 577.2058925628662
#   timestamp: 1661776199
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00009
#   warmup_time: 0.0180666446685791
#
# Result for train_mnist_dacf6_00010:
#   date: 2022-08-29_14-30-03
#   done: false
#   experiment_id: acf7aae528ac4a738b374acc7d9b2312
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 95.37
#   node_ip: 147.142.68.85
#   pid: 84581
#   time_since_restore: 572.3672335147858
#   time_this_iter_s: 288.5095658302307
#   time_total_s: 572.3672335147858
#   timestamp: 1661776203
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00010
#   warmup_time: 0.011073112487792969
#
# Result for train_mnist_dacf6_00010:
#   date: 2022-08-29_14-30-03
#   done: true
#   experiment_id: acf7aae528ac4a738b374acc7d9b2312
#   experiment_tag: 10_lr=0.0100,momentum=0.9900,weight_decay=0.0100
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 95.37
#   node_ip: 147.142.68.85
#   pid: 84581
#   time_since_restore: 572.3672335147858
#   time_this_iter_s: 288.5095658302307
#   time_total_s: 572.3672335147858
#   timestamp: 1661776203
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00010
#   warmup_time: 0.011073112487792969
#
# Result for train_mnist_dacf6_00011:
#   date: 2022-08-29_14-30-08
#   done: false
#   experiment_id: 6667ebbd45f34db79c73e20bf98299f4
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 93.59
#   node_ip: 147.142.68.85
#   pid: 84649
#   time_since_restore: 566.6545248031616
#   time_this_iter_s: 284.01207160949707
#   time_total_s: 566.6545248031616
#   timestamp: 1661776208
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00011
#   warmup_time: 0.017235279083251953
#
# Result for train_mnist_dacf6_00011:
#   date: 2022-08-29_14-30-08
#   done: true
#   experiment_id: 6667ebbd45f34db79c73e20bf98299f4
#   experiment_tag: 11_lr=0.1000,momentum=0.9900,weight_decay=0.0100
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 93.59
#   node_ip: 147.142.68.85
#   pid: 84649
#   time_since_restore: 566.6545248031616
#   time_this_iter_s: 284.01207160949707
#   time_total_s: 566.6545248031616
#   timestamp: 1661776208
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00011
#   warmup_time: 0.017235279083251953
#
# Result for train_mnist_dacf6_00012:
#   date: 2022-08-29_14-31-57
#   done: false
#   experiment_id: 7079a85c0fc04a629399b20373dc3293
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 41.65
#   node_ip: 147.142.68.85
#   pid: 83875
#   time_since_restore: 190.5228123664856
#   time_this_iter_s: 190.5228123664856
#   time_total_s: 190.5228123664856
#   timestamp: 1661776317
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: dacf6_00012
#   warmup_time: 0.0023016929626464844
#
# Result for train_mnist_dacf6_00013:
#   date: 2022-08-29_14-32-01
#   done: false
#   experiment_id: d5732706c94843cfa282ca7a37c17c13
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 66.33
#   node_ip: 147.142.68.85
#   pid: 83959
#   time_since_restore: 174.00107622146606
#   time_this_iter_s: 174.00107622146606
#   time_total_s: 174.00107622146606
#   timestamp: 1661776321
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: dacf6_00013
#   warmup_time: 0.008489131927490234
#
# Result for train_mnist_dacf6_00014:
#   date: 2022-08-29_14-32-06
#   done: false
#   experiment_id: 155fc01774114092ba5f488a31e405a0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 63.99
#   node_ip: 147.142.68.85
#   pid: 83930
#   time_since_restore: 173.41724514961243
#   time_this_iter_s: 173.41724514961243
#   time_total_s: 173.41724514961243
#   timestamp: 1661776326
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: dacf6_00014
#   warmup_time: 0.008280754089355469
#
# Result for train_mnist_dacf6_00015:
#   date: 2022-08-29_14-32-09
#   done: false
#   experiment_id: e1d00ed9416b411b8a01b7b889f7bc2a
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 11.35
#   node_ip: 147.142.68.85
#   pid: 83956
#   time_since_restore: 174.48565316200256
#   time_this_iter_s: 174.48565316200256
#   time_total_s: 174.48565316200256
#   timestamp: 1661776329
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: dacf6_00015
#   warmup_time: 0.005101203918457031
#
# Result for train_mnist_dacf6_00016:
#   date: 2022-08-29_14-32-09
#   done: false
#   experiment_id: 5ecc9a47b61c494b83558fd9fd8009b3
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 11.35
#   node_ip: 147.142.68.85
#   pid: 83982
#   time_since_restore: 173.69266319274902
#   time_this_iter_s: 173.69266319274902
#   time_total_s: 173.69266319274902
#   timestamp: 1661776329
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: dacf6_00016
#   warmup_time: 0.005768537521362305
#
# Result for train_mnist_dacf6_00017:
#   date: 2022-08-29_14-32-10
#   done: false
#   experiment_id: 0ce17d9cfa2044cb8fddf5f8300435f1
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 66.38
#   node_ip: 147.142.68.85
#   pid: 83927
#   time_since_restore: 173.15358233451843
#   time_this_iter_s: 173.15358233451843
#   time_total_s: 173.15358233451843
#   timestamp: 1661776330
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: dacf6_00017
#   warmup_time: 0.0030519962310791016
#
# Result for train_mnist_dacf6_00012:
#   date: 2022-08-29_14-34-27
#   done: false
#   experiment_id: 7079a85c0fc04a629399b20373dc3293
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 64.78
#   node_ip: 147.142.68.85
#   pid: 83875
#   time_since_restore: 340.50611543655396
#   time_this_iter_s: 149.98330307006836
#   time_total_s: 340.50611543655396
#   timestamp: 1661776467
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00012
#   warmup_time: 0.0023016929626464844
#
# Result for train_mnist_dacf6_00012:
#   date: 2022-08-29_14-34-27
#   done: true
#   experiment_id: 7079a85c0fc04a629399b20373dc3293
#   experiment_tag: 12_lr=0.0010,momentum=0.9000,weight_decay=0.1000
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 64.78
#   node_ip: 147.142.68.85
#   pid: 83875
#   time_since_restore: 340.50611543655396
#   time_this_iter_s: 149.98330307006836
#   time_total_s: 340.50611543655396
#   timestamp: 1661776467
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00012
#   warmup_time: 0.0023016929626464844
#
# Result for train_mnist_dacf6_00013:
#   date: 2022-08-29_14-34-28
#   done: false
#   experiment_id: d5732706c94843cfa282ca7a37c17c13
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 66.66
#   node_ip: 147.142.68.85
#   pid: 83959
#   time_since_restore: 321.0056812763214
#   time_this_iter_s: 147.00460505485535
#   time_total_s: 321.0056812763214
#   timestamp: 1661776468
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00013
#   warmup_time: 0.008489131927490234
#
# Result for train_mnist_dacf6_00013:
#   date: 2022-08-29_14-34-28
#   done: true
#   experiment_id: d5732706c94843cfa282ca7a37c17c13
#   experiment_tag: 13_lr=0.0100,momentum=0.9000,weight_decay=0.1000
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 66.66
#   node_ip: 147.142.68.85
#   pid: 83959
#   time_since_restore: 321.0056812763214
#   time_this_iter_s: 147.00460505485535
#   time_total_s: 321.0056812763214
#   timestamp: 1661776468
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00013
#   warmup_time: 0.008489131927490234
#
# Result for train_mnist_dacf6_00015:
#   date: 2022-08-29_14-34-34
#   done: false
#   experiment_id: e1d00ed9416b411b8a01b7b889f7bc2a
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 11.35
#   node_ip: 147.142.68.85
#   pid: 83956
#   time_since_restore: 319.9007143974304
#   time_this_iter_s: 145.41506123542786
#   time_total_s: 319.9007143974304
#   timestamp: 1661776474
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00015
#   warmup_time: 0.005101203918457031
#
# Result for train_mnist_dacf6_00015:
#   date: 2022-08-29_14-34-34
#   done: true
#   experiment_id: e1d00ed9416b411b8a01b7b889f7bc2a
#   experiment_tag: 15_lr=0.0010,momentum=0.9900,weight_decay=0.1000
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 11.35
#   node_ip: 147.142.68.85
#   pid: 83956
#   time_since_restore: 319.9007143974304
#   time_this_iter_s: 145.41506123542786
#   time_total_s: 319.9007143974304
#   timestamp: 1661776474
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00015
#   warmup_time: 0.005101203918457031
#
# Result for train_mnist_dacf6_00017:
#   date: 2022-08-29_14-34-35
#   done: false
#   experiment_id: 0ce17d9cfa2044cb8fddf5f8300435f1
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 76.4
#   node_ip: 147.142.68.85
#   pid: 83927
#   time_since_restore: 318.465904712677
#   time_this_iter_s: 145.31232237815857
#   time_total_s: 318.465904712677
#   timestamp: 1661776475
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00017
#   warmup_time: 0.0030519962310791016
#
# Result for train_mnist_dacf6_00017:
#   date: 2022-08-29_14-34-35
#   done: true
#   experiment_id: 0ce17d9cfa2044cb8fddf5f8300435f1
#   experiment_tag: 17_lr=0.1000,momentum=0.9900,weight_decay=0.1000
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 76.4
#   node_ip: 147.142.68.85
#   pid: 83927
#   time_since_restore: 318.465904712677
#   time_this_iter_s: 145.31232237815857
#   time_total_s: 318.465904712677
#   timestamp: 1661776475
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00017
#   warmup_time: 0.0030519962310791016
#
# Result for train_mnist_dacf6_00014:
#   date: 2022-08-29_14-34-36
#   done: false
#   experiment_id: 155fc01774114092ba5f488a31e405a0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 65.55
#   node_ip: 147.142.68.85
#   pid: 83930
#   time_since_restore: 323.5642249584198
#   time_this_iter_s: 150.14697980880737
#   time_total_s: 323.5642249584198
#   timestamp: 1661776476
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00014
#   warmup_time: 0.008280754089355469
#
# Result for train_mnist_dacf6_00014:
#   date: 2022-08-29_14-34-36
#   done: true
#   experiment_id: 155fc01774114092ba5f488a31e405a0
#   experiment_tag: 14_lr=0.1000,momentum=0.9000,weight_decay=0.1000
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 65.55
#   node_ip: 147.142.68.85
#   pid: 83930
#   time_since_restore: 323.5642249584198
#   time_this_iter_s: 150.14697980880737
#   time_total_s: 323.5642249584198
#   timestamp: 1661776476
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00014
#   warmup_time: 0.008280754089355469
#
# Result for train_mnist_dacf6_00016:
#   date: 2022-08-29_14-34-37
#   done: false
#   experiment_id: 5ecc9a47b61c494b83558fd9fd8009b3
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 11.35
#   node_ip: 147.142.68.85
#   pid: 83982
#   time_since_restore: 322.02067255973816
#   time_this_iter_s: 148.32800936698914
#   time_total_s: 322.02067255973816
#   timestamp: 1661776477
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00016
#   warmup_time: 0.005768537521362305
#
# Result for train_mnist_dacf6_00016:
#   date: 2022-08-29_14-34-37
#   done: true
#   experiment_id: 5ecc9a47b61c494b83558fd9fd8009b3
#   experiment_tag: 16_lr=0.0100,momentum=0.9900,weight_decay=0.1000
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 11.35
#   node_ip: 147.142.68.85
#   pid: 83982
#   time_since_restore: 322.02067255973816
#   time_this_iter_s: 148.32800936698914
#   time_total_s: 322.02067255973816
#   timestamp: 1661776477
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dacf6_00016
#   warmup_time: 0.005768537521362305
# 2022-08-29 14:34:38,071	INFO tune.py:758 -- Total run time: 898.94 seconds (897.58 seconds for the tuning loop).
# Best config:  {'lr': 0.1, 'momentum': 0.9, 'weight_decay': 0}

# %%
from Models import LeNet
input_shape = (batch_size, 1, 28, 28)
criterion = CrossEntropyLoss()

def train_mnist(config):
    test_device = "cpu"
    model = LeNet(input_shape, 10, initial_lr=config["lr"], momentum=config["momentum"], weight_decay=config["weight_decay"]).to(test_device)
    for i in range(2):
        train_NN(model, criterion, train_dataloader,
        test_dataloader, epochs=2, batches_to_test=100,patience=2,device=test_device, print_test=False, verbose=False)
        acc = test_loss(model, test_dataloader, criterion, test_device)[1]
        tune.report(mean_accuracy=acc)

analysis = tune.run(
    train_mnist, config={"lr": tune.grid_search([0.001, 0.01, 0.1]), "momentum": tune.grid_search([0.9, 0.99]), "weight_decay": tune.grid_search([0, 0.01, 0.1])})

print("Best config: ", analysis.get_best_config(metric="mean_accuracy", mode="max",))

# Get a dataframe for analyzing trial results.
df = analysis.dataframe()
# Out:
# == Status ==<br>Current time: 2022-08-29 15:07:06 (running for 00:11:45.68)<br>Memory usage on this node: 8.4/15.4 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/5.55 GiB heap, 0.0/2.78 GiB objects (0.0/1.0 accelerator_type:G)<br>Result logdir: /home/max/ray_results/train_mnist_2022-08-29_14-55-20<br>Number of trials: 18/18 (18 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name             </th><th>status    </th><th>loc                </th><th style="text-align: right;">   lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">  weight_decay</th><th style="text-align: right;">  acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>train_mnist_d6d05_00000</td><td>TERMINATED</td><td>147.142.68.85:96840</td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0   </td><td style="text-align: right;">95.77</td><td style="text-align: right;">     2</td><td style="text-align: right;">         430.805</td></tr>
# <tr><td>train_mnist_d6d05_00001</td><td>TERMINATED</td><td>147.142.68.85:96891</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0   </td><td style="text-align: right;">94.67</td><td style="text-align: right;">     2</td><td style="text-align: right;">         444.224</td></tr>
# <tr><td>train_mnist_d6d05_00002</td><td>TERMINATED</td><td>147.142.68.85:96898</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0   </td><td style="text-align: right;">99.07</td><td style="text-align: right;">     2</td><td style="text-align: right;">         444.087</td></tr>
# <tr><td>train_mnist_d6d05_00003</td><td>TERMINATED</td><td>147.142.68.85:96920</td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0   </td><td style="text-align: right;">98.35</td><td style="text-align: right;">     2</td><td style="text-align: right;">         450.634</td></tr>
# <tr><td>train_mnist_d6d05_00004</td><td>TERMINATED</td><td>147.142.68.85:96922</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0   </td><td style="text-align: right;">98.67</td><td style="text-align: right;">     2</td><td style="text-align: right;">         438.771</td></tr>
# <tr><td>train_mnist_d6d05_00005</td><td>TERMINATED</td><td>147.142.68.85:96962</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0   </td><td style="text-align: right;">30.74</td><td style="text-align: right;">     2</td><td style="text-align: right;">         444.898</td></tr>
# <tr><td>train_mnist_d6d05_00006</td><td>TERMINATED</td><td>147.142.68.85:97124</td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.01</td><td style="text-align: right;">96.17</td><td style="text-align: right;">     2</td><td style="text-align: right;">         461.305</td></tr>
# <tr><td>train_mnist_d6d05_00007</td><td>TERMINATED</td><td>147.142.68.85:97127</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.01</td><td style="text-align: right;">93.32</td><td style="text-align: right;">     2</td><td style="text-align: right;">         460.013</td></tr>
# <tr><td>train_mnist_d6d05_00008</td><td>TERMINATED</td><td>147.142.68.85:97310</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.01</td><td style="text-align: right;">97.27</td><td style="text-align: right;">     2</td><td style="text-align: right;">         455.669</td></tr>
# <tr><td>train_mnist_d6d05_00009</td><td>TERMINATED</td><td>147.142.68.85:97393</td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.01</td><td style="text-align: right;">95.66</td><td style="text-align: right;">     2</td><td style="text-align: right;">         457.808</td></tr>
# <tr><td>train_mnist_d6d05_00010</td><td>TERMINATED</td><td>147.142.68.85:97540</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.01</td><td style="text-align: right;">93.16</td><td style="text-align: right;">     2</td><td style="text-align: right;">         455.011</td></tr>
# <tr><td>train_mnist_d6d05_00011</td><td>TERMINATED</td><td>147.142.68.85:97622</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.01</td><td style="text-align: right;">90.6 </td><td style="text-align: right;">     2</td><td style="text-align: right;">         450.983</td></tr>
# <tr><td>train_mnist_d6d05_00012</td><td>TERMINATED</td><td>147.142.68.85:96840</td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.1 </td><td style="text-align: right;">79.84</td><td style="text-align: right;">     2</td><td style="text-align: right;">         251.329</td></tr>
# <tr><td>train_mnist_d6d05_00013</td><td>TERMINATED</td><td>147.142.68.85:96922</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.1 </td><td style="text-align: right;">88.69</td><td style="text-align: right;">     2</td><td style="text-align: right;">         241.357</td></tr>
# <tr><td>train_mnist_d6d05_00014</td><td>TERMINATED</td><td>147.142.68.85:96891</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.9 </td><td style="text-align: right;">          0.1 </td><td style="text-align: right;">67.1 </td><td style="text-align: right;">     2</td><td style="text-align: right;">         246.923</td></tr>
# <tr><td>train_mnist_d6d05_00015</td><td>TERMINATED</td><td>147.142.68.85:96898</td><td style="text-align: right;">0.001</td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.1 </td><td style="text-align: right;">76.32</td><td style="text-align: right;">     2</td><td style="text-align: right;">         243.662</td></tr>
# <tr><td>train_mnist_d6d05_00016</td><td>TERMINATED</td><td>147.142.68.85:96962</td><td style="text-align: right;">0.01 </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.1 </td><td style="text-align: right;">62.91</td><td style="text-align: right;">     2</td><td style="text-align: right;">         241.595</td></tr>
# <tr><td>train_mnist_d6d05_00017</td><td>TERMINATED</td><td>147.142.68.85:96920</td><td style="text-align: right;">0.1  </td><td style="text-align: right;">      0.99</td><td style="text-align: right;">          0.1 </td><td style="text-align: right;">61.59</td><td style="text-align: right;">     2</td><td style="text-align: right;">         237.789</td></tr>
# </tbody>
# </table><br><br>
# 2022-08-29 14:55:29,402	WARNING worker.py:1829 -- Warning: The actor ImplicitFunc is very large (52 MiB). Check that its definition is not implicitly capturing a large array or other object in scope. Tip: use ray.put() to put large objects in the Ray object store.
# 2022-08-29 14:55:29,523	WARNING util.py:220 -- The `start_trial` operation took 0.875 s, which may be a performance bottleneck.
# 2022-08-29 14:55:39,059	WARNING util.py:220 -- The `start_trial` operation took 0.712 s, which may be a performance bottleneck.
# 2022-08-29 14:55:39,790	WARNING util.py:220 -- The `start_trial` operation took 0.728 s, which may be a performance bottleneck.
# 2022-08-29 14:55:45,867	WARNING util.py:220 -- The `start_trial` operation took 0.784 s, which may be a performance bottleneck.
# 2022-08-29 14:55:52,663	WARNING util.py:220 -- The `start_trial` operation took 0.834 s, which may be a performance bottleneck.
# 2022-08-29 14:55:59,831	WARNING util.py:220 -- The `start_trial` operation took 0.896 s, which may be a performance bottleneck.
# 2022-08-29 14:56:07,712	WARNING util.py:220 -- The `start_trial` operation took 0.918 s, which may be a performance bottleneck.
# Result for train_mnist_d6d05_00000:
#   date: 2022-08-29_14-58-48
#   done: false
#   experiment_id: 6eb2d6ddb1ca433a98476d01ce30bb94
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 91.01
#   node_ip: 147.142.68.85
#   pid: 96840
#   time_since_restore: 196.7659192085266
#   time_this_iter_s: 196.7659192085266
#   time_total_s: 196.7659192085266
#   timestamp: 1661777928
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00000
#   warmup_time: 0.0029163360595703125
#
# Result for train_mnist_d6d05_00001:
#   date: 2022-08-29_14-59-00
#   done: false
#   experiment_id: 09dead0ff7394abfba708c66d4c6fb7e
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 84.55
#   node_ip: 147.142.68.85
#   pid: 96891
#   time_since_restore: 205.38097524642944
#   time_this_iter_s: 205.38097524642944
#   time_total_s: 205.38097524642944
#   timestamp: 1661777940
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00001
#   warmup_time: 0.002808094024658203
#
# Result for train_mnist_d6d05_00004:
#   date: 2022-08-29_14-59-06
#   done: false
#   experiment_id: 3e54a894655340fa9993945b657772e0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 97.8
#   node_ip: 147.142.68.85
#   pid: 96922
#   time_since_restore: 209.13505721092224
#   time_this_iter_s: 209.13505721092224
#   time_total_s: 209.13505721092224
#   timestamp: 1661777946
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00004
#   warmup_time: 0.004798173904418945
#
# Result for train_mnist_d6d05_00002:
#   date: 2022-08-29_14-59-10
#   done: false
#   experiment_id: 3564bc84c2d7442398ab5c644993d1a4
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 77.21
#   node_ip: 147.142.68.85
#   pid: 96898
#   time_since_restore: 214.52799344062805
#   time_this_iter_s: 214.52799344062805
#   time_total_s: 214.52799344062805
#   timestamp: 1661777950
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00002
#   warmup_time: 0.004522562026977539
#
# Result for train_mnist_d6d05_00005:
#   date: 2022-08-29_14-59-12
#   done: false
#   experiment_id: b3701e47210e430fa1ed6425754c2461
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 20.87
#   node_ip: 147.142.68.85
#   pid: 96962
#   time_since_restore: 213.7410593032837
#   time_this_iter_s: 213.7410593032837
#   time_total_s: 213.7410593032837
#   timestamp: 1661777952
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00005
#   warmup_time: 0.004241228103637695
#
# Result for train_mnist_d6d05_00003:
#   date: 2022-08-29_14-59-13
#   done: false
#   experiment_id: 0e90858623cb450eaa85859ec5da25fc
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 93.92
#   node_ip: 147.142.68.85
#   pid: 96920
#   time_since_restore: 216.29233765602112
#   time_this_iter_s: 216.29233765602112
#   time_total_s: 216.29233765602112
#   timestamp: 1661777953
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00003
#   warmup_time: 0.0043027400970458984
#
# Result for train_mnist_d6d05_00006:
#   date: 2022-08-29_14-59-29
#   done: false
#   experiment_id: 2fe3b689ad5941b9aaca9d3af3b26b0c
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 92.27
#   node_ip: 147.142.68.85
#   pid: 97124
#   time_since_restore: 225.0220763683319
#   time_this_iter_s: 225.0220763683319
#   time_total_s: 225.0220763683319
#   timestamp: 1661777969
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00006
#   warmup_time: 0.004260063171386719
#
# Result for train_mnist_d6d05_00007:
#   date: 2022-08-29_14-59-30
#   done: false
#   experiment_id: ce329c6a43fa4ec2849a25f88c1e70a4
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 84.12
#   node_ip: 147.142.68.85
#   pid: 97127
#   time_since_restore: 225.21538496017456
#   time_this_iter_s: 225.21538496017456
#   time_total_s: 225.21538496017456
#   timestamp: 1661777970
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00007
#   warmup_time: 0.00983572006225586
#
# Result for train_mnist_d6d05_00008:
#   date: 2022-08-29_14-59-35
#   done: false
#   experiment_id: f04744bd2c524396b7729fee139bf300
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 85.69
#   node_ip: 147.142.68.85
#   pid: 97310
#   time_since_restore: 223.18477821350098
#   time_this_iter_s: 223.18477821350098
#   time_total_s: 223.18477821350098
#   timestamp: 1661777975
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00008
#   warmup_time: 0.009851455688476562
#
# Result for train_mnist_d6d05_00009:
#   date: 2022-08-29_14-59-46
#   done: false
#   experiment_id: 3a01de2a0b6c4a7787c17638a7900b85
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 96.86
#   node_ip: 147.142.68.85
#   pid: 97393
#   time_since_restore: 227.87822222709656
#   time_this_iter_s: 227.87822222709656
#   time_total_s: 227.87822222709656
#   timestamp: 1661777986
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00009
#   warmup_time: 0.012578010559082031
#
# Result for train_mnist_d6d05_00010:
#   date: 2022-08-29_14-59-57
#   done: false
#   experiment_id: 21b6c0002646473db9af64d3d9725dae
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 95.64
#   node_ip: 147.142.68.85
#   pid: 97540
#   time_since_restore: 230.47767400741577
#   time_this_iter_s: 230.47767400741577
#   time_total_s: 230.47767400741577
#   timestamp: 1661777997
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00010
#   warmup_time: 0.017763853073120117
#
# Result for train_mnist_d6d05_00011:
#   date: 2022-08-29_15-00-05
#   done: false
#   experiment_id: 070c5ce040f74800b1e8f38246149c75
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 60.41
#   node_ip: 147.142.68.85
#   pid: 97622
#   time_since_restore: 230.84846806526184
#   time_this_iter_s: 230.84846806526184
#   time_total_s: 230.84846806526184
#   timestamp: 1661778005
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00011
#   warmup_time: 0.012460708618164062
#
# Result for train_mnist_d6d05_00000:
#   date: 2022-08-29_15-02-42
#   done: false
#   experiment_id: 6eb2d6ddb1ca433a98476d01ce30bb94
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 95.77
#   node_ip: 147.142.68.85
#   pid: 96840
#   time_since_restore: 430.80548572540283
#   time_this_iter_s: 234.03956651687622
#   time_total_s: 430.80548572540283
#   timestamp: 1661778162
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00000
#   warmup_time: 0.0029163360595703125
#
# Result for train_mnist_d6d05_00000:
#   date: 2022-08-29_15-02-42
#   done: true
#   experiment_id: 6eb2d6ddb1ca433a98476d01ce30bb94
#   experiment_tag: 0_lr=0.0010,momentum=0.9000,weight_decay=0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 95.77
#   node_ip: 147.142.68.85
#   pid: 96840
#   time_since_restore: 430.80548572540283
#   time_this_iter_s: 234.03956651687622
#   time_total_s: 430.80548572540283
#   timestamp: 1661778162
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00000
#   warmup_time: 0.0029163360595703125
#
# Result for train_mnist_d6d05_00004:
#   date: 2022-08-29_15-02-56
#   done: false
#   experiment_id: 3e54a894655340fa9993945b657772e0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 98.67
#   node_ip: 147.142.68.85
#   pid: 96922
#   time_since_restore: 438.77088379859924
#   time_this_iter_s: 229.635826587677
#   time_total_s: 438.77088379859924
#   timestamp: 1661778176
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00004
#   warmup_time: 0.004798173904418945
#
# Result for train_mnist_d6d05_00004:
#   date: 2022-08-29_15-02-56
#   done: true
#   experiment_id: 3e54a894655340fa9993945b657772e0
#   experiment_tag: 4_lr=0.0100,momentum=0.9900,weight_decay=0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 98.67
#   node_ip: 147.142.68.85
#   pid: 96922
#   time_since_restore: 438.77088379859924
#   time_this_iter_s: 229.635826587677
#   time_total_s: 438.77088379859924
#   timestamp: 1661778176
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00004
#   warmup_time: 0.004798173904418945
#
# Result for train_mnist_d6d05_00001:
#   date: 2022-08-29_15-02-59
#   done: false
#   experiment_id: 09dead0ff7394abfba708c66d4c6fb7e
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 94.67
#   node_ip: 147.142.68.85
#   pid: 96891
#   time_since_restore: 444.22418308258057
#   time_this_iter_s: 238.84320783615112
#   time_total_s: 444.22418308258057
#   timestamp: 1661778179
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00001
#   warmup_time: 0.002808094024658203
#
# Result for train_mnist_d6d05_00001:
#   date: 2022-08-29_15-02-59
#   done: true
#   experiment_id: 09dead0ff7394abfba708c66d4c6fb7e
#   experiment_tag: 1_lr=0.0100,momentum=0.9000,weight_decay=0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 94.67
#   node_ip: 147.142.68.85
#   pid: 96891
#   time_since_restore: 444.22418308258057
#   time_this_iter_s: 238.84320783615112
#   time_total_s: 444.22418308258057
#   timestamp: 1661778179
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00001
#   warmup_time: 0.002808094024658203
#
# Result for train_mnist_d6d05_00002:
#   date: 2022-08-29_15-03-00
#   done: false
#   experiment_id: 3564bc84c2d7442398ab5c644993d1a4
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 99.07
#   node_ip: 147.142.68.85
#   pid: 96898
#   time_since_restore: 444.08652544021606
#   time_this_iter_s: 229.558531999588
#   time_total_s: 444.08652544021606
#   timestamp: 1661778180
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00002
#   warmup_time: 0.004522562026977539
#
# Result for train_mnist_d6d05_00002:
#   date: 2022-08-29_15-03-00
#   done: true
#   experiment_id: 3564bc84c2d7442398ab5c644993d1a4
#   experiment_tag: 2_lr=0.1000,momentum=0.9000,weight_decay=0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 99.07
#   node_ip: 147.142.68.85
#   pid: 96898
#   time_since_restore: 444.08652544021606
#   time_this_iter_s: 229.558531999588
#   time_total_s: 444.08652544021606
#   timestamp: 1661778180
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00002
#   warmup_time: 0.004522562026977539
#
# Result for train_mnist_d6d05_00005:
#   date: 2022-08-29_15-03-03
#   done: false
#   experiment_id: b3701e47210e430fa1ed6425754c2461
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 30.74
#   node_ip: 147.142.68.85
#   pid: 96962
#   time_since_restore: 444.8980641365051
#   time_this_iter_s: 231.15700483322144
#   time_total_s: 444.8980641365051
#   timestamp: 1661778183
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00005
#   warmup_time: 0.004241228103637695
#
# Result for train_mnist_d6d05_00005:
#   date: 2022-08-29_15-03-03
#   done: true
#   experiment_id: b3701e47210e430fa1ed6425754c2461
#   experiment_tag: 5_lr=0.1000,momentum=0.9900,weight_decay=0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 30.74
#   node_ip: 147.142.68.85
#   pid: 96962
#   time_since_restore: 444.8980641365051
#   time_this_iter_s: 231.15700483322144
#   time_total_s: 444.8980641365051
#   timestamp: 1661778183
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00005
#   warmup_time: 0.004241228103637695
#
# Result for train_mnist_d6d05_00003:
#   date: 2022-08-29_15-03-07
#   done: false
#   experiment_id: 0e90858623cb450eaa85859ec5da25fc
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 98.35
#   node_ip: 147.142.68.85
#   pid: 96920
#   time_since_restore: 450.6336464881897
#   time_this_iter_s: 234.34130883216858
#   time_total_s: 450.6336464881897
#   timestamp: 1661778187
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00003
#   warmup_time: 0.0043027400970458984
#
# Result for train_mnist_d6d05_00003:
#   date: 2022-08-29_15-03-07
#   done: true
#   experiment_id: 0e90858623cb450eaa85859ec5da25fc
#   experiment_tag: 3_lr=0.0010,momentum=0.9900,weight_decay=0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 98.35
#   node_ip: 147.142.68.85
#   pid: 96920
#   time_since_restore: 450.6336464881897
#   time_this_iter_s: 234.34130883216858
#   time_total_s: 450.6336464881897
#   timestamp: 1661778187
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00003
#   warmup_time: 0.0043027400970458984
#
# Result for train_mnist_d6d05_00007:
#   date: 2022-08-29_15-03-25
#   done: false
#   experiment_id: ce329c6a43fa4ec2849a25f88c1e70a4
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 93.32
#   node_ip: 147.142.68.85
#   pid: 97127
#   time_since_restore: 460.0130891799927
#   time_this_iter_s: 234.79770421981812
#   time_total_s: 460.0130891799927
#   timestamp: 1661778205
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00007
#   warmup_time: 0.00983572006225586
#
# Result for train_mnist_d6d05_00007:
#   date: 2022-08-29_15-03-25
#   done: true
#   experiment_id: ce329c6a43fa4ec2849a25f88c1e70a4
#   experiment_tag: 7_lr=0.0100,momentum=0.9000,weight_decay=0.0100
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 93.32
#   node_ip: 147.142.68.85
#   pid: 97127
#   time_since_restore: 460.0130891799927
#   time_this_iter_s: 234.79770421981812
#   time_total_s: 460.0130891799927
#   timestamp: 1661778205
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00007
#   warmup_time: 0.00983572006225586
#
# Result for train_mnist_d6d05_00006:
#   date: 2022-08-29_15-03-25
#   done: false
#   experiment_id: 2fe3b689ad5941b9aaca9d3af3b26b0c
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 96.17
#   node_ip: 147.142.68.85
#   pid: 97124
#   time_since_restore: 461.3054401874542
#   time_this_iter_s: 236.28336381912231
#   time_total_s: 461.3054401874542
#   timestamp: 1661778205
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00006
#   warmup_time: 0.004260063171386719
#
# Result for train_mnist_d6d05_00006:
#   date: 2022-08-29_15-03-25
#   done: true
#   experiment_id: 2fe3b689ad5941b9aaca9d3af3b26b0c
#   experiment_tag: 6_lr=0.0010,momentum=0.9000,weight_decay=0.0100
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 96.17
#   node_ip: 147.142.68.85
#   pid: 97124
#   time_since_restore: 461.3054401874542
#   time_this_iter_s: 236.28336381912231
#   time_total_s: 461.3054401874542
#   timestamp: 1661778205
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00006
#   warmup_time: 0.004260063171386719
#
# Result for train_mnist_d6d05_00008:
#   date: 2022-08-29_15-03-27
#   done: false
#   experiment_id: f04744bd2c524396b7729fee139bf300
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 97.27
#   node_ip: 147.142.68.85
#   pid: 97310
#   time_since_restore: 455.6686351299286
#   time_this_iter_s: 232.4838569164276
#   time_total_s: 455.6686351299286
#   timestamp: 1661778207
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00008
#   warmup_time: 0.009851455688476562
#
# Result for train_mnist_d6d05_00008:
#   date: 2022-08-29_15-03-27
#   done: true
#   experiment_id: f04744bd2c524396b7729fee139bf300
#   experiment_tag: 8_lr=0.1000,momentum=0.9000,weight_decay=0.0100
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 97.27
#   node_ip: 147.142.68.85
#   pid: 97310
#   time_since_restore: 455.6686351299286
#   time_this_iter_s: 232.4838569164276
#   time_total_s: 455.6686351299286
#   timestamp: 1661778207
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00008
#   warmup_time: 0.009851455688476562
#
# Result for train_mnist_d6d05_00009:
#   date: 2022-08-29_15-03-36
#   done: false
#   experiment_id: 3a01de2a0b6c4a7787c17638a7900b85
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 95.66
#   node_ip: 147.142.68.85
#   pid: 97393
#   time_since_restore: 457.8082420825958
#   time_this_iter_s: 229.93001985549927
#   time_total_s: 457.8082420825958
#   timestamp: 1661778216
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00009
#   warmup_time: 0.012578010559082031
#
# Result for train_mnist_d6d05_00009:
#   date: 2022-08-29_15-03-36
#   done: true
#   experiment_id: 3a01de2a0b6c4a7787c17638a7900b85
#   experiment_tag: 9_lr=0.0010,momentum=0.9900,weight_decay=0.0100
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 95.66
#   node_ip: 147.142.68.85
#   pid: 97393
#   time_since_restore: 457.8082420825958
#   time_this_iter_s: 229.93001985549927
#   time_total_s: 457.8082420825958
#   timestamp: 1661778216
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00009
#   warmup_time: 0.012578010559082031
#
# Result for train_mnist_d6d05_00010:
#   date: 2022-08-29_15-03-41
#   done: false
#   experiment_id: 21b6c0002646473db9af64d3d9725dae
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 93.16
#   node_ip: 147.142.68.85
#   pid: 97540
#   time_since_restore: 455.0114860534668
#   time_this_iter_s: 224.53381204605103
#   time_total_s: 455.0114860534668
#   timestamp: 1661778221
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00010
#   warmup_time: 0.017763853073120117
#
# Result for train_mnist_d6d05_00010:
#   date: 2022-08-29_15-03-41
#   done: true
#   experiment_id: 21b6c0002646473db9af64d3d9725dae
#   experiment_tag: 10_lr=0.0100,momentum=0.9900,weight_decay=0.0100
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 93.16
#   node_ip: 147.142.68.85
#   pid: 97540
#   time_since_restore: 455.0114860534668
#   time_this_iter_s: 224.53381204605103
#   time_total_s: 455.0114860534668
#   timestamp: 1661778221
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00010
#   warmup_time: 0.017763853073120117
#
# Result for train_mnist_d6d05_00011:
#   date: 2022-08-29_15-03-45
#   done: false
#   experiment_id: 070c5ce040f74800b1e8f38246149c75
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 90.6
#   node_ip: 147.142.68.85
#   pid: 97622
#   time_since_restore: 450.98347878456116
#   time_this_iter_s: 220.13501071929932
#   time_total_s: 450.98347878456116
#   timestamp: 1661778225
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00011
#   warmup_time: 0.012460708618164062
#
# Result for train_mnist_d6d05_00011:
#   date: 2022-08-29_15-03-45
#   done: true
#   experiment_id: 070c5ce040f74800b1e8f38246149c75
#   experiment_tag: 11_lr=0.1000,momentum=0.9900,weight_decay=0.0100
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 90.6
#   node_ip: 147.142.68.85
#   pid: 97622
#   time_since_restore: 450.98347878456116
#   time_this_iter_s: 220.13501071929932
#   time_total_s: 450.98347878456116
#   timestamp: 1661778225
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00011
#   warmup_time: 0.012460708618164062
#
# Result for train_mnist_d6d05_00012:
#   date: 2022-08-29_15-05-02
#   done: false
#   experiment_id: 6eb2d6ddb1ca433a98476d01ce30bb94
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 76.74
#   node_ip: 147.142.68.85
#   pid: 96840
#   time_since_restore: 139.96768236160278
#   time_this_iter_s: 139.96768236160278
#   time_total_s: 139.96768236160278
#   timestamp: 1661778302
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00012
#   warmup_time: 0.0029163360595703125
#
# Result for train_mnist_d6d05_00013:
#   date: 2022-08-29_15-05-05
#   done: false
#   experiment_id: 3e54a894655340fa9993945b657772e0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 85.13
#   node_ip: 147.142.68.85
#   pid: 96922
#   time_since_restore: 129.25716757774353
#   time_this_iter_s: 129.25716757774353
#   time_total_s: 129.25716757774353
#   timestamp: 1661778305
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00013
#   warmup_time: 0.004798173904418945
#
# Result for train_mnist_d6d05_00015:
#   date: 2022-08-29_15-05-12
#   done: false
#   experiment_id: 3564bc84c2d7442398ab5c644993d1a4
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 78.27
#   node_ip: 147.142.68.85
#   pid: 96898
#   time_since_restore: 131.9203155040741
#   time_this_iter_s: 131.9203155040741
#   time_total_s: 131.9203155040741
#   timestamp: 1661778312
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00015
#   warmup_time: 0.004522562026977539
#
# Result for train_mnist_d6d05_00016:
#   date: 2022-08-29_15-05-12
#   done: false
#   experiment_id: b3701e47210e430fa1ed6425754c2461
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 37.62
#   node_ip: 147.142.68.85
#   pid: 96962
#   time_since_restore: 129.07028698921204
#   time_this_iter_s: 129.07028698921204
#   time_total_s: 129.07028698921204
#   timestamp: 1661778312
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00016
#   warmup_time: 0.004241228103637695
#
# Result for train_mnist_d6d05_00017:
#   date: 2022-08-29_15-05-14
#   done: false
#   experiment_id: 0e90858623cb450eaa85859ec5da25fc
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 61.12
#   node_ip: 147.142.68.85
#   pid: 96920
#   time_since_restore: 126.68470573425293
#   time_this_iter_s: 126.68470573425293
#   time_total_s: 126.68470573425293
#   timestamp: 1661778314
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00017
#   warmup_time: 0.0043027400970458984
#
# Result for train_mnist_d6d05_00014:
#   date: 2022-08-29_15-05-14
#   done: false
#   experiment_id: 09dead0ff7394abfba708c66d4c6fb7e
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 55.16
#   node_ip: 147.142.68.85
#   pid: 96891
#   time_since_restore: 135.299622297287
#   time_this_iter_s: 135.299622297287
#   time_total_s: 135.299622297287
#   timestamp: 1661778314
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: d6d05_00014
#   warmup_time: 0.002808094024658203
#
# Result for train_mnist_d6d05_00012:
#   date: 2022-08-29_15-06-53
#   done: false
#   experiment_id: 6eb2d6ddb1ca433a98476d01ce30bb94
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 79.84
#   node_ip: 147.142.68.85
#   pid: 96840
#   time_since_restore: 251.3289337158203
#   time_this_iter_s: 111.36125135421753
#   time_total_s: 251.3289337158203
#   timestamp: 1661778413
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00012
#   warmup_time: 0.0029163360595703125
#
# Result for train_mnist_d6d05_00012:
#   date: 2022-08-29_15-06-53
#   done: true
#   experiment_id: 6eb2d6ddb1ca433a98476d01ce30bb94
#   experiment_tag: 12_lr=0.0010,momentum=0.9000,weight_decay=0.1000
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 79.84
#   node_ip: 147.142.68.85
#   pid: 96840
#   time_since_restore: 251.3289337158203
#   time_this_iter_s: 111.36125135421753
#   time_total_s: 251.3289337158203
#   timestamp: 1661778413
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00012
#   warmup_time: 0.0029163360595703125
#
# Result for train_mnist_d6d05_00013:
#   date: 2022-08-29_15-06-57
#   done: false
#   experiment_id: 3e54a894655340fa9993945b657772e0
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 88.69
#   node_ip: 147.142.68.85
#   pid: 96922
#   time_since_restore: 241.35749292373657
#   time_this_iter_s: 112.10032534599304
#   time_total_s: 241.35749292373657
#   timestamp: 1661778417
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00013
#   warmup_time: 0.004798173904418945
#
# Result for train_mnist_d6d05_00013:
#   date: 2022-08-29_15-06-57
#   done: true
#   experiment_id: 3e54a894655340fa9993945b657772e0
#   experiment_tag: 13_lr=0.0100,momentum=0.9000,weight_decay=0.1000
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 88.69
#   node_ip: 147.142.68.85
#   pid: 96922
#   time_since_restore: 241.35749292373657
#   time_this_iter_s: 112.10032534599304
#   time_total_s: 241.35749292373657
#   timestamp: 1661778417
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00013
#   warmup_time: 0.004798173904418945
#
# Result for train_mnist_d6d05_00015:
#   date: 2022-08-29_15-07-04
#   done: false
#   experiment_id: 3564bc84c2d7442398ab5c644993d1a4
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 76.32
#   node_ip: 147.142.68.85
#   pid: 96898
#   time_since_restore: 243.6615219116211
#   time_this_iter_s: 111.741206407547
#   time_total_s: 243.6615219116211
#   timestamp: 1661778424
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00015
#   warmup_time: 0.004522562026977539
#
# Result for train_mnist_d6d05_00015:
#   date: 2022-08-29_15-07-04
#   done: true
#   experiment_id: 3564bc84c2d7442398ab5c644993d1a4
#   experiment_tag: 15_lr=0.0010,momentum=0.9900,weight_decay=0.1000
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 76.32
#   node_ip: 147.142.68.85
#   pid: 96898
#   time_since_restore: 243.6615219116211
#   time_this_iter_s: 111.741206407547
#   time_total_s: 243.6615219116211
#   timestamp: 1661778424
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00015
#   warmup_time: 0.004522562026977539
#
# Result for train_mnist_d6d05_00016:
#   date: 2022-08-29_15-07-04
#   done: false
#   experiment_id: b3701e47210e430fa1ed6425754c2461
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 62.91
#   node_ip: 147.142.68.85
#   pid: 96962
#   time_since_restore: 241.59546399116516
#   time_this_iter_s: 112.52517700195312
#   time_total_s: 241.59546399116516
#   timestamp: 1661778424
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00016
#   warmup_time: 0.004241228103637695
#
# Result for train_mnist_d6d05_00016:
#   date: 2022-08-29_15-07-04
#   done: true
#   experiment_id: b3701e47210e430fa1ed6425754c2461
#   experiment_tag: 16_lr=0.0100,momentum=0.9900,weight_decay=0.1000
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 62.91
#   node_ip: 147.142.68.85
#   pid: 96962
#   time_since_restore: 241.59546399116516
#   time_this_iter_s: 112.52517700195312
#   time_total_s: 241.59546399116516
#   timestamp: 1661778424
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00016
#   warmup_time: 0.004241228103637695
#
# Result for train_mnist_d6d05_00017:
#   date: 2022-08-29_15-07-05
#   done: false
#   experiment_id: 0e90858623cb450eaa85859ec5da25fc
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 61.59
#   node_ip: 147.142.68.85
#   pid: 96920
#   time_since_restore: 237.78889322280884
#   time_this_iter_s: 111.10418748855591
#   time_total_s: 237.78889322280884
#   timestamp: 1661778425
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00017
#   warmup_time: 0.0043027400970458984
#
# Result for train_mnist_d6d05_00017:
#   date: 2022-08-29_15-07-05
#   done: true
#   experiment_id: 0e90858623cb450eaa85859ec5da25fc
#   experiment_tag: 17_lr=0.1000,momentum=0.9900,weight_decay=0.1000
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 61.59
#   node_ip: 147.142.68.85
#   pid: 96920
#   time_since_restore: 237.78889322280884
#   time_this_iter_s: 111.10418748855591
#   time_total_s: 237.78889322280884
#   timestamp: 1661778425
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00017
#   warmup_time: 0.0043027400970458984
#
# Result for train_mnist_d6d05_00014:
#   date: 2022-08-29_15-07-06
#   done: false
#   experiment_id: 09dead0ff7394abfba708c66d4c6fb7e
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 67.1
#   node_ip: 147.142.68.85
#   pid: 96891
#   time_since_restore: 246.92278742790222
#   time_this_iter_s: 111.62316513061523
#   time_total_s: 246.92278742790222
#   timestamp: 1661778426
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00014
#   warmup_time: 0.002808094024658203
#
# Result for train_mnist_d6d05_00014:
#   date: 2022-08-29_15-07-06
#   done: true
#   experiment_id: 09dead0ff7394abfba708c66d4c6fb7e
#   experiment_tag: 14_lr=0.1000,momentum=0.9000,weight_decay=0.1000
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 67.1
#   node_ip: 147.142.68.85
#   pid: 96891
#   time_since_restore: 246.92278742790222
#   time_this_iter_s: 111.62316513061523
#   time_total_s: 246.92278742790222
#   timestamp: 1661778426
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: d6d05_00014
#   warmup_time: 0.002808094024658203
# 2022-08-29 15:07:06,676	INFO tune.py:758 -- Total run time: 706.66 seconds (705.67 seconds for the tuning loop).
# Best config:  {'lr': 0.1, 'momentum': 0.9, 'weight_decay': 0}

# %%
from Models import LeNet
input_shape = (batch_size, 1, 28, 28)
criterion = CrossEntropyLoss()

def train_mnist(config):
    test_device = "cpu"
    model = LeNet(input_shape, 10, initial_lr=config["lr"], momentum=config["momentum"], weight_decay=0).to(test_device)
    for i in range(2):
        train_NN(model, criterion, train_dataloader,
        test_dataloader, epochs=2, batches_to_test=100,patience=2,device=test_device, print_test=False, verbose=False)
        acc = test_loss(model, test_dataloader, criterion, test_device)[1]
        tune.report(mean_accuracy=acc)

# %%
config = {"steps": 2,"lr": tune.uniform(0.001, 0.1), "momentum": tune.uniform(0.1, 1)}

bayesopt = BayesOptSearch(metric="mean_accuracy", mode="max")

tuner = tune.Tuner(train_mnist, tune_config=tune.TuneConfig(search_alg=bayesopt, num_samples=5), param_space=config)

analysis = tuner.fit()
# Out:
# 2022-08-29 16:42:52,539	WARNING bayesopt_search.py:423 -- BayesOpt does not support specific sampling methods. The Uniform sampler will be dropped.
# 2022-08-29 16:42:52,539	WARNING bayesopt_search.py:423 -- BayesOpt does not support specific sampling methods. The Uniform sampler will be dropped.
# == Status ==<br>Current time: 2022-08-29 16:46:10 (running for 00:03:17.33)<br>Memory usage on this node: 10.7/15.4 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/12 CPUs, 0/1 GPUs, 0.0/4.36 GiB heap, 0.0/2.18 GiB objects (0.0/1.0 accelerator_type:G)<br>Result logdir: /home/max/ray_results/train_mnist_2022-08-29_16-42-51<br>Number of trials: 5/5 (5 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name          </th><th>status    </th><th>loc                  </th><th style="text-align: right;">        lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">  acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>train_mnist_dca770a6</td><td>TERMINATED</td><td>129.206.61.139:129797</td><td style="text-align: right;">0.0380795 </td><td style="text-align: right;">  0.955643</td><td style="text-align: right;">98.94</td><td style="text-align: right;">     2</td><td style="text-align: right;">         185.733</td></tr>
# <tr><td>train_mnist_debca8d4</td><td>TERMINATED</td><td>129.206.61.139:129848</td><td style="text-align: right;">0.0734674 </td><td style="text-align: right;">  0.638793</td><td style="text-align: right;">81.88</td><td style="text-align: right;">     2</td><td style="text-align: right;">         185.63 </td></tr>
# <tr><td>train_mnist_df3b427a</td><td>TERMINATED</td><td>129.206.61.139:129872</td><td style="text-align: right;">0.0164458 </td><td style="text-align: right;">  0.240395</td><td style="text-align: right;">84.22</td><td style="text-align: right;">     2</td><td style="text-align: right;">         187.914</td></tr>
# <tr><td>train_mnist_dfc3da04</td><td>TERMINATED</td><td>129.206.61.139:129898</td><td style="text-align: right;">0.00675028</td><td style="text-align: right;">  0.879559</td><td style="text-align: right;">98.01</td><td style="text-align: right;">     2</td><td style="text-align: right;">         187.512</td></tr>
# <tr><td>train_mnist_e0607eea</td><td>TERMINATED</td><td>129.206.61.139:129939</td><td style="text-align: right;">0.0605104 </td><td style="text-align: right;">  0.737265</td><td style="text-align: right;">98.35</td><td style="text-align: right;">     2</td><td style="text-align: right;">         186.534</td></tr>
# </tbody>
# </table><br><br>
# 2022-08-29 16:42:54,289	WARNING worker.py:1829 -- Warning: The actor ImplicitFunc is very large (52 MiB). Check that its definition is not implicitly capturing a large array or other object in scope. Tip: use ray.put() to put large objects in the Ray object store.
# 2022-08-29 16:42:54,427	WARNING util.py:220 -- The `start_trial` operation took 0.951 s, which may be a performance bottleneck.
# Result for train_mnist_dca770a6:
#   date: 2022-08-29_16-44-26
#   done: false
#   experiment_id: 318f1ba9084d438bbb046ef1c981b5c6
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 98.49
#   node_ip: 129.206.61.139
#   pid: 129797
#   time_since_restore: 89.69512009620667
#   time_this_iter_s: 89.69512009620667
#   time_total_s: 89.69512009620667
#   timestamp: 1661784266
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: dca770a6
#   warmup_time: 0.002826690673828125
#
# Result for train_mnist_debca8d4:
#   date: 2022-08-29_16-44-31
#   done: false
#   experiment_id: e7ef166a1f8d4b41b5c058e9f1dfb97a
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 95.53
#   node_ip: 129.206.61.139
#   pid: 129848
#   time_since_restore: 91.39510655403137
#   time_this_iter_s: 91.39510655403137
#   time_total_s: 91.39510655403137
#   timestamp: 1661784271
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: debca8d4
#   warmup_time: 0.0028324127197265625
#
# Result for train_mnist_df3b427a:
#   date: 2022-08-29_16-44-34
#   done: false
#   experiment_id: 6f5dbd2f8aba4fd4bac247a56731ee81
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 95.98
#   node_ip: 129.206.61.139
#   pid: 129872
#   time_since_restore: 93.08461499214172
#   time_this_iter_s: 93.08461499214172
#   time_total_s: 93.08461499214172
#   timestamp: 1661784274
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: df3b427a
#   warmup_time: 0.0039577484130859375
#
# Result for train_mnist_dfc3da04:
#   date: 2022-08-29_16-44-35
#   done: false
#   experiment_id: 50ed1c2ad36947cb827342474e38c73a
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 94.25
#   node_ip: 129.206.61.139
#   pid: 129898
#   time_since_restore: 93.04969239234924
#   time_this_iter_s: 93.04969239234924
#   time_total_s: 93.04969239234924
#   timestamp: 1661784275
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: dfc3da04
#   warmup_time: 0.004178762435913086
#
# Result for train_mnist_e0607eea:
#   date: 2022-08-29_16-44-36
#   done: false
#   experiment_id: bd08cbb745a344969bde54ecc3c103be
#   hostname: max-Latitude-5401
#   iterations_since_restore: 1
#   mean_accuracy: 93.47
#   node_ip: 129.206.61.139
#   pid: 129939
#   time_since_restore: 92.98487496376038
#   time_this_iter_s: 92.98487496376038
#   time_total_s: 92.98487496376038
#   timestamp: 1661784276
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: e0607eea
#   warmup_time: 0.005148172378540039
#
# Result for train_mnist_dca770a6:
#   date: 2022-08-29_16-46-02
#   done: false
#   experiment_id: 318f1ba9084d438bbb046ef1c981b5c6
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 98.94
#   node_ip: 129.206.61.139
#   pid: 129797
#   time_since_restore: 185.73275065422058
#   time_this_iter_s: 96.03763055801392
#   time_total_s: 185.73275065422058
#   timestamp: 1661784362
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dca770a6
#   warmup_time: 0.002826690673828125
#
# Result for train_mnist_dca770a6:
#   date: 2022-08-29_16-46-02
#   done: true
#   experiment_id: 318f1ba9084d438bbb046ef1c981b5c6
#   experiment_tag: 1_lr=0.0381,momentum=0.9556,steps=2
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 98.94
#   node_ip: 129.206.61.139
#   pid: 129797
#   time_since_restore: 185.73275065422058
#   time_this_iter_s: 96.03763055801392
#   time_total_s: 185.73275065422058
#   timestamp: 1661784362
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dca770a6
#   warmup_time: 0.002826690673828125
#
# Result for train_mnist_debca8d4:
#   date: 2022-08-29_16-46-05
#   done: false
#   experiment_id: e7ef166a1f8d4b41b5c058e9f1dfb97a
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 81.88
#   node_ip: 129.206.61.139
#   pid: 129848
#   time_since_restore: 185.62972712516785
#   time_this_iter_s: 94.23462057113647
#   time_total_s: 185.62972712516785
#   timestamp: 1661784365
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: debca8d4
#   warmup_time: 0.0028324127197265625
#
# Result for train_mnist_debca8d4:
#   date: 2022-08-29_16-46-05
#   done: true
#   experiment_id: e7ef166a1f8d4b41b5c058e9f1dfb97a
#   experiment_tag: 2_lr=0.0735,momentum=0.6388,steps=2
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 81.88
#   node_ip: 129.206.61.139
#   pid: 129848
#   time_since_restore: 185.62972712516785
#   time_this_iter_s: 94.23462057113647
#   time_total_s: 185.62972712516785
#   timestamp: 1661784365
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: debca8d4
#   warmup_time: 0.0028324127197265625
#
# Result for train_mnist_df3b427a:
#   date: 2022-08-29_16-46-08
#   done: false
#   experiment_id: 6f5dbd2f8aba4fd4bac247a56731ee81
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 84.22
#   node_ip: 129.206.61.139
#   pid: 129872
#   time_since_restore: 187.91350388526917
#   time_this_iter_s: 94.82888889312744
#   time_total_s: 187.91350388526917
#   timestamp: 1661784368
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: df3b427a
#   warmup_time: 0.0039577484130859375
#
# Result for train_mnist_df3b427a:
#   date: 2022-08-29_16-46-08
#   done: true
#   experiment_id: 6f5dbd2f8aba4fd4bac247a56731ee81
#   experiment_tag: 3_lr=0.0164,momentum=0.2404,steps=2
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 84.22
#   node_ip: 129.206.61.139
#   pid: 129872
#   time_since_restore: 187.91350388526917
#   time_this_iter_s: 94.82888889312744
#   time_total_s: 187.91350388526917
#   timestamp: 1661784368
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: df3b427a
#   warmup_time: 0.0039577484130859375
#
# Result for train_mnist_dfc3da04:
#   date: 2022-08-29_16-46-09
#   done: false
#   experiment_id: 50ed1c2ad36947cb827342474e38c73a
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 98.01
#   node_ip: 129.206.61.139
#   pid: 129898
#   time_since_restore: 187.51159977912903
#   time_this_iter_s: 94.46190738677979
#   time_total_s: 187.51159977912903
#   timestamp: 1661784369
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dfc3da04
#   warmup_time: 0.004178762435913086
#
# Result for train_mnist_dfc3da04:
#   date: 2022-08-29_16-46-09
#   done: true
#   experiment_id: 50ed1c2ad36947cb827342474e38c73a
#   experiment_tag: 4_lr=0.0068,momentum=0.8796,steps=2
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 98.01
#   node_ip: 129.206.61.139
#   pid: 129898
#   time_since_restore: 187.51159977912903
#   time_this_iter_s: 94.46190738677979
#   time_total_s: 187.51159977912903
#   timestamp: 1661784369
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: dfc3da04
#   warmup_time: 0.004178762435913086
#
# Result for train_mnist_e0607eea:
#   date: 2022-08-29_16-46-10
#   done: false
#   experiment_id: bd08cbb745a344969bde54ecc3c103be
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 98.35
#   node_ip: 129.206.61.139
#   pid: 129939
#   time_since_restore: 186.53414487838745
#   time_this_iter_s: 93.54926991462708
#   time_total_s: 186.53414487838745
#   timestamp: 1661784370
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: e0607eea
#   warmup_time: 0.005148172378540039
#
# Result for train_mnist_e0607eea:
#   date: 2022-08-29_16-46-10
#   done: true
#   experiment_id: bd08cbb745a344969bde54ecc3c103be
#   experiment_tag: 5_lr=0.0605,momentum=0.7373,steps=2
#   hostname: max-Latitude-5401
#   iterations_since_restore: 2
#   mean_accuracy: 98.35
#   node_ip: 129.206.61.139
#   pid: 129939
#   time_since_restore: 186.53414487838745
#   time_this_iter_s: 93.54926991462708
#   time_total_s: 186.53414487838745
#   timestamp: 1661784370
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: e0607eea
#   warmup_time: 0.005148172378540039
# 2022-08-29 16:46:10,268	INFO tune.py:758 -- Total run time: 198.28 seconds (197.33 seconds for the tuning loop).

# %%
print(analysis.get_best_result(metric="mean_accuracy", mode="max"))
analysis.get_dataframe()
# Out:
# Result(metrics={'mean_accuracy': 98.94, 'done': True, 'trial_id': 'dca770a6', 'experiment_tag': '1_lr=0.0381,momentum=0.9556,steps=2'}, error=None, log_dir=PosixPath('/home/max/ray_results/train_mnist_2022-08-29_16-42-51/train_mnist_dca770a6_1_lr=0.0381,momentum=0.9556,steps=2_2022-08-29_16-42-53'))
#    mean_accuracy  time_this_iter_s   done  timesteps_total  episodes_total  \
# 0          98.94         96.037631  False              NaN             NaN
# 1          81.88         94.234621  False              NaN             NaN
# 2          84.22         94.828889  False              NaN             NaN
# 3          98.01         94.461907  False              NaN             NaN
# 4          98.35         93.549270  False              NaN             NaN
#
#    training_iteration  trial_id                     experiment_id  \
# 0                   2  dca770a6  318f1ba9084d438bbb046ef1c981b5c6
# 1                   2  debca8d4  e7ef166a1f8d4b41b5c058e9f1dfb97a
# 2                   2  df3b427a  6f5dbd2f8aba4fd4bac247a56731ee81
# 3                   2  dfc3da04  50ed1c2ad36947cb827342474e38c73a
# 4                   2  e0607eea  bd08cbb745a344969bde54ecc3c103be
#
#                   date   timestamp  ...           hostname         node_ip  \
# 0  2022-08-29_16-46-02  1661784362  ...  max-Latitude-5401  129.206.61.139
# 1  2022-08-29_16-46-05  1661784365  ...  max-Latitude-5401  129.206.61.139
# 2  2022-08-29_16-46-08  1661784368  ...  max-Latitude-5401  129.206.61.139
# 3  2022-08-29_16-46-09  1661784369  ...  max-Latitude-5401  129.206.61.139
# 4  2022-08-29_16-46-10  1661784370  ...  max-Latitude-5401  129.206.61.139
#
#   time_since_restore timesteps_since_restore  iterations_since_restore  \
# 0         185.732751                       0                         2
# 1         185.629727                       0                         2
# 2         187.913504                       0                         2
# 3         187.511600                       0                         2
# 4         186.534145                       0                         2
#
#    warmup_time  config/lr  config/momentum  config/steps  \
# 0     0.002827   0.038079         0.955643             2
# 1     0.002832   0.073467         0.638793             2
# 2     0.003958   0.016446         0.240395             2
# 3     0.004179   0.006750         0.879559             2
# 4     0.005148   0.060510         0.737265             2
#
#                                               logdir
# 0  /home/max/ray_results/train_mnist_2022-08-29_1...
# 1  /home/max/ray_results/train_mnist_2022-08-29_1...
# 2  /home/max/ray_results/train_mnist_2022-08-29_1...
# 3  /home/max/ray_results/train_mnist_2022-08-29_1...
# 4  /home/max/ray_results/train_mnist_2022-08-29_1...
#
# [5 rows x 22 columns]
